# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\dhars\downloads\dhass\codeing\guvi\2. mainboot\4.project_code\project1\tennis_data_sportradar\.venv\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dhars\downloads\dhass\codeing\guvi\2. mainboot\4.project_code\project1\tennis_data_sportradar\.venv\lib\site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dhars\downloads\dhass\codeing\guvi\2. mainboot\4.project_code\project1\tennis_data_sportradar\.venv\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dhars\downloads\dhass\codeing\guvi\2. mainboot\4.project_code\project1\tennis_data_sportradar\.venv\lib\site-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dhars\downloads\dhass\codeing\guvi\2. mainboot\4.project_code\project1\tennis_data_sportradar\.venv\lib\site-packages (from requests) (2025.4.26)

# %%
import requests

url = "https://api.sportradar.com/tennis/trial/v3/en/complexes.json"

headers = {
    "accept": "application/json",
    "x-api-key": "KqqxRyHiVJpTNkBEu09mDWY6ZQTOEQUVRENVTP1B"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"generated_at":"2025-05-11T13:48:33+00:00","complexes":[{"id":"sr:complex:705","name":"Nacional","venues":[{"id":"sr:venue:70045","name":"Cancha Central","city_name":"Santiago","country_name":"Chile","country_code":"CHL","timezone":"America\/Santiago"}]},{"id":"sr:complex:1078","name":"Estadio de la Cartuja","venues":[{"id":"sr:venue:74856","name":"Centre Court","city_name":"Seville","country_name":"Spain","country_code":"ESP","timezone":"Europe\/Madrid"},{"id":"sr:venue:74858","name":"Court One","city_name":"Seville","country_name":"Spain","country_code":"ESP","timezone":"Europe\/Madrid"}]},{"id":"sr:complex:1495","name":"Sibur Arena","venues":[{"id":"sr:venue:1496","name":"COURT 1","city_name":"Saint Petersburg","country_name":"Russia","country_code":"RUS","timezone":"Europe\/Moscow"},{"id":"sr:venue:1500","name":"CENTER COURT","city_name":"Saint Petersburg","country_name":"Russia","country_code":"RUS","timezone":"Europe\/Moscow"},{"id":"sr:venue:62149","name":"Sibur Arena","city_name":"Saint Petersburg","country_name":"Russia","country_code":"RUS","timezone":"Europe\/Moscow"},{"id":"sr:venue:62153","name":"TC Dynamo","city_name":"Saint Petersburg","country_name":"Russia","country_code":"RUS","timezone":"Europe\/Moscow"}]},{"id":"sr:complex:2375","name":"Complexo de Tenis do Jamor","venues":[{"id":"sr:venue:57912","name":"Central","city_name":"Oeiras","country_name":"Portugal","country_code":"PRT","timezone":"Europe\/Lisbon"},{"id":"sr:venue:70805","name":"Campo 3","city_name":"Oeiras","country_name":"Portugal","country_code":"PRT","timezone":"Europe\/Lisbon"},{"id":"sr:venue:70807","name":"Campo 4","city_name":"Oeiras","country_name":"Portugal","country_code":"PRT","timezone":"Europe\/Lisbon"},{"id":"sr:venue:77423","name":"Campo 1","city_name":"Oeiras","country_name":"Portugal","country_code":"PRT","timezone":"Europe\/Lisbon"},{"id":"sr:venue:77437","name":"Campo 8","city_name":"Oeiras","country_name":"Portugal","country_code":"PRT","timezone":"Europe\/Lisbon"}]},{"id":"sr:complex:4032","name":"Shree Shiv Chhatrapati Sports Complex"},{"id":"sr:complex:5520","name":"O2 Arena"},{"id":"sr:complex:5526","name":"Ostravar Arena","venues":[{"id":"sr:venue:13912","name":"Centre Court","city_name":"Ostrava","country_name":"Czechia","country_code":"CZE","timezone":"Europe\/Prague"},{"id":"sr:venue:13914","name":"Court 3","city_name":"Ostrava","country_name":"Czechia","country_code":"CZE","timezone":"Europe\/Prague"},{"id":"sr:venue:13916","name":"Court 6","city_name":"Ostrava","country_name":"Czechia","country_code":"CZE","timezone":"Europe\/Prague"},{"id":"sr:venue:13942","name":"Court 4","city_name":"Ostrava","country_name":"Czechia","country_code":"CZE","timezone":"Europe\/Prague"},{"id":"sr:venue:55221","name":"Court 1","capacity":1,"city_name":"Ostrava","country_name":"Czechia","country_code":"CZE","timezone":"Europe\/Prague"},{"id":"sr:venue:55223","name":"Court 2","capacity":1,"city_name":"Ostrava","country_name":"Czechia","country_code":"CZE","timezone":"Europe\/Prague"}]},{"id":"sr:complex:6310","name":"Varazdin Arena","venues":[{"id":"sr:venue:77271","name":"Table 1","city_name":"Varazdin","country_name":"Croatia","country_code":"HRV","timezone":"Europe\/Zagreb"},{"id":"sr:venue:77273","name":"Table 2","city_name":"Varazdin","country_name":"Croatia","country_code":"HRV","timezone":"Europe\/Zagreb"},{"id":"sr:venue:77275","name":"Table 3","city_name":"Varazdin","country_name":"Croatia","country_code":"HRV","timezone":"Europe\/Zagreb"},{"id":"sr:venue:77277","name":"Table 4","city_name":"Varazdin","country_name":"Croatia","country_code":"HRV","timezone":"Europe\/Zagreb"},{"id":"sr:venue:77279","name":"Table 5","city_name":"Varazdin","country_name":"Croatia","country_code":"HRV","timezone":"Europe\/Zagreb"},{"id":"sr:venue:77281","name":"Table 6","city_name":"Varazdin","country_name":"Croatia","country_code":"HRV","timezone":"Europe\/Zagreb"},{"id":"sr:venue:77283","name":"Table 7","city_name":"Varazdin","country_name":"Croa ...

# %%
import json
data = json.loads(response.text)
data
# Out:
# {'generated_at': '2025-05-11T13:48:33+00:00',
#  'complexes': [{'id': 'sr:complex:705',
#    'name': 'Nacional',
#    'venues': [{'id': 'sr:venue:70045',
#      'name': 'Cancha Central',
#      'city_name': 'Santiago',
#      'country_name': 'Chile',
#      'country_code': 'CHL',
#      'timezone': 'America/Santiago'}]},
#   {'id': 'sr:complex:1078',
#    'name': 'Estadio de la Cartuja',
#    'venues': [{'id': 'sr:venue:74856',
#      'name': 'Centre Court',
#      'city_name': 'Seville',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:74858',
#      'name': 'Court One',
#      'city_name': 'Seville',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'}]},
#   {'id': 'sr:complex:1495',
#    'name': 'Sibur Arena',
#    'venues': [{'id': 'sr:venue:1496',
#      'name': 'COURT 1',
#      'city_name': 'Saint Petersburg',
#      'country_name': 'Russia',
#      'country_code': 'RUS',
#      'timezone': 'Europe/Moscow'},
#     {'id': 'sr:venue:1500',
#      'name': 'CENTER COURT',
#      'city_name': 'Saint Petersburg',
#      'country_name': 'Russia',
#      'country_code': 'RUS',
#      'timezone': 'Europe/Moscow'},
#     {'id': 'sr:venue:62149',
#      'name': 'Sibur Arena',
#      'city_name': 'Saint Petersburg',
#      'country_name': 'Russia',
#      'country_code': 'RUS',
#      'timezone': 'Europe/Moscow'},
#     {'id': 'sr:venue:62153',
#      'name': 'TC Dynamo',
#      'city_name': 'Saint Petersburg',
#      'country_name': 'Russia',
#      'country_code': 'RUS',
#      'timezone': 'Europe/Moscow'}]},
#   {'id': 'sr:complex:2375',
#    'name': 'Complexo de Tenis do Jamor',
#    'venues': [{'id': 'sr:venue:57912',
#      'name': 'Central',
#      'city_name': 'Oeiras',
#      'country_name': 'Portugal',
#      'country_code': 'PRT',
#      'timezone': 'Europe/Lisbon'},
#     {'id': 'sr:venue:70805',
#      'name': 'Campo 3',
#      'city_name': 'Oeiras',
#      'country_name': 'Portugal',
#      'country_code': 'PRT',
#      'timezone': 'Europe/Lisbon'},
#     {'id': 'sr:venue:70807',
#      'name': 'Campo 4',
#      'city_name': 'Oeiras',
#      'country_name': 'Portugal',
#      'country_code': 'PRT',
#      'timezone': 'Europe/Lisbon'},
#     {'id': 'sr:venue:77423',
#      'name': 'Campo 1',
#      'city_name': 'Oeiras',
#      'country_name': 'Portugal',
#      'country_code': 'PRT',
#      'timezone': 'Europe/Lisbon'},
#     {'id': 'sr:venue:77437',
#      'name': 'Campo 8',
#      'city_name': 'Oeiras',
#      'country_name': 'Portugal',
#      'country_code': 'PRT',
#      'timezone': 'Europe/Lisbon'}]},
#   {'id': 'sr:complex:4032', 'name': 'Shree Shiv Chhatrapati Sports Complex'},
#   {'id': 'sr:complex:5520', 'name': 'O2 Arena'},
#   {'id': 'sr:complex:5526',
#    'name': 'Ostravar Arena',
#    'venues': [{'id': 'sr:venue:13912',
#      'name': 'Centre Court',
#      'city_name': 'Ostrava',
#      'country_name': 'Czechia',
#      'country_code': 'CZE',
#      'timezone': 'Europe/Prague'},
#     {'id': 'sr:venue:13914',
#      'name': 'Court 3',
#      'city_name': 'Ostrava',
#      'country_name': 'Czechia',
#      'country_code': 'CZE',
#      'timezone': 'Europe/Prague'},
#     {'id': 'sr:venue:13916',
#      'name': 'Court 6',
#      'city_name': 'Ostrava',
#      'country_name': 'Czechia',
#      'country_code': 'CZE',
#      'timezone': 'Europe/Prague'},
#     {'id': 'sr:venue:13942',
#      'name': 'Court 4',
#      'city_name': 'Ostrava',
#      'country_name': 'Czechia',
#      'country_code': 'CZE',
#      'timezone': 'Europe/Prague'},
#     {'id': 'sr:venue:55221',
#      'name': 'Court 1',
#      'capacity': 1,
#      'city_name': 'Ostrava',
#      'country_name': 'Czechia',
#      'country_code': 'CZE',
#      'timezone': 'Europe/Prague'},
#     {'id': 'sr:venue:55223',
#      'name': 'Court 2',
#      'capacity': 1,
#      'city_name': 'Ostrava',
#      'country_name': 'Czechia',
#      'country_code': 'CZE',
#      'timezone': 'Europe/Prague'}]},
#   {'id': 'sr:complex:6310',
#    'name': 'Varazdin Arena',
#    'venues': [{'id': 'sr:venue:77271',
#      'name': 'Table 1',
#      'city_name': 'Varazdin',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:77273',
#      'name': 'Table 2',
#      'city_name': 'Varazdin',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:77275',
#      'name': 'Table 3',
#      'city_name': 'Varazdin',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:77277',
#      'name': 'Table 4',
#      'city_name': 'Varazdin',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:77279',
#      'name': 'Table 5',
#      'city_name': 'Varazdin',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:77281',
#      'name': 'Table 6',
#      'city_name': 'Varazdin',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:77283',
#      'name': 'Table 7',
#      'city_name': 'Varazdin',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:77285',
#      'name': 'Table 8',
#      'city_name': 'Varazdin',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'}]},
#   {'id': 'sr:complex:6484',
#    'name': 'Arena Montpellier',
#    'venues': [{'id': 'sr:venue:2146',
#      'name': 'Court 1',
#      'city_name': 'Montpellier',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:19477',
#      'name': 'Court Patrice Dominguez',
#      'city_name': 'Montpellier',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:30567',
#      'name': 'Court Central',
#      'city_name': 'Montpellier',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:30569',
#      'name': 'Court 2',
#      'city_name': 'Montpellier',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:39934',
#      'name': 'Court 3',
#      'city_name': 'Montpellier',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'}]},
#   {'id': 'sr:complex:6736', 'name': 'Arenes de Metz'},
#   {'id': 'sr:complex:6888', 'name': 'Palais des sports de Pau'},
#   {'id': 'sr:complex:6890',
#    'name': 'Palais des Sports Orleans',
#    'venues': [{'id': 'sr:venue:66107',
#      'name': 'Court 2',
#      'city_name': 'Orchies',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:66109',
#      'name': 'Court 3',
#      'city_name': 'Orleans',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:66111',
#      'name': 'Court 4',
#      'city_name': 'Orleans',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:70605',
#      'name': 'Court 5',
#      'city_name': 'Orleans',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:74195',
#      'name': 'Center Court',
#      'city_name': 'Orleans',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:74197',
#      'name': 'Court 1',
#      'city_name': 'Orleans',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'}]},
#   {'id': 'sr:complex:6904', 'name': 'Stade Pierre-de-Coubertin'},
#   {'id': 'sr:complex:7048',
#    'name': 'Palacio de Deportes Jose Maria Martin Carpena',
#    'venues': [{'id': 'sr:venue:72565',
#      'name': 'Pista Cental',
#      'city_name': 'Malaga',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:72567',
#      'name': 'Pista 2',
#      'city_name': 'Malaga',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:72569',
#      'name': 'Pista 3',
#      'city_name': 'Malaga',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:72571',
#      'name': 'Pista 4',
#      'city_name': 'Malaga',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'}]},
#   {'id': 'sr:complex:7052', 'name': 'Pabellon Municipal Fuente San Luis'},
#   {'id': 'sr:complex:7208', 'name': 'Unipol Arena'},
#   {'id': 'sr:complex:7778', 'name': 'Arena Gripe'},
#   {'id': 'sr:complex:9725',
#    'name': 'Arena Armeets Sofia',
#    'venues': [{'id': 'sr:venue:17756',
#      'name': 'Center Court',
#      'city_name': 'Sofia',
#      'country_name': 'Bulgaria',
#      'country_code': 'BGR',
#      'timezone': 'Europe/Sofia'},
#     {'id': 'sr:venue:17758',
#      'name': 'Court 1',
#      'city_name': 'Sofia',
#      'country_name': 'Bulgaria',
#      'country_code': 'BGR',
#      'timezone': 'Europe/Sofia'},
#     {'id': 'sr:venue:23352',
#      'name': 'Court 3',
#      'city_name': 'Sofia',
#      'country_name': 'Bulgaria',
#      'country_code': 'BGR',
#      'timezone': 'Europe/Sofia'},
#     {'id': 'sr:venue:23354',
#      'name': 'Court 4',
#      'city_name': 'Sofia',
#      'country_name': 'Bulgaria',
#      'country_code': 'BGR',
#      'timezone': 'Europe/Sofia'},
#     {'id': 'sr:venue:23356',
#      'name': 'Court 2',
#      'city_name': 'Sofia',
#      'country_name': 'Bulgaria',
#      'country_code': 'BGR',
#      'timezone': 'Europe/Sofia'}]},
#   {'id': 'sr:complex:10063',
#    'name': 'Kindarena',
#    'venues': [{'id': 'sr:venue:66889',
#      'name': 'Center Court',
#      'city_name': 'Rouen',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:66925',
#      'name': 'Amelie Mauresmo',
#      'city_name': 'Rouen',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:66979',
#      'name': 'Celine Dumerc',
#      'city_name': 'Rouen',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:74546',
#      'name': 'Court 1',
#      'city_name': 'Rouen',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'}]},
#   {'id': 'sr:complex:11769',
#    'name': 'Estadio German Becker',
#    'venues': [{'id': 'sr:venue:67857',
#      'name': 'Cancha Central',
#      'city_name': 'Temuco',
#      'country_name': 'Chile',
#      'country_code': 'CHL',
#      'timezone': 'America/Santiago'},
#     {'id': 'sr:venue:67859',
#      'name': 'Cancha 1',
#      'city_name': 'Temuco',
#      'country_name': 'Chile',
#      'country_code': 'CHL',
#      'timezone': 'America/Santiago'},
#     {'id': 'sr:venue:67861',
#      'name': 'Cancha 2',
#      'city_name': 'Temuco',
#      'country_name': 'Chile',
#      'country_code': 'CHL',
#      'timezone': 'America/Santiago'},
#     {'id': 'sr:venue:67863',
#      'name': 'Cancha 3',
#      'city_name': 'Temuco',
#      'country_name': 'Chile',
#      'country_code': 'CHL',
#      'timezone': 'America/Santiago'}]},
#   {'id': 'sr:complex:12241',
#    'name': 'Palais des sports de Gerland',
#    'venues': [{'id': 'sr:venue:30465',
#      'name': 'Indoor 1',
#      'city_name': 'Lyon',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:30467',
#      'name': 'Indoor 2',
#      'city_name': 'Lyon',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:30469',
#      'name': 'Indoor 3',
#      'city_name': 'Lyon',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:39773',
#      'name': 'Court 23',
#      'capacity': 1,
#      'city_name': 'Lyon',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:39842',
#      'name': 'Court 14',
#      'city_name': 'Lyon',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:39844',
#      'name': 'Court 15',
#      'city_name': 'Lyon',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:58692',
#      'name': 'Court 12',
#      'capacity': 1,
#      'city_name': 'Lyon',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'}]},
#   {'id': 'sr:complex:15014',
#    'name': 'Palais Des Sport',
#    'venues': [{'id': 'sr:venue:15010',
#      'name': 'La Foret 3',
#      'city_name': 'Orleans',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:16880',
#      'name': 'Central Court',
#      'city_name': 'Orleans',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:23652',
#      'name': 'La Foret 2',
#      'city_name': 'Orleans',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:66105',
#      'name': 'Court 1',
#      'city_name': 'Orleans',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:66137',
#      'name': 'La Foret 4',
#      'capacity': 1,
#      'city_name': 'Orleans',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:66139',
#      'name': 'La Foret 1',
#      'capacity': 1,
#      'city_name': 'Orleans',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:70603',
#      'name': 'Court 2',
#      'city_name': 'Orleans',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'}]},
#   {'id': 'sr:complex:15371',
#    'name': 'Palasport',
#    'venues': [{'id': 'sr:venue:67869',
#      'name': 'Court 2',
#      'city_name': 'Andria',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'},
#     {'id': 'sr:venue:67871',
#      'name': 'Court 3',
#      'city_name': 'Andria',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'},
#     {'id': 'sr:venue:68095',
#      'name': 'Campo Tato Paride',
#      'city_name': 'Andria',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'},
#     {'id': 'sr:venue:68097',
#      'name': 'Campo Arpex',
#      'city_name': 'Andria',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'}]},
#   {'id': 'sr:complex:16020',
#    'name': 'Salle Steredenn',
#    'venues': [{'id': 'sr:venue:16022',
#      'name': 'Atg 3',
#      'city_name': 'Saint-Brieuc',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:18015',
#      'name': 'Atg 4',
#      'city_name': 'Saint-Brieuc',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:28371',
#      'name': 'Tcsb 4',
#      'city_name': 'Saint-Brieuc',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:28373',
#      'name': 'Tcsb 3',
#      'city_name': 'Saint-Brieuc',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:62697',
#      'name': 'Court Steredenn',
#      'city_name': 'Saint-Brieuc',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:80523',
#      'name': 'Court TCSB',
#      'city_name': 'Saint-Brieuc',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'}]},
#   {'id': 'sr:complex:16069',
#    'name': 'Garanti Koza Arena',
#    'venues': [{'id': 'sr:venue:14874',
#      'name': 'Court Limak Enerji',
#      'city_name': 'Istanbul',
#      'country_name': 'Turkiye',
#      'country_code': 'TUR',
#      'timezone': 'Europe/Istanbul'}]},
#   {'id': 'sr:complex:16612',
#    'name': 'Porsche-Arena',
#    'venues': [{'id': 'sr:venue:1765',
#      'name': 'Centre Court',
#      'city_name': 'Stuttgart',
#      'country_name': 'Germany',
#      'country_code': 'DEU',
#      'timezone': 'Europe/Berlin'},
#     {'id': 'sr:venue:77411',
#      'name': 'Court 1',
#      'city_name': 'Stuttgart',
#      'country_name': 'Germany',
#      'country_code': 'DEU',
#      'timezone': 'Europe/Berlin'},
#     {'id': 'sr:venue:77413',
#      'name': 'Court 2',
#      'city_name': 'Stuttgart',
#      'country_name': 'Germany',
#      'country_code': 'DEU',
#      'timezone': 'Europe/Berlin'}]},
#   {'id': 'sr:complex:17254', 'name': "Poliesportiu d'Andorra"},
#   {'id': 'sr:complex:17945',
#    'name': 'Rotterdam Ahoy',
#    'venues': [{'id': 'sr:venue:1648',
#      'name': 'Court 1',
#      'city_name': 'Rotterdam',
#      'country_name': 'Netherlands',
#      'country_code': 'NLD',
#      'timezone': 'Europe/Brussels'},
#     {'id': 'sr:venue:3696',
#      'name': 'Court 2',
#      'city_name': 'Rotterdam',
#      'country_name': 'Netherlands',
#      'country_code': 'NLD',
#      'timezone': 'Europe/Brussels'},
#     {'id': 'sr:venue:22854',
#      'name': 'Centre Court',
#      'city_name': 'Rotterdam',
#      'country_name': 'Netherlands',
#      'country_code': 'NLD',
#      'timezone': 'Europe/Brussels'}]},
#   {'id': 'sr:complex:18201',
#    'name': 'The O2',
#    'venues': [{'id': 'sr:venue:66121',
#      'name': 'Centre Court',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'}]},
#   {'id': 'sr:complex:18221',
#    'name': 'Bluesun Tennis Center',
#    'venues': [{'id': 'sr:venue:18223',
#      'name': 'Cedevita Court',
#      'city_name': 'Bol',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:18225',
#      'name': 'Cockta Court',
#      'city_name': 'Bol',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:18227',
#      'name': 'Kala Court',
#      'city_name': 'Bol',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:21412',
#      'name': 'INA Court',
#      'city_name': 'Bol',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:21422',
#      'name': 'Raiffeisen Court',
#      'city_name': 'Bol',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:30195',
#      'name': 'Lukas Court',
#      'city_name': 'Bol',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:39715',
#      'name': 'Center Court',
#      'city_name': 'Bol',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:39717',
#      'name': 'Court 1',
#      'city_name': 'Bol',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'}]},
#   {'id': 'sr:complex:19166', 'name': 'Shlomo Group Arena'},
#   {'id': 'sr:complex:19737',
#    'name': 'Club Sonoma, Estadio Gnp Seguros',
#    'venues': [{'id': 'sr:venue:1695',
#      'name': 'Center Court',
#      'city_name': 'Monterrey',
#      'country_name': 'Mexico',
#      'country_code': 'MEX',
#      'timezone': 'America/Mexico_City'},
#     {'id': 'sr:venue:1696',
#      'name': 'Court 1',
#      'city_name': 'Monterrey',
#      'country_name': 'Mexico',
#      'country_code': 'MEX',
#      'timezone': 'America/Mexico_City'},
#     {'id': 'sr:venue:62341',
#      'name': 'Court 4',
#      'city_name': 'Monterrey',
#      'country_name': 'Mexico',
#      'country_code': 'MEX',
#      'timezone': 'America/Mexico_City'}]},
#   {'id': 'sr:complex:19951',
#    'name': 'Accor Arena',
#    'venues': [{'id': 'sr:venue:1520',
#      'name': 'Court Central',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1521',
#      'name': 'Court 1',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1522',
#      'name': 'Court 2',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'}]},
#   {'id': 'sr:complex:21870',
#    'name': 'Stadium Goran Ivanisevic in ITC Stella Maris',
#    'venues': [{'id': 'sr:venue:21868',
#      'name': 'Next Gen Arena',
#      'city_name': 'Umag',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'}]},
#   {'id': 'sr:complex:21910',
#    'name': 'Roy Emerson Arena',
#    'venues': [{'id': 'sr:venue:1938',
#      'name': 'Roy Emerson Arena',
#      'city_name': 'Gstaad',
#      'country_name': 'Switzerland',
#      'country_code': 'CHE',
#      'timezone': 'Europe/Zurich'},
#     {'id': 'sr:venue:1939',
#      'name': 'Court 1',
#      'city_name': 'Gstaad',
#      'country_name': 'Switzerland',
#      'country_code': 'CHE',
#      'timezone': 'Europe/Zurich'},
#     {'id': 'sr:venue:1953',
#      'name': 'Sportzentrum 1',
#      'city_name': 'Gstaad',
#      'country_name': 'Switzerland',
#      'country_code': 'CHE',
#      'timezone': 'Europe/Zurich'},
#     {'id': 'sr:venue:2461',
#      'name': 'Sportzentrum 3',
#      'city_name': 'Gstaad',
#      'country_name': 'Switzerland',
#      'country_code': 'CHE',
#      'timezone': 'Europe/Zurich'}]},
#   {'id': 'sr:complex:26983',
#    'name': 'Club de Tenis Puente Romano',
#    'venues': [{'id': 'sr:venue:1728',
#      'name': 'Centre Court',
#      'city_name': 'Marbella',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:1729',
#      'name': 'Court 1',
#      'city_name': 'Marbella',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:1730',
#      'name': 'Court 7',
#      'city_name': 'Marbella',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:28357',
#      'name': 'Court 2',
#      'city_name': 'Marbella',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:33908',
#      'name': 'Court 3',
#      'city_name': 'Marbella',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:33916',
#      'name': 'Court 4',
#      'city_name': 'Marbella',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:57732',
#      'name': 'Estadio Manolo Santana',
#      'city_name': 'Marbella',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:62729',
#      'name': 'Court 8',
#      'city_name': 'Marbella',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:62731',
#      'name': 'Court 9',
#      'city_name': 'Marbella',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'}]},
#   {'id': 'sr:complex:26985',
#    'name': 'National Tennis Center',
#    'venues': [{'id': 'sr:venue:1383',
#      'name': 'Astana Arena',
#      'capacity': 30000,
#      'city_name': 'Astana',
#      'country_name': 'Kazakhstan',
#      'map_coordinates': '51.108244,71.402584',
#      'country_code': 'KAZ',
#      'timezone': 'Asia/Almaty'},
#     {'id': 'sr:venue:2595',
#      'name': 'Astana',
#      'city_name': 'Astana',
#      'country_name': 'Kazakhstan',
#      'country_code': 'KAZ',
#      'timezone': 'Asia/Almaty'},
#     {'id': 'sr:venue:14620',
#      'name': 'Center Court',
#      'city_name': 'Astana',
#      'country_name': 'Kazakhstan',
#      'country_code': 'KAZ',
#      'timezone': 'Asia/Almaty'},
#     {'id': 'sr:venue:14622',
#      'name': 'Court 1',
#      'city_name': 'Astana',
#      'country_name': 'Kazakhstan',
#      'country_code': 'KAZ',
#      'timezone': 'Asia/Almaty'},
#     {'id': 'sr:venue:14624',
#      'name': 'Court 2',
#      'city_name': 'Astana',
#      'country_name': 'Kazakhstan',
#      'country_code': 'KAZ',
#      'timezone': 'Asia/Almaty'},
#     {'id': 'sr:venue:14626',
#      'name': 'Court 3',
#      'city_name': 'Astana',
#      'country_name': 'Kazakhstan',
#      'country_code': 'KAZ',
#      'timezone': 'Asia/Almaty'},
#     {'id': 'sr:venue:14628',
#      'name': 'Court 6',
#      'city_name': 'Astana',
#      'country_name': 'Kazakhstan',
#      'country_code': 'KAZ',
#      'timezone': 'Asia/Almaty'},
#     {'id': 'sr:venue:18439',
#      'name': 'Court 4',
#      'city_name': 'Astana',
#      'country_name': 'Kazakhstan',
#      'country_code': 'KAZ',
#      'timezone': 'Asia/Almaty'},
#     {'id': 'sr:venue:31557',
#      'name': 'Court 9',
#      'city_name': 'Astana',
#      'country_name': 'Kazakhstan',
#      'country_code': 'KAZ',
#      'timezone': 'Asia/Almaty'},
#     {'id': 'sr:venue:32005',
#      'name': 'Indoor Center Court',
#      'city_name': 'Astana',
#      'country_name': 'Kazakhstan',
#      'country_code': 'KAZ',
#      'timezone': 'Asia/Almaty'},
#     {'id': 'sr:venue:43100',
#      'name': 'Court 5',
#      'city_name': 'Astana',
#      'country_name': 'Kazakhstan',
#      'country_code': 'KAZ',
#      'timezone': 'Asia/Almaty'},
#     {'id': 'sr:venue:59164',
#      'name': 'Indoor Court 3',
#      'city_name': 'Astana',
#      'country_name': 'Kazakhstan',
#      'country_code': 'KAZ',
#      'timezone': 'Asia/Almaty'}]},
#   {'id': 'sr:complex:27093',
#    'name': 'Canberra Tennis Centre',
#    'venues': [{'id': 'sr:venue:25218',
#      'name': 'Court 4',
#      'city_name': 'Canberra',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/ACT'},
#     {'id': 'sr:venue:25292',
#      'name': 'Centre Court',
#      'city_name': 'Canberra',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/ACT'},
#     {'id': 'sr:venue:25296',
#      'name': 'Court 7',
#      'city_name': 'Canberra',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/ACT'},
#     {'id': 'sr:venue:25298',
#      'name': 'Court 5',
#      'city_name': 'Canberra',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/ACT'},
#     {'id': 'sr:venue:68975',
#      'name': 'Court 1',
#      'city_name': 'Canberra',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/ACT'},
#     {'id': 'sr:venue:68977',
#      'name': 'Court 6',
#      'city_name': 'Canberra',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/ACT'},
#     {'id': 'sr:venue:75825',
#      'name': 'Court 2',
#      'city_name': 'Canberra',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/ACT'}]},
#   {'id': 'sr:complex:27095',
#    'name': 'BT Arena',
#    'venues': [{'id': 'sr:venue:59476',
#      'name': 'Center Court',
#      'city_name': 'Cluj Napoca',
#      'country_name': 'Romania',
#      'country_code': 'ROU',
#      'timezone': 'Europe/Bucharest'},
#     {'id': 'sr:venue:59478',
#      'name': 'Court 2',
#      'city_name': 'Cluj Napoca',
#      'country_name': 'Romania',
#      'country_code': 'ROU',
#      'timezone': 'Europe/Bucharest'}]},
#   {'id': 'sr:complex:28457',
#    'name': 'Valletta Cambiaso ASD',
#    'venues': [{'id': 'sr:venue:14846',
#      'name': 'Center Court',
#      'city_name': 'Genoa',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'},
#     {'id': 'sr:venue:14848',
#      'name': 'Court 1',
#      'city_name': 'Genoa',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'},
#     {'id': 'sr:venue:14850',
#      'name': 'Court 2',
#      'city_name': 'Genoa',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'},
#     {'id': 'sr:venue:14852',
#      'name': 'Campo 3',
#      'city_name': 'Genoa',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'},
#     {'id': 'sr:venue:58750',
#      'name': 'Court 3',
#      'city_name': 'Genoa',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'},
#     {'id': 'sr:venue:58754',
#      'name': 'Court 4',
#      'city_name': 'Genoa',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'},
#     {'id': 'sr:venue:66059',
#      'name': 'Centrale',
#      'city_name': 'Genoa',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'},
#     {'id': 'sr:venue:66061',
#      'name': 'Campo 1',
#      'city_name': 'Genoa',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'},
#     {'id': 'sr:venue:66063',
#      'name': 'Campo 2',
#      'city_name': 'Genoa',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'}]},
#   {'id': 'sr:complex:28617',
#    'name': 'Porsche Arena',
#    'venues': [{'id': 'sr:venue:1766',
#      'name': 'Court 1',
#      'city_name': 'Stuttgart',
#      'country_name': 'Germany',
#      'country_code': 'DEU',
#      'timezone': 'Europe/Berlin'},
#     {'id': 'sr:venue:2345',
#      'name': 'Court 2',
#      'city_name': 'Stuttgart',
#      'country_name': 'Germany',
#      'country_code': 'DEU',
#      'timezone': 'Europe/Berlin'},
#     {'id': 'sr:venue:2421',
#      'name': 'Court 18',
#      'city_name': 'Stuttgart',
#      'country_name': 'Germany',
#      'country_code': 'DEU',
#      'timezone': 'Europe/Berlin'},
#     {'id': 'sr:venue:16273',
#      'name': 'Court 3',
#      'city_name': 'Stuttgart',
#      'country_name': 'Germany',
#      'country_code': 'DEU',
#      'timezone': 'Europe/Berlin'},
#     {'id': 'sr:venue:30921',
#      'name': 'Court 4',
#      'city_name': 'Stuttgart',
#      'country_name': 'Germany',
#      'country_code': 'DEU',
#      'timezone': 'Europe/Berlin'},
#     {'id': 'sr:venue:77441',
#      'name': 'Centre Court',
#      'city_name': 'Stuttgart',
#      'country_name': 'Germany',
#      'country_code': 'DEU',
#      'timezone': 'Europe/Berlin'}]},
#   {'id': 'sr:complex:28926',
#    'name': 'Royal Arena',
#    'venues': [{'id': 'sr:venue:73239',
#      'name': 'Court 1',
#      'city_name': 'Copenhagen',
#      'country_name': 'Denmark',
#      'country_code': 'DNK',
#      'timezone': 'Europe/Copenhagen'},
#     {'id': 'sr:venue:73241',
#      'name': 'Court 2',
#      'city_name': 'Copenhagen',
#      'country_name': 'Denmark',
#      'country_code': 'DNK',
#      'timezone': 'Europe/Copenhagen'},
#     {'id': 'sr:venue:73243',
#      'name': 'Court 3',
#      'city_name': 'Copenhagen',
#      'country_name': 'Denmark',
#      'country_code': 'DNK',
#      'timezone': 'Europe/Copenhagen'},
#     {'id': 'sr:venue:73245',
#      'name': 'Court 4',
#      'city_name': 'Copenhagen',
#      'country_name': 'Denmark',
#      'country_code': 'DNK',
#      'timezone': 'Europe/Copenhagen'}]},
#   {'id': 'sr:complex:32327',
#    'name': 'Taipei Arena',
#    'venues': [{'id': 'sr:venue:13904',
#      'name': 'Centre Court',
#      'city_name': 'Taipei',
#      'country_name': 'Chinese Taipei',
#      'country_code': 'TPE',
#      'timezone': 'Asia/Taipei'},
#     {'id': 'sr:venue:13906',
#      'name': 'Court 2',
#      'city_name': 'Taipei',
#      'country_name': 'Chinese Taipei',
#      'country_code': 'TPE',
#      'timezone': 'Asia/Taipei'},
#     {'id': 'sr:venue:15298',
#      'name': 'Court 1',
#      'city_name': 'Taipei',
#      'country_name': 'Chinese Taipei',
#      'country_code': 'TPE',
#      'timezone': 'Asia/Taipei'},
#     {'id': 'sr:venue:31685',
#      'name': 'Court 3',
#      'city_name': 'Taipei',
#      'country_name': 'Chinese Taipei',
#      'country_code': 'TPE',
#      'timezone': 'Asia/Taipei'},
#     {'id': 'sr:venue:31687',
#      'name': 'Show court',
#      'city_name': 'Taipei',
#      'country_name': 'Chinese Taipei',
#      'country_code': 'TPE',
#      'timezone': 'Asia/Taipei'},
#     {'id': 'sr:venue:31689',
#      'name': 'Court 4',
#      'city_name': 'Taipei',
#      'country_name': 'Chinese Taipei',
#      'country_code': 'TPE',
#      'timezone': 'Asia/Taipei'},
#     {'id': 'sr:venue:31947',
#      'name': 'Court 6',
#      'city_name': 'Taipei',
#      'country_name': 'Chinese Taipei',
#      'country_code': 'TPE',
#      'timezone': 'Asia/Taipei'},
#     {'id': 'sr:venue:31951',
#      'name': 'Court 7',
#      'city_name': 'Taipei',
#      'country_name': 'Chinese Taipei',
#      'country_code': 'TPE',
#      'timezone': 'Asia/Taipei'},
#     {'id': 'sr:venue:31953',
#      'name': 'Court 5',
#      'city_name': 'Taipei',
#      'country_name': 'Chinese Taipei',
#      'country_code': 'TPE',
#      'timezone': 'Asia/Taipei'},
#     {'id': 'sr:venue:31955',
#      'name': 'Court 8',
#      'city_name': 'Taipei',
#      'country_name': 'Chinese Taipei',
#      'country_code': 'TPE',
#      'timezone': 'Asia/Taipei'}]},
#   {'id': 'sr:complex:32403', 'name': 'Ohio State University GC'},
#   {'id': 'sr:complex:32668', 'name': 'Shenzhen Bay Sports Center'},
#   {'id': 'sr:complex:32812',
#    'name': 'Singapore Indoor Stadium',
#    'venues': [{'id': 'sr:venue:15250',
#      'name': 'Centre Court',
#      'city_name': 'Kallang',
#      'country_name': 'Singapore',
#      'country_code': 'SGP',
#      'timezone': 'Asia/Singapore'},
#     {'id': 'sr:venue:71439',
#      'name': 'Court 2',
#      'city_name': 'Kallang',
#      'country_name': 'Singapore',
#      'country_code': 'SGP',
#      'timezone': 'Asia/Singapore'},
#     {'id': 'sr:venue:71441',
#      'name': 'Court 3',
#      'city_name': 'Kallang',
#      'country_name': 'Singapore',
#      'country_code': 'SGP',
#      'timezone': 'Asia/Singapore'},
#     {'id': 'sr:venue:71443',
#      'name': 'Court 4',
#      'city_name': 'Kallang',
#      'country_name': 'Singapore',
#      'country_code': 'SGP',
#      'timezone': 'Asia/Singapore'}]},
#   {'id': 'sr:complex:33186',
#    'name': 'Palais des Sports de Marseille',
#    'venues': [{'id': 'sr:venue:1665',
#      'name': 'Central',
#      'city_name': 'Marseille',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1666',
#      'name': 'Court 1',
#      'city_name': 'Marseille',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:38311',
#      'name': 'Court 2',
#      'city_name': 'Marseille',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'}]},
#   {'id': 'sr:complex:33188',
#    'name': 'Caja Magica',
#    'venues': [{'id': 'sr:venue:56690',
#      'name': 'Pista 2',
#      'city_name': 'Madrid',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:56692',
#      'name': 'Pista 3',
#      'city_name': 'Madrid',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:68305',
#      'name': 'Court Central',
#      'city_name': 'Madrid',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'}]},
#   {'id': 'sr:complex:33190',
#    'name': 'All England Lawn Tennis and Croquet Club',
#    'venues': [{'id': 'sr:venue:1846',
#      'name': 'Court 1',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1848',
#      'name': 'Court 9',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1849',
#      'name': 'Court 10',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1855',
#      'name': 'Court 3',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1856',
#      'name': 'Court 12',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1884',
#      'name': 'Court 4',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1886',
#      'name': 'Court 6',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1887',
#      'name': 'Court 7',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1888',
#      'name': 'Court 8',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1889',
#      'name': 'Court 11',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1890',
#      'name': 'Court 13',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1891',
#      'name': 'Court 14',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1892',
#      'name': 'Court 15',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1893',
#      'name': 'Court 16',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1894',
#      'name': 'Court 18',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1900',
#      'name': 'Court 17',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:19070',
#      'name': 'Centre Court',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:21634',
#      'name': 'Court 2',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:21642',
#      'name': 'Court 5',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'}]},
#   {'id': 'sr:complex:33192',
#    'name': 'Stade Roland Garros',
#    'venues': [{'id': 'sr:venue:1809',
#      'name': 'Court 6',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1810',
#      'name': 'Court 7',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1811',
#      'name': 'Court 8',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1812',
#      'name': 'Court 9',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1813',
#      'name': 'Court 10',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1814',
#      'name': 'Court 11',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1815',
#      'name': 'Court 12',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1816',
#      'name': 'Court 13',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1817',
#      'name': 'Court 14',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1818',
#      'name': 'Court 15',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1819',
#      'name': 'Court 16',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1826',
#      'name': 'Court Philippe Chatrier',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1827',
#      'name': 'Court Suzanne Lenglen',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1828',
#      'name': 'Court 3',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1829',
#      'name': 'Court 4',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1830',
#      'name': 'Court 5',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:39589',
#      'name': 'Court Simonne Mathieu',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'}]},
#   {'id': 'sr:complex:33194', 'name': 'Complexe Al Amal'},
#   {'id': 'sr:complex:33196',
#    'name': 'Melbourne Park',
#    'venues': [{'id': 'sr:venue:1572',
#      'name': 'Court 3',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1573',
#      'name': 'Court 4',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1574',
#      'name': 'Court 5',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1575',
#      'name': 'Court 6',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1576',
#      'name': 'Court 7',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1577',
#      'name': 'Court 8',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1578',
#      'name': 'Court 10',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1579',
#      'name': 'Court 11',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1580',
#      'name': 'Court 9',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1581',
#      'name': 'Court 12',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1582',
#      'name': 'Court 13',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1583',
#      'name': 'Court 14',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1584',
#      'name': 'Court 15',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1586',
#      'name': 'Rod Laver Arena',
#      'capacity': 14820,
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1587',
#      'name': 'John Cain Arena',
#      'capacity': 10500,
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'map_coordinates': '-37.822568, 144.980913',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1588',
#      'name': 'Margaret Court Arena',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1589',
#      'name': '1573 Arena',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1590',
#      'name': 'Court 18',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1591',
#      'name': 'Court 19',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1592',
#      'name': 'Court 21',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:10536',
#      'name': 'Court 20',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:10538',
#      'name': 'Court 22',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:57064',
#      'name': 'Court 16',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:57072',
#      'name': 'Court 17',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:61865',
#      'name': 'Kia Arena',
#      'capacity': 5000,
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'}]},
#   {'id': 'sr:complex:33198',
#    'name': 'Qi zhong Forest Sports City Arena',
#    'venues': [{'id': 'sr:venue:23520',
#      'name': 'Indoor West',
#      'city_name': 'Shanghai',
#      'country_name': 'China',
#      'country_code': 'CHN',
#      'timezone': 'Asia/Shanghai'},
#     {'id': 'sr:venue:24396',
#      'name': 'Indoor 1',
#      'city_name': 'Shanghai',
#      'country_name': 'China',
#      'country_code': 'CHN',
#      'timezone': 'Asia/Shanghai'}]},
#   {'id': 'sr:complex:33200',
#    'name': 'Wake Forest University Tennis Complex',
#    'venues': [{'id': 'sr:venue:2575',
#      'name': 'Center Court',
#      'city_name': 'Winston Salem, NC',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/New_York'},
#     {'id': 'sr:venue:2577',
#      'name': 'Court 2',
#      'city_name': 'Winston Salem, NC',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/New_York'},
#     {'id': 'sr:venue:2579',
#      'name': 'Court 3',
#      'city_name': 'Winston Salem, NC',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/New_York'},
#     {'id': 'sr:venue:2581',
#      'name': 'Court 4',
#      'city_name': 'Winston Salem, NC',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/New_York'},
#     {'id': 'sr:venue:2583',
#      'name': 'Court 5',
#      'city_name': 'Winston Salem, NC',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/New_York'},
#     {'id': 'sr:venue:16760',
#      'name': 'Stadium',
#      'city_name': 'Winston Salem, NC',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/New_York'}]},
#   {'id': 'sr:complex:33204', 'name': 'Clube de Ténis do Estoril'},
#   {'id': 'sr:complex:33206',
# ...
#      'timezone': 'America/New_York'},
#     {'id': 'sr:venue:82410',
#      'name': 'Georgia Gwinnett - Court 06',
#      'city_name': 'Lawrenceville, GA',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/New_York'}]},
#   {'id': 'sr:complex:82007',
#    'name': 'Sport Center Visnjik (Clay)',
#    'venues': [{'id': 'sr:venue:82009',
#      'name': 'Sport Center Visnjik Court 4 (Clay)',
#      'city_name': 'Zadar',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:82011',
#      'name': 'Sport Center Visnjik Court 5 (Clay)',
#      'city_name': 'Zadar',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:82013',
#      'name': 'Sport Center Visnjik Court 6 (Clay)',
#      'city_name': 'Zadar',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:82021',
#      'name': 'Sport Center Visnjik (Clay) - Court 3',
#      'city_name': 'Zadar',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:82045',
#      'name': 'Sport Center Visnjik (Clay) - Court 1',
#      'city_name': 'Zadar',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:82195',
#      'name': 'Sport Center Visnjik (Clay) - Court 2',
#      'city_name': 'Zadar',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'}]},
#   {'id': 'sr:complex:82033',
#    'name': 'Spot - Salle Jean Burger',
#    'venues': [{'id': 'sr:venue:82057',
#      'name': 'Court 1',
#      'city_name': 'Thionville',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:82059',
#      'name': 'Court Central',
#      'city_name': 'Thionville',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'}]},
#   {'id': 'sr:complex:82065',
#    'name': 'Raquet Village',
#    'venues': [{'id': 'sr:venue:82093',
#      'name': 'Grandstand',
#      'city_name': 'Cap Cana',
#      'country_name': 'Dominican Republic',
#      'country_code': 'DOM',
#      'timezone': 'America/Santo_Domingo'},
#     {'id': 'sr:venue:82095',
#      'name': 'Estadio',
#      'city_name': 'Cap Cana',
#      'country_name': 'Dominican Republic',
#      'country_code': 'DOM',
#      'timezone': 'America/Santo_Domingo'},
#     {'id': 'sr:venue:82103',
#      'name': 'Cancha 1',
#      'city_name': 'Cap Cana',
#      'country_name': 'Dominican Republic',
#      'country_code': 'DOM',
#      'timezone': 'America/Santo_Domingo'}]},
#   {'id': 'sr:complex:82109',
#    'name': 'Manzanillo',
#    'venues': [{'id': 'sr:venue:82111',
#      'name': 'Manzanillo - Court 03',
#      'city_name': 'Manzanillo',
#      'country_name': 'Mexico',
#      'country_code': 'MEX',
#      'timezone': 'America/Mexico_City'},
#     {'id': 'sr:venue:82113',
#      'name': 'Manzanillo - Court 01',
#      'city_name': 'Manzanillo',
#      'country_name': 'Mexico',
#      'country_code': 'MEX',
#      'timezone': 'America/Mexico_City'},
#     {'id': 'sr:venue:82115',
#      'name': 'Manzanillo - Court 02',
#      'city_name': 'Manzanillo',
#      'country_name': 'Mexico',
#      'country_code': 'MEX',
#      'timezone': 'America/Mexico_City'},
#     {'id': 'sr:venue:82117',
#      'name': 'Manzanillo - Court 04',
#      'city_name': 'Manzanillo',
#      'country_name': 'Mexico',
#      'country_code': 'MEX',
#      'timezone': 'America/Mexico_City'}]},
#   {'id': 'sr:complex:82131',
#    'name': 'Club de Golf Tres Marias',
#    'venues': [{'id': 'sr:venue:82143',
#      'name': 'Estadio',
#      'city_name': 'Morelia',
#      'country_name': 'Mexico',
#      'country_code': 'MEX',
#      'timezone': 'America/Mexico_City'},
#     {'id': 'sr:venue:82145',
#      'name': 'Cancha 1',
#      'city_name': 'Morelia',
#      'country_name': 'Mexico',
#      'country_code': 'MEX',
#      'timezone': 'America/Mexico_City'},
#     {'id': 'sr:venue:82147',
#      'name': 'Cancha 2',
#      'city_name': 'Morelia',
#      'country_name': 'Mexico',
#      'country_code': 'MEX',
#      'timezone': 'America/Mexico_City'},
#     {'id': 'sr:venue:82209',
#      'name': 'Estadio Tres Marias',
#      'city_name': 'Morelia',
#      'country_name': 'Mexico',
#      'country_code': 'MEX',
#      'timezone': 'America/Mexico_City'},
#     {'id': 'sr:venue:82211',
#      'name': 'Grandstand Pablo Arroyo',
#      'city_name': 'Morelia',
#      'country_name': 'Mexico',
#      'country_code': 'MEX',
#      'timezone': 'America/Mexico_City'}]},
#   {'id': 'sr:complex:82133',
#    'name': 'Sheraton Buganvilias Resort and Convention Center',
#    'venues': [{'id': 'sr:venue:61569',
#      'name': 'Court 1',
#      'city_name': 'Puerto Vallarta',
#      'country_name': 'Mexico',
#      'country_code': 'MEX',
#      'timezone': 'America/Mexico_City'},
#     {'id': 'sr:venue:82135',
#      'name': 'Estadio Akron',
#      'city_name': 'Puerto Vallarta',
#      'country_name': 'Mexico',
#      'country_code': 'MEX',
#      'timezone': 'America/Mexico_City'},
#     {'id': 'sr:venue:82137',
#      'name': 'Cancha 1',
#      'city_name': 'Puerto Vallarta',
#      'country_name': 'Mexico',
#      'country_code': 'MEX',
#      'timezone': 'America/Mexico_City'},
#     {'id': 'sr:venue:82217',
#      'name': 'Sheraton Buganvilias',
#      'city_name': 'Puerto Vallarta',
#      'country_name': 'Mexico',
#      'country_code': 'MEX',
#      'timezone': 'America/Mexico_City'}]},
#   {'id': 'sr:complex:82197',
#    'name': 'Tennis Club Porto Rose',
#    'venues': [{'id': 'sr:venue:82199',
#      'name': 'Tennis Club Porto Rose - Centre Court',
#      'city_name': 'Roseto Degli Abruzzi',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'},
#     {'id': 'sr:venue:82201',
#      'name': 'Tennis Club Porto Rose - Court 1',
#      'city_name': 'Roseto Degli Abruzzi',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'},
#     {'id': 'sr:venue:82251',
#      'name': 'Tennis Club Porto Rose - Court 2',
#      'city_name': 'Roseto Degli Abruzzi',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'}]},
#   {'id': 'sr:complex:82223',
#    'name': 'Complejo Deportivo San Carlos De Apoquindo',
#    'venues': [{'id': 'sr:venue:82225',
#      'name': 'Cc. Banco De Chile',
#      'city_name': 'Santiago',
#      'country_name': 'Chile',
#      'country_code': 'CHL',
#      'timezone': 'America/Santiago'},
#     {'id': 'sr:venue:82227',
#      'name': 'C2 Shell',
#      'city_name': 'Santiago',
#      'country_name': 'Chile',
#      'country_code': 'CHL',
#      'timezone': 'America/Santiago'},
#     {'id': 'sr:venue:82229',
#      'name': 'C3 Costa',
#      'city_name': 'Santiago',
#      'country_name': 'Chile',
#      'country_code': 'CHL',
#      'timezone': 'America/Santiago'},
#     {'id': 'sr:venue:82231',
#      'name': 'C4 Skechers',
#      'city_name': 'Santiago',
#      'country_name': 'Chile',
#      'country_code': 'CHL',
#      'timezone': 'America/Santiago'}]},
#   {'id': 'sr:complex:82243',
#    'name': 'Club Tenis Ciutadella',
#    'venues': [{'id': 'sr:venue:82273',
#      'name': 'Menorca Center Court',
#      'city_name': 'Menorca',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:82275',
#      'name': 'San Miguel Court 2',
#      'city_name': 'Menorca',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:82277',
#      'name': 'Joma Court 3',
#      'city_name': 'Menorca',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'}]},
#   {'id': 'sr:complex:82279',
#    'name': 'Tenis Club Crvena Zvezda',
#    'venues': [{'id': 'sr:venue:82281',
#      'name': 'Tenis Club Crvena Zvezda - Court 02',
#      'city_name': 'Belgrade',
#      'country_name': 'Serbia',
#      'country_code': 'SRB',
#      'timezone': 'Europe/Belgrade'},
#     {'id': 'sr:venue:82283',
#      'name': 'Tenis Club Crvena Zvezda - Court 04',
#      'city_name': 'Belgrade',
#      'country_name': 'Serbia',
#      'country_code': 'SRB',
#      'timezone': 'Europe/Belgrade'},
#     {'id': 'sr:venue:82285',
#      'name': 'Tenis Club Crvena Zvezda - Court 03',
#      'city_name': 'Belgrade',
#      'country_name': 'Serbia',
#      'country_code': 'SRB',
#      'timezone': 'Europe/Belgrade'}]},
#   {'id': 'sr:complex:82301',
#    'name': 'Villa Reale Tennis Monza',
#    'venues': [{'id': 'sr:venue:82317',
#      'name': 'Center Court',
#      'city_name': 'Monza',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'},
#     {'id': 'sr:venue:82319',
#      'name': 'Court 2',
#      'city_name': 'Monza',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'},
#     {'id': 'sr:venue:82321',
#      'name': 'Court 1',
#      'city_name': 'Monza',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'}]},
#   {'id': 'sr:complex:82313',
#    'name': 'Carvoeiro Clube de Tenis',
#    'venues': [{'id': 'sr:venue:82327',
#      'name': 'Carvoeiro Clube de Tenis - 05. Court FredGil',
#      'city_name': 'Carvoeiro',
#      'country_name': 'Portugal',
#      'country_code': 'PRT',
#      'timezone': 'Europe/Lisbon'},
#     {'id': 'sr:venue:82329',
#      'name': 'Carvoeiro Clube de Tenis - 09. Court Lagoa',
#      'city_name': 'Carvoeiro',
#      'country_name': 'Portugal',
#      'country_code': 'PRT',
#      'timezone': 'Europe/Lisbon'},
#     {'id': 'sr:venue:82331',
#      'name': 'Carvoeiro Clube de Tenis - 04. Court Carvoeiro',
#      'city_name': 'Carvoeiro',
#      'country_name': 'Portugal',
#      'country_code': 'PRT',
#      'timezone': 'Europe/Lisbon'},
#     {'id': 'sr:venue:82333',
#      'name': 'Carvoeiro Clube de Tenis - 08. Court Details',
#      'city_name': 'Carvoeiro',
#      'country_name': 'Portugal',
#      'country_code': 'PRT',
#      'timezone': 'Europe/Lisbon'}]},
#   {'id': 'sr:complex:82335',
#    'name': 'Sarasota Sports Club',
#    'venues': [{'id': 'sr:venue:82337',
#      'name': 'Nick Bollettieri Court',
#      'city_name': 'Sarasota',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/New_York'},
#     {'id': 'sr:venue:82339',
#      'name': 'Court 14',
#      'city_name': 'Sarasota',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/New_York'},
#     {'id': 'sr:venue:82341',
#      'name': 'Court 7',
#      'city_name': 'Sarasota',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/New_York'}]},
#   {'id': 'sr:complex:82343',
#    'name': 'Le Central Tennis Club',
#    'venues': [{'id': 'sr:venue:82378',
#      'name': 'Court COFINA NEEMBA',
#      'city_name': 'Abidjan',
#      'country_name': 'Cote d’Ivoire',
#      'country_code': 'CIV',
#      'timezone': 'Africa/Abidjan'},
#     {'id': 'sr:venue:82380',
#      'name': 'Court CNPS',
#      'city_name': 'Abidjan',
#      'country_name': 'Cote d’Ivoire',
#      'country_code': 'CIV',
#      'timezone': 'Africa/Abidjan'},
#     {'id': 'sr:venue:82382',
#      'name': 'Central KAYDAN',
#      'city_name': 'Abidjan',
#      'country_name': 'Cote d’Ivoire',
#      'country_code': 'CIV',
#      'timezone': 'Africa/Abidjan'}]},
#   {'id': 'sr:complex:82356',
#    'name': 'Dan Maskell Tennis Centre',
#    'venues': [{'id': 'sr:venue:82386',
#      'name': 'Loughborough University - Court 07',
#      'city_name': 'Loughborough',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:82388',
#      'name': 'Loughborough University - Court 06',
#      'city_name': 'Loughborough',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:82390',
#      'name': 'Loughborough University - Court 08',
#      'city_name': 'Loughborough',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:82392',
#      'name': 'Loughborough University - Court 05',
#      'city_name': 'Loughborough',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'}]},
#   {'id': 'sr:complex:82415',
#    'name': 'George P Mitchell 40 Tennis Center',
#    'venues': [{'id': 'sr:venue:82445',
#      'name': 'Mitchell Tennis Center - Texas AM - Court 01',
#      'city_name': 'College Station, TX',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/Chicago'},
#     {'id': 'sr:venue:82447',
#      'name': 'Mitchell Tennis Center - Texas AM - Court 02',
#      'city_name': 'College Station, TX',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/Chicago'},
#     {'id': 'sr:venue:82449',
#      'name': 'Mitchell Tennis Center - Texas AM - Court 03',
#      'city_name': 'College Station, TX',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/Chicago'},
#     {'id': 'sr:venue:82451',
#      'name': 'Mitchell Tennis Center - Texas AM - Court 04',
#      'city_name': 'College Station, TX',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/Chicago'}]},
#   {'id': 'sr:complex:82417',
#    'name': 'National Tennis Center',
#    'venues': [{'id': 'sr:venue:82419',
#      'name': 'National Tennis Center - Outdoor - Court 1',
#      'city_name': 'Bucharest',
#      'country_name': 'Romania',
#      'country_code': 'ROU',
#      'timezone': 'Europe/Bucharest'},
#     {'id': 'sr:venue:82457',
#      'name': 'National Tennis Center - Outdoor - Court 2',
#      'city_name': 'Bucharest',
#      'country_name': 'Romania',
#      'country_code': 'ROU',
#      'timezone': 'Europe/Bucharest'},
#     {'id': 'sr:venue:82459',
#      'name': 'National Tennis Center - Outdoor - Court 3',
#      'city_name': 'Bucharest',
#      'country_name': 'Romania',
#      'country_code': 'ROU',
#      'timezone': 'Europe/Bucharest'},
#     {'id': 'sr:venue:82461',
#      'name': 'National Tennis Center - Outdoor - Court 7',
#      'city_name': 'Bucharest',
#      'country_name': 'Romania',
#      'country_code': 'ROU',
#      'timezone': 'Europe/Bucharest'},
#     {'id': 'sr:venue:82463',
#      'name': 'National Tennis Center - Outdoor - Court 8',
#      'city_name': 'Bucharest',
#      'country_name': 'Romania',
#      'country_code': 'ROU',
#      'timezone': 'Europe/Bucharest'},
#     {'id': 'sr:venue:82465',
#      'name': 'National Tennis Center - Outdoor - Court 9',
#      'city_name': 'Bucharest',
#      'country_name': 'Romania',
#      'country_code': 'ROU',
#      'timezone': 'Europe/Bucharest'},
#     {'id': 'sr:venue:82479',
#      'name': 'National Tennis Center - Outdoor - Court 06',
#      'city_name': 'Bucharest',
#      'country_name': 'Romania',
#      'country_code': 'ROU',
#      'timezone': 'Europe/Bucharest'}]},
#   {'id': 'sr:complex:82467',
#    'name': 'Tcja Saint-Malo',
#    'venues': [{'id': 'sr:venue:82487',
#      'name': 'Central',
#      'city_name': 'Saint Malo',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:82489',
#      'name': 'Court 1',
#      'city_name': 'Saint Malo',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:82495',
#      'name': 'Court 2',
#      'city_name': 'Saint Malo',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'}]},
#   {'id': 'sr:complex:82469',
#    'name': 'Club Tennis Vic',
#    'venues': [{'id': 'sr:venue:39565',
#      'name': 'Court 1',
#      'city_name': 'Vic',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:39567',
#      'name': 'Court 2',
#      'city_name': 'Vic',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:82497',
#      'name': 'Centre Court',
#      'city_name': 'Vic',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:82499',
#      'name': 'Court 3',
#      'city_name': 'Vic',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'}]}]}

# %% [markdown]
# Complexes Details:

# %%
complexes_list = []

for i in data["complexes"]:
    complexs_id = i.get("id")
    complexs_name = i.get("name")

    complexes_list.append({
    'complex_id' : complexs_id,
    'complex_name' : complexs_name
    })

complexes_list
# Out:
# [{'complex_id': 'sr:complex:705', 'complex_name': 'Nacional'},
#  {'complex_id': 'sr:complex:1078', 'complex_name': 'Estadio de la Cartuja'},
#  {'complex_id': 'sr:complex:1495', 'complex_name': 'Sibur Arena'},
#  {'complex_id': 'sr:complex:2375',
#   'complex_name': 'Complexo de Tenis do Jamor'},
#  {'complex_id': 'sr:complex:4032',
#   'complex_name': 'Shree Shiv Chhatrapati Sports Complex'},
#  {'complex_id': 'sr:complex:5520', 'complex_name': 'O2 Arena'},
#  {'complex_id': 'sr:complex:5526', 'complex_name': 'Ostravar Arena'},
#  {'complex_id': 'sr:complex:6310', 'complex_name': 'Varazdin Arena'},
#  {'complex_id': 'sr:complex:6484', 'complex_name': 'Arena Montpellier'},
#  {'complex_id': 'sr:complex:6736', 'complex_name': 'Arenes de Metz'},
#  {'complex_id': 'sr:complex:6888', 'complex_name': 'Palais des sports de Pau'},
#  {'complex_id': 'sr:complex:6890',
#   'complex_name': 'Palais des Sports Orleans'},
#  {'complex_id': 'sr:complex:6904',
#   'complex_name': 'Stade Pierre-de-Coubertin'},
#  {'complex_id': 'sr:complex:7048',
#   'complex_name': 'Palacio de Deportes Jose Maria Martin Carpena'},
#  {'complex_id': 'sr:complex:7052',
#   'complex_name': 'Pabellon Municipal Fuente San Luis'},
#  {'complex_id': 'sr:complex:7208', 'complex_name': 'Unipol Arena'},
#  {'complex_id': 'sr:complex:7778', 'complex_name': 'Arena Gripe'},
#  {'complex_id': 'sr:complex:9725', 'complex_name': 'Arena Armeets Sofia'},
#  {'complex_id': 'sr:complex:10063', 'complex_name': 'Kindarena'},
#  {'complex_id': 'sr:complex:11769', 'complex_name': 'Estadio German Becker'},
#  {'complex_id': 'sr:complex:12241',
#   'complex_name': 'Palais des sports de Gerland'},
#  {'complex_id': 'sr:complex:15014', 'complex_name': 'Palais Des Sport'},
#  {'complex_id': 'sr:complex:15371', 'complex_name': 'Palasport'},
#  {'complex_id': 'sr:complex:16020', 'complex_name': 'Salle Steredenn'},
#  {'complex_id': 'sr:complex:16069', 'complex_name': 'Garanti Koza Arena'},
#  {'complex_id': 'sr:complex:16612', 'complex_name': 'Porsche-Arena'},
#  {'complex_id': 'sr:complex:17254', 'complex_name': "Poliesportiu d'Andorra"},
#  {'complex_id': 'sr:complex:17945', 'complex_name': 'Rotterdam Ahoy'},
#  {'complex_id': 'sr:complex:18201', 'complex_name': 'The O2'},
#  {'complex_id': 'sr:complex:18221', 'complex_name': 'Bluesun Tennis Center'},
#  {'complex_id': 'sr:complex:19166', 'complex_name': 'Shlomo Group Arena'},
#  {'complex_id': 'sr:complex:19737',
#   'complex_name': 'Club Sonoma, Estadio Gnp Seguros'},
#  {'complex_id': 'sr:complex:19951', 'complex_name': 'Accor Arena'},
#  {'complex_id': 'sr:complex:21870',
#   'complex_name': 'Stadium Goran Ivanisevic in ITC Stella Maris'},
#  {'complex_id': 'sr:complex:21910', 'complex_name': 'Roy Emerson Arena'},
#  {'complex_id': 'sr:complex:26983',
#   'complex_name': 'Club de Tenis Puente Romano'},
#  {'complex_id': 'sr:complex:26985', 'complex_name': 'National Tennis Center'},
#  {'complex_id': 'sr:complex:27093', 'complex_name': 'Canberra Tennis Centre'},
#  {'complex_id': 'sr:complex:27095', 'complex_name': 'BT Arena'},
#  {'complex_id': 'sr:complex:28457', 'complex_name': 'Valletta Cambiaso ASD'},
#  {'complex_id': 'sr:complex:28617', 'complex_name': 'Porsche Arena'},
#  {'complex_id': 'sr:complex:28926', 'complex_name': 'Royal Arena'},
#  {'complex_id': 'sr:complex:32327', 'complex_name': 'Taipei Arena'},
#  {'complex_id': 'sr:complex:32403',
#   'complex_name': 'Ohio State University GC'},
#  {'complex_id': 'sr:complex:32668',
#   'complex_name': 'Shenzhen Bay Sports Center'},
#  {'complex_id': 'sr:complex:32812',
#   'complex_name': 'Singapore Indoor Stadium'},
#  {'complex_id': 'sr:complex:33186',
#   'complex_name': 'Palais des Sports de Marseille'},
#  {'complex_id': 'sr:complex:33188', 'complex_name': 'Caja Magica'},
#  {'complex_id': 'sr:complex:33190',
#   'complex_name': 'All England Lawn Tennis and Croquet Club'},
#  {'complex_id': 'sr:complex:33192', 'complex_name': 'Stade Roland Garros'},
#  {'complex_id': 'sr:complex:33194', 'complex_name': 'Complexe Al Amal'},
#  {'complex_id': 'sr:complex:33196', 'complex_name': 'Melbourne Park'},
#  {'complex_id': 'sr:complex:33198',
#   'complex_name': 'Qi zhong Forest Sports City Arena'},
#  {'complex_id': 'sr:complex:33200',
#   'complex_name': 'Wake Forest University Tennis Complex'},
#  {'complex_id': 'sr:complex:33204',
#   'complex_name': 'Clube de Ténis do Estoril'},
#  {'complex_id': 'sr:complex:33206', 'complex_name': 'The Drive'},
#  {'complex_id': 'sr:complex:33208', 'complex_name': 'Atlantic Station'},
#  {'complex_id': 'sr:complex:33210',
#   'complex_name': 'International Tennis Hall of Fame'},
#  {'complex_id': 'sr:complex:33214', 'complex_name': 'Club Jacaranda Cumbaya'},
#  {'complex_id': 'sr:complex:33218',
#   'complex_name': 'Hengqin International Tennis Center Zhuhai'},
#  {'complex_id': 'sr:complex:33222',
#   'complex_name': 'Buenos Aires Lawn Tennis Club'},
#  {'complex_id': 'sr:complex:33226',
#   'complex_name': 'The Racquet Club of Memphis'},
#  {'complex_id': 'sr:complex:33228',
#   'complex_name': 'Delray Beach Tennis Center'},
#  {'complex_id': 'sr:complex:33230',
#   'complex_name': 'CK Sportcenter Kockelscheuer'},
#  {'complex_id': 'sr:complex:33232', 'complex_name': 'Singapore Sports Hub'},
#  {'complex_id': 'sr:complex:33234', 'complex_name': 'Linzer Sporthalle'},
#  {'complex_id': 'sr:complex:33236',
#   'complex_name': 'Luzhniki Olympic Complex'},
#  {'complex_id': 'sr:complex:33238', 'complex_name': 'Ariake Colosseum'},
#  {'complex_id': 'sr:complex:33240',
#   'complex_name': 'Optics Valley International Tennis Center'},
#  {'complex_id': 'sr:complex:33242',
#   'complex_name': 'Guangzhou Tianhe Sports Center'},
#  {'complex_id': 'sr:complex:33244',
#   'complex_name': 'Olympic Park Tennis Center'},
#  {'complex_id': 'sr:complex:33246',
#   'complex_name': 'Victoria Park Tennis Court'},
#  {'complex_id': 'sr:complex:33248',
#   'complex_name': 'Tianjin Tuanbo International Tennis Center'},
#  {'complex_id': 'sr:complex:33250',
#   'complex_name': 'Tashkent Tennis Centreake'},
#  {'complex_id': 'sr:complex:33252',
#   'complex_name': 'China National Tennis Center'},
#  {'complex_id': 'sr:complex:33254', 'complex_name': 'Utsubo Tennis Center'},
#  {'complex_id': 'sr:complex:33258',
#   'complex_name': 'Connecticut Tennis Center'},
#  {'complex_id': 'sr:complex:33262',
#   'complex_name': 'Santa Catarina Tennis Federation'},
#  {'complex_id': 'sr:complex:33264', 'complex_name': 'Baku Tennis Academy'},
#  {'complex_id': 'sr:complex:33266', 'complex_name': 'Sobeys Stadium'},
#  {'complex_id': 'sr:complex:33268',
#   'complex_name': 'Lindner Family Tennis Center'},
#  {'complex_id': 'sr:complex:33270', 'complex_name': 'Taube Tennis Stadium'},
#  {'complex_id': 'sr:complex:33274',
#   'complex_name': 'Tennis Club de Strasbourg'},
#  {'complex_id': 'sr:complex:33276', 'complex_name': 'Edgbaston Priory Club'},
#  {'complex_id': 'sr:complex:33278',
#   'complex_name': 'Royal Tennis Club de Marrakech'},
#  {'complex_id': 'sr:complex:33280', 'complex_name': 'Tennis Club 1.FCN'},
#  {'complex_id': 'sr:complex:33282',
#   'complex_name': 'Devonshire Park International Tennis Centre'},
#  {'complex_id': 'sr:complex:33286',
#   'complex_name': 'Tennis Club Sparta Praha'},
#  {'complex_id': 'sr:complex:33288',
#   'complex_name': 'Club Campestre El Rancho'},
#  {'complex_id': 'sr:complex:33290',
#   'complex_name': 'Khalifa International Tennis & Squash Complex'},
#  {'complex_id': 'sr:complex:33292', 'complex_name': 'Club Sonoma'},
#  {'complex_id': 'sr:complex:33294',
#   'complex_name': 'Centre Municipal de Tennis Vall d Hebron'},
#  {'complex_id': 'sr:complex:33296', 'complex_name': 'Jockey Club Brasileiro'},
#  {'complex_id': 'sr:complex:33298',
#   'complex_name': 'Acapulco Princess Mundo Imperial'},
#  {'complex_id': 'sr:complex:33300',
#   'complex_name': 'Tennis Center at Crandon Park'},
#  {'complex_id': 'sr:complex:33302',
#   'complex_name': 'Family Circle Tennis Center'},
#  {'complex_id': 'sr:complex:33306',
#   'complex_name': 'Indian Wells Tennis Garden'},
#  {'complex_id': 'sr:complex:33310',
#   'complex_name': 'Aviation Club Tennis Centre'},
#  {'complex_id': 'sr:complex:33316',
#   'complex_name': 'Indianapolis Tennis Center'},
#  {'complex_id': 'sr:complex:33318', 'complex_name': 'SKT Sopot'},
#  {'complex_id': 'sr:complex:33320', 'complex_name': 'St. Jakobshalle Basel'},
#  {'complex_id': 'sr:complex:33322', 'complex_name': 'Wien, Wiener Stadthalle'},
#  {'complex_id': 'sr:complex:33324', 'complex_name': "L'Agora"},
#  {'complex_id': 'sr:complex:33328', 'complex_name': 'ASB Tennis Centre'},
#  {'complex_id': 'sr:complex:33332', 'complex_name': 'NSW Tennis Centre'},
#  {'complex_id': 'sr:complex:33334',
#   'complex_name': 'Shenzhen Longgang Sports Center'},
#  {'complex_id': 'sr:complex:33336',
#   'complex_name': 'Queensland Tennis Centre'},
#  {'complex_id': 'sr:complex:33338', 'complex_name': 'Am Rothenbaum'},
#  {'complex_id': 'sr:complex:33340', 'complex_name': 'Kungliga Tennishallen'},
#  {'complex_id': 'sr:complex:33342',
#   'complex_name': 'Kitzbuehel Tennis Club Sportfeld 2'},
#  {'complex_id': 'sr:complex:33344', 'complex_name': 'The Queens Club'},
#  {'complex_id': 'sr:complex:33346', 'complex_name': 'Gerry Weber Stadium'},
#  {'complex_id': 'sr:complex:33348',
#   'complex_name': 'Nottingham Tennis Centre'},
#  {'complex_id': 'sr:complex:33350', 'complex_name': 'Bastad Tennis Stadium'},
#  {'complex_id': 'sr:complex:33354', 'complex_name': 'Nice Lawn Tennis Club'},
#  {'complex_id': 'sr:complex:33356', 'complex_name': 'Tennis Club de Geneve'},
#  {'complex_id': 'sr:complex:33358',
#   'complex_name': 'Koza World of Sport Complex'},
#  {'complex_id': 'sr:complex:33362', 'complex_name': 'Tennis Club Weissenhof'},
#  {'complex_id': 'sr:complex:33364', 'complex_name': 'Autotron Rosmalen'},
#  {'complex_id': 'sr:complex:33366', 'complex_name': 'BNR arena'},
#  {'complex_id': 'sr:complex:33368', 'complex_name': 'MTTC Iphitos e.V.'},
#  {'complex_id': 'sr:complex:33372',
#   'complex_name': 'Real Club de Tenis Barcelona'},
#  {'complex_id': 'sr:complex:33374', 'complex_name': 'Hiroshima Regional Park'},
#  {'complex_id': 'sr:complex:33380', 'complex_name': 'Europe Tennis Center'},
#  {'complex_id': 'sr:complex:33382', 'complex_name': 'Tennis Club Lido Lugano'},
#  {'complex_id': 'sr:complex:33386', 'complex_name': 'Nemzeti Edzes Kozpont'},
#  {'complex_id': 'sr:complex:33390', 'complex_name': 'Lyon Tennis Club'},
#  {'complex_id': 'sr:complex:33392',
#   'complex_name': 'Sichuan International Tennis Center'},
#  {'complex_id': 'sr:complex:33394', 'complex_name': 'Swiss Tennis Arena'},
#  {'complex_id': 'sr:complex:33400',
#   'complex_name': 'Nanchang International Tennis Center'},
#  {'complex_id': 'sr:complex:33402', 'complex_name': 'Louisville Boat Club'},
#  {'complex_id': 'sr:complex:33406', 'complex_name': 'Rochusclub'},
#  {'complex_id': 'sr:complex:33408',
#   'complex_name': 'Shenzhen Luohu Tennis Centre'},
#  {'complex_id': 'sr:complex:33410', 'complex_name': 'Yang-Ming Tennis Centre'},
#  {'complex_id': 'sr:complex:33418',
#   'complex_name': 'Country Club Santa Ponsa'},
#  {'complex_id': 'sr:complex:33422',
#   'complex_name': 'Royal Primerose Tennis Club'},
#  {'complex_id': 'sr:complex:33424',
#   'complex_name': 'The Tennis Center at College Park'},
#  {'complex_id': 'sr:complex:33426', 'complex_name': 'Tennis Center Novak'},
#  {'complex_id': 'sr:complex:33428', 'complex_name': 'Farum Arena'},
#  {'complex_id': 'sr:complex:33430',
#   'complex_name': 'Racquet Club of the South'},
#  {'complex_id': 'sr:complex:33434', 'complex_name': 'Atlanta Athletic Club'},
#  {'complex_id': 'sr:complex:33436', 'complex_name': 'Madrid Arena'},
#  {'complex_id': 'sr:complex:33438',
#   'complex_name': 'Club Avantage Multi-Sports'},
#  {'complex_id': 'sr:complex:33440', 'complex_name': 'Rama Gardens Hotel'},
#  {'complex_id': 'sr:complex:33442',
#   'complex_name': 'Delmar International School'},
#  {'complex_id': 'sr:complex:33444',
#   'complex_name': 'OMNI LA COSTA RESORT & SPA'},
#  {'complex_id': 'sr:complex:33446', 'complex_name': 'Country Time Club'},
#  {'complex_id': 'sr:complex:33448', 'complex_name': 'ŠRC MARINA PORTOROŽ'},
#  {'complex_id': 'sr:complex:33450',
#   'complex_name': 'Fangcun Tennis Sports Center'},
#  {'complex_id': 'sr:complex:33454', 'complex_name': 'Netaji Indoor Stadium'},
#  {'complex_id': 'sr:complex:33456',
#   'complex_name': 'Holiday Inn Crowne Plaza Hotel Asheville'},
#  {'complex_id': 'sr:complex:33458',
#   'complex_name': "Ligue d'Alsace de Tennis"},
#  {'complex_id': 'sr:complex:33460',
#   'complex_name': 'I. Czech Lawn Tennis Club Praha'},
#  {'complex_id': 'sr:complex:33462', 'complex_name': 'Fes Country Club'},
#  {'complex_id': 'sr:complex:33466',
#   'complex_name': 'Warszawianka Tennis Centre'},
#  {'complex_id': 'sr:complex:33468', 'complex_name': 'LTTC Rot-Weiss'},
#  {'complex_id': 'sr:complex:33470',
#   'complex_name': 'Amelia Island Plantation Resort'},
#  {'complex_id': 'sr:complex:33472', 'complex_name': 'Romai Tennis Academy'},
#  {'complex_id': 'sr:complex:33474',
#   'complex_name': 'El Recinto Ferial Casa de Campo'},
#  {'complex_id': 'sr:complex:33476', 'complex_name': 'Impact Arena'},
#  {'complex_id': 'sr:complex:33478',
#   'complex_name': 'Tokyo Metropolitan Gymnasium'},
#  {'complex_id': 'sr:complex:33482',
#   'complex_name': 'Sporting Club de Tenis Valencia'},
#  {'complex_id': 'sr:complex:33484', 'complex_name': 'Pörtschach Werzer Arena'},
#  {'complex_id': 'sr:complex:33486',
#   'complex_name': 'Club Naval de Campo las Salinas'},
#  {'complex_id': 'sr:complex:33488', 'complex_name': 'Hilton DFW Lakes'},
#  {'complex_id': 'sr:complex:33490',
#   'complex_name': 'Sportingclub Bokkeduinen'},
#  {'complex_id': 'sr:complex:33492', 'complex_name': 'Baku Tennis Academy'},
#  {'complex_id': 'sr:complex:33808',
#   'complex_name': 'USTA Billie Jean King National Tennis Center'},
#  {'complex_id': 'sr:complex:34336', 'complex_name': 'Emirates Arena'},
#  {'complex_id': 'sr:complex:34586', 'complex_name': 'Lanxess Arena'},
#  {'complex_id': 'sr:complex:34736', 'complex_name': 'Tiburon Peninsula Club'},
#  {'complex_id': 'sr:complex:34766', 'complex_name': 'Country Club de Bogota'},
#  {'complex_id': 'sr:complex:34812', 'complex_name': 'Almaty Tennis Center'},
#  {'complex_id': 'sr:complex:34814',
#   'complex_name': 'Sociedade Hipica de Campinas'},
#  {'complex_id': 'sr:complex:34816',
#   'complex_name': 'Eve Zimmermann Tennis Center'},
#  {'complex_id': 'sr:complex:34896',
#   'complex_name': 'Circolo del Tennis Firenze 1898'},
#  {'complex_id': 'sr:complex:35048',
#   'complex_name': 'Sanchez-Casal Tennis Academy'},
#  {'complex_id': 'sr:complex:35052',
#   'complex_name': 'Santo Domingo Tennis Club La Bocha'},
#  {'complex_id': 'sr:complex:35054',
#   'complex_name': 'Solano Community College Tennis Center'},
#  {'complex_id': 'sr:complex:35142', 'complex_name': 'Lotto Arena'},
#  {'complex_id': 'sr:complex:35212', 'complex_name': 'TC Ismaning'},
#  {'complex_id': 'sr:complex:35214',
#   'complex_name': 'Osten & Victor Alberta Tennis Centre'},
#  {'complex_id': 'sr:complex:35236',
#   'complex_name': 'Ningbo Tennis Center of WTA Ningbo, China w42'},
#  {'complex_id': 'sr:complex:35290',
#   'complex_name': 'Club Tennis Las Terrazas de Miraflores'},
#  {'complex_id': 'sr:complex:35292', 'complex_name': 'Liuzhou Tennis Center'},
#  {'complex_id': 'sr:complex:35458',
#   'complex_name': 'Shree Shiv Chhatrapati Sports Complex'},
#  {'complex_id': 'sr:complex:35512',
#   'complex_name': "The Boar's Head Sports Club"},
#  {'complex_id': 'sr:complex:35516',
#   'complex_name': 'Anexo Guayaquil Tenis Club'},
#  {'complex_id': 'sr:complex:35580', 'complex_name': 'Uber Arena'},
#  {'complex_id': 'sr:complex:35592', 'complex_name': 'Sporting Milano 3'},
#  {'complex_id': 'sr:complex:35638', 'complex_name': 'Fiera Milano stadium'},
#  {'complex_id': 'sr:complex:35640', 'complex_name': 'AXA Arena NTC'},
#  {'complex_id': 'sr:complex:35642', 'complex_name': 'Vendéspace'},
#  {'complex_id': 'sr:complex:35644',
#   'complex_name': 'Carrasco Lawn Tennis Club'},
#  {'complex_id': 'sr:complex:35646',
#   'complex_name': 'Goodfriend Indoor Tennis Center'},
#  {'complex_id': 'sr:complex:35648',
#   'complex_name': 'Palais des sports de Beaublanc'},
#  {'complex_id': 'sr:complex:35684',
#   'complex_name': 'Miki Disaster Management Park'},
#  {'complex_id': 'sr:complex:35688',
#   'complex_name': 'Karnataka State Lawn Tennis Association'},
#  {'complex_id': 'sr:complex:35690', 'complex_name': 'Racket Club, Argentina'},
#  {'complex_id': 'sr:complex:35692', 'complex_name': 'Atkins Tennis Center'},
#  {'complex_id': 'sr:complex:35694',
#   'complex_name': 'Rice Stadium (Brian Patterson Sports Performance Center)'},
#  {'complex_id': 'sr:complex:35870',
#   'complex_name': 'Mhalunge Balewadi Tennis Complex'},
#  {'complex_id': 'sr:complex:35902', 'complex_name': 'Palazzetto dello Sport'},
#  {'complex_id': 'sr:complex:36493', 'complex_name': 'ASB Tennis Arena'},
#  {'complex_id': 'sr:complex:36495', 'complex_name': 'Domain Tennis Centre'},
#  {'complex_id': 'sr:complex:36497',
#   'complex_name': 'Ohio State Varsity Tennis Center'},
#  {'complex_id': 'sr:complex:36573', 'complex_name': 'EPG Arena'},
#  {'complex_id': 'sr:complex:36783',
#   'complex_name': 'Newport Beach Tennis Club'},
#  {'complex_id': 'sr:complex:36785', 'complex_name': 'Burnie Tennis Club'},
#  {'complex_id': 'sr:complex:36787', 'complex_name': 'Cantegril Country Club'},
#  {'complex_id': 'sr:complex:37001', 'complex_name': 'Francoise Savatier'},
#  {'complex_id': 'sr:complex:37003', 'complex_name': 'Francoise Savatier'},
#  {'complex_id': 'sr:complex:37007', 'complex_name': 'Salle Collete-Benson'},
#  {'complex_id': 'sr:complex:38029', 'complex_name': 'True Arena Hua Hin'},
#  {'complex_id': 'sr:complex:38041',
#   'complex_name': 'Launceston Regional Tennis Centre'},
#  {'complex_id': 'sr:complex:38043', 'complex_name': 'True Arena Hua Hin'},
#  {'complex_id': 'sr:complex:38045',
#   'complex_name': 'Parc des Expositions Quimper Cornouaille'},
#  {'complex_id': 'sr:complex:38047', 'complex_name': 'Cleveland Racquet Club'},
#  {'complex_id': 'sr:complex:38187', 'complex_name': 'Sud de France Arena'},
#  {'complex_id': 'sr:complex:38189',
#   'complex_name': 'Estadio Mario Alberto Kempes'},
#  {'complex_id': 'sr:complex:38191', 'complex_name': 'T Bar M Racquet Club'},
#  {'complex_id': 'sr:complex:38193',
#   'complex_name': 'SYMA Sports and Conference Centre'},
#  {'complex_id': 'sr:complex:38195', 'complex_name': 'SDAT Tennis Stadium'},
#  {'complex_id': 'sr:complex:38277',
#   'complex_name': 'Club Campestre Sede Llanogrande'},
#  {'complex_id': 'sr:complex:38285',
#   'complex_name': 'Complexe Sportif Chantereyne'},
#  {'complex_id': 'sr:complex:38313',
#   'complex_name': 'Dubai Duty Free Tennis Stadium'},
#  {'complex_id': 'sr:complex:38315',
#   'complex_name': 'Hotel Racquet Cuernavaca'},
#  {'complex_id': 'sr:complex:38419',
#   'complex_name': 'Indian Wells Tennis Garden'},
#  {'complex_id': 'sr:complex:38421',
#   'complex_name': 'Mamushidani Tennis Courts, Keio University'},
#  {'complex_id': 'sr:complex:38451',
#   'complex_name': 'Palais des Sports de Pau'},
#  {'complex_id': 'sr:complex:38483', 'complex_name': 'Manquehue Sports Club'},
#  {'complex_id': 'sr:complex:38603',
#   'complex_name': 'Shenzhen International Tennis Center'},
#  {'complex_id': 'sr:complex:38625',
#   'complex_name': 'The Phoenix Country Club'},
#  {'complex_id': 'sr:complex:38631',
#   'complex_name': 'The Phoenix Country Club'},
#  {'complex_id': 'sr:complex:38678', 'complex_name': 'Hard Rock Stadium'},
#  {'complex_id': 'sr:complex:38680',
#   'complex_name': 'Centro Panamericano de Tenis'},
#  {'complex_id': 'sr:complex:38684', 'complex_name': 'Club Los Lagartos'},
#  {'complex_id': 'sr:complex:38690', 'complex_name': 'TK Sparta Praha'},
#  {'complex_id': 'sr:complex:38692',
#   'complex_name': 'Hot Springs Tennis Center'},
#  {'complex_id': 'sr:complex:38694', 'complex_name': 'Club des Cheminots'},
#  {'complex_id': 'sr:complex:38698', 'complex_name': 'La Caja Magica'},
#  {'complex_id': 'sr:complex:38702', 'complex_name': 'Tennis Club Kastela'},
#  {'complex_id': 'sr:complex:38704', 'complex_name': 'River Oaks Country Club'},
#  {'complex_id': 'sr:complex:38712', 'complex_name': 'National Tennis Center'},
#  {'complex_id': 'sr:complex:38716',
#   'complex_name': 'Clube de Ténis do Estoril'},
#  {'complex_id': 'sr:complex:38720', 'complex_name': "Parc De La TeTe D'or"},
#  {'complex_id': 'sr:complex:38722',
#   'complex_name': 'TC Weissenhof, Stuttgart'},
#  {'complex_id': 'sr:complex:38732',
#   'complex_name': 'Tennis Club Lillois Lille Metropole'},
#  {'complex_id': 'sr:complex:38856',
#   'complex_name': 'Sala Polivalenta Piatra Neamt'},
#  {'complex_id': 'sr:complex:38858',
#   'complex_name': 'The National Tennis Development Center'},
#  {'complex_id': 'sr:complex:38862',
#   'complex_name': 'Complejo Polideportivo de Cuidad Merliot'},
#  {'complex_id': 'sr:complex:38882',
#   'complex_name': 'JC Ferrero Equelite Sport Academy'},
#  {'complex_id': 'sr:complex:38884',
#   'complex_name': 'Mouratoglou Tennis Academy'},
#  {'complex_id': 'sr:complex:38986',
#   'complex_name': 'National Taiwan University Sports Center'},
#  {'complex_id': 'sr:complex:38988', 'complex_name': 'Circolo Tennis Barletta'},
#  {'complex_id': 'sr:complex:38990', 'complex_name': 'Murcia Tennis Club 1919'},
#  {'complex_id': 'sr:complex:39000', 'complex_name': 'El Club el Carmel'},
#  {'complex_id': 'sr:complex:39093', 'complex_name': 'Laurel Oak Country Club'},
#  {'complex_id': 'sr:complex:39095', 'complex_name': 'Club Deportivo Potosino'},
#  {'complex_id': 'sr:complex:39097', 'complex_name': 'Au Tennis Club De Tunis'},
#  {'complex_id': 'sr:complex:39167', 'complex_name': 'Tali Tennis Center'},
#  {'complex_id': 'sr:complex:39377',
#   'complex_name': 'Jinwol International Tennis Court'},
#  {'complex_id': 'sr:complex:39379', 'complex_name': 'Tennis Club Dinamo'},
#  {'complex_id': 'sr:complex:39381',
#   'complex_name': 'Tennisclub Heilbronn am Trappensee'},
#  {'complex_id': 'sr:complex:39383',
#   'complex_name': 'Club Internacional de Foot-ball'},
#  {'complex_id': 'sr:complex:39483', 'complex_name': 'Israel Tennis Center'},
#  {'complex_id': 'sr:complex:39491', 'complex_name': "The Queen's Club"},
#  {'complex_id': 'sr:complex:39493', 'complex_name': 'Kaya Palazzo Belek'},
#  {'complex_id': 'sr:complex:39503',
#   'complex_name': 'Fitzerald Tennis Center Rock Creek Park'},
#  {'complex_id': 'sr:complex:39505',
#   'complex_name': 'Delmar International School'},
#  {'complex_id': 'sr:complex:39507',
#   'complex_name': 'Tennis Club du Stade-Lausanne'},
#  {'complex_id': 'sr:complex:39509',
#   'complex_name': 'National Tennis Centre Lielupe'},
#  {'complex_id': 'sr:complex:39511', 'complex_name': 'TC Rüppurr'},
#  {'complex_id': 'sr:complex:39513',
#   'complex_name': 'San José State University Tennis Center'},
#  {'complex_id': 'sr:complex:39515', 'complex_name': 'Stade Iga'},
#  {'complex_id': 'sr:complex:39591', 'complex_name': 'Tennis Palladio 98'},
#  {'complex_id': 'sr:complex:39653', 'complex_name': 'Palexpo'},
#  {'complex_id': 'sr:complex:39852',
#   'complex_name': 'Club de Campo Villa de Madrid'},
#  {'complex_id': 'sr:complex:39864', 'complex_name': 'Istiklol Tennis Club'},
#  {'complex_id': 'sr:complex:39866', 'complex_name': 'AAJB Tennis'},
#  {'complex_id': 'sr:complex:39868', 'complex_name': 'Tenis Club Parma'},
#  {'complex_id': 'sr:complex:39870',
#   'complex_name': 'Ilkley Lawn Tennis and Squash Club'},
#  {'complex_id': 'sr:complex:39872', 'complex_name': 'NTC Arena'},
#  {'complex_id': 'sr:complex:39958', 'complex_name': 'RT Torax Arena'},
#  {'complex_id': 'sr:complex:40110', 'complex_name': 'Aspria Harbor Club'},
#  {'complex_id': 'sr:complex:40788',
#   'complex_name': 'Francesco Guzzini Recanati Tennis Club'},
#  {'complex_id': 'sr:complex:44124',
#   'complex_name': 'Cary Leeds Center for Tennis & Learning'},
#  {'complex_id': 'sr:complex:44126',
#   'complex_name': 'National Sport Center Nanchang'},
#  {'complex_id': 'sr:complex:44128',
#   'complex_name': 'Center Plains Tennis Center'},
#  {'complex_id': 'sr:complex:44130', 'complex_name': 'Les Arenes de Metz'},
#  {'complex_id': 'sr:complex:44516',
#   'complex_name': 'Ariake Tennis Forest Park Ariake Colesseum'},
#  {'complex_id': 'sr:complex:44518', 'complex_name': 'Qi Zhong Tennis Center'},
#  {'complex_id': 'sr:complex:44520', 'complex_name': 'Olympic Tennis Courts'},
#  {'complex_id': 'sr:complex:44522', 'complex_name': 'Olympic Tennis School'},
#  {'complex_id': 'sr:complex:44640', 'complex_name': 'Eurosporting Cordenons'},
#  {'complex_id': 'sr:complex:46448', 'complex_name': 'Hakons Hall'},
#  {'complex_id': 'sr:complex:46526', 'complex_name': 'National Tennis Center'},
#  {'complex_id': 'sr:complex:46550', 'complex_name': 'Palais des Sports'},
#  {'complex_id': 'sr:complex:46552',
#   'complex_name': 'Circolo del Tennis Firenze 1898'},
#  {'complex_id': 'sr:complex:47140', 'complex_name': 'Tips Arena Linz'},
#  {'complex_id': 'sr:complex:47146',
#   'complex_name': 'Solano Community College'},
#  {'complex_id': 'sr:complex:47302', 'complex_name': 'Ice Palace Krylatskoye'},
#  {'complex_id': 'sr:complex:47306', 'complex_name': 'Sportpark Ismaning'},
#  {'complex_id': 'sr:complex:47476', 'complex_name': 'DTB-Stutzpunkt'},
#  {'complex_id': 'sr:complex:47815',
#   'complex_name': 'Playford City Tennis Centre'},
#  {'complex_id': 'sr:complex:47817', 'complex_name': 'House of Sports'},
#  {'complex_id': 'sr:complex:47819', 'complex_name': 'Guayaquil Tennis Club'},
#  {'complex_id': 'sr:complex:47893', 'complex_name': 'Palalido Allianz Cloud'},
#  {'complex_id': 'sr:complex:48779',
#   'complex_name': 'Tennis Center, Roncaddizza'},
#  {'complex_id': 'sr:complex:48857',
#   'complex_name': 'Complexo Municipal de Tenis da Maia'},
#  {'complex_id': 'sr:complex:49319', 'complex_name': 'Stan Sheriff Center'},
#  {'complex_id': 'sr:complex:49633', 'complex_name': 'Bendigo Tennis Centre'},
#  {'complex_id': 'sr:complex:49635',
#   'complex_name': 'Complexe Tennistique Marie-Louise Lhuillier'},
#  {'complex_id': 'sr:complex:49637',
#   'complex_name': 'University of Michigan Varsity Tennis Center'},
#  {'complex_id': 'sr:complex:49803',
#   'complex_name': 'Kooyong Lawn Tennis Club'},
#  {'complex_id': 'sr:complex:50605',
#   'complex_name': 'Club Deportivo Universidad Catolica'},
#  {'complex_id': 'sr:complex:50973', 'complex_name': 'Tennis Club Cagliari'},
#  {'complex_id': 'sr:complex:51589',
#   'complex_name': 'Palais Des Sports De Gerland'},
#  {'complex_id': 'sr:complex:51745', 'complex_name': 'Pakistan Sports Complex'},
#  {'complex_id': 'sr:complex:51757',
#   'complex_name': 'Club de Tenis Santa Cruz'},
#  {'complex_id': 'sr:complex:51761',
#   'complex_name': 'Club Megasaray Tennis Centre'},
#  {'complex_id': 'sr:complex:51775',
#   'complex_name': 'Automobile and Touring Club of Lebanon'},
#  {'complex_id': 'sr:complex:51779',
#   'complex_name': 'Club Lawn Tennis de la Exposicion'},
#  {'complex_id': 'sr:complex:51783', 'complex_name': 'Oslo Tennis Arena'},
#  {'complex_id': 'sr:complex:51785', 'complex_name': 'Siauliai Tennis Academy'},
#  {'complex_id': 'sr:complex:51791',
#   'complex_name': 'Club Internacional de Tenis'},
#  {'complex_id': 'sr:complex:51795',
#   'complex_name': 'Federacion Nacional De Tenis'},
#  {'complex_id': 'sr:complex:51797', 'complex_name': 'Costa Rica Country Club'},
#  {'complex_id': 'sr:complex:51805',
#   'complex_name': 'Alex Metreveli Tennis Club'},
#  {'complex_id': 'sr:complex:52275', 'complex_name': 'TK As Timok'},
#  {'complex_id': 'sr:complex:52289', 'complex_name': 'TK Magnet'},
#  {'complex_id': 'sr:complex:52527', 'complex_name': 'COMUNIDAD VALENCIANA'},
#  {'complex_id': 'sr:complex:52537',
#   'complex_name': 'Sparta Prague Tennis Complex'},
#  {'complex_id': 'sr:complex:52559', 'complex_name': 'National Tennis Centre'},
#  {'complex_id': 'sr:complex:52665', 'complex_name': 'TOP SEED TENNIS CLUB'},
#  {'complex_id': 'sr:complex:53263',
#   'complex_name': 'Henan Provincial Sports Centre Stadium'},
#  {'complex_id': 'sr:complex:53979', 'complex_name': 'TC Bad Homburg'},
#  {'complex_id': 'sr:complex:54105', 'complex_name': 'Foro Italico'},
#  {'complex_id': 'sr:complex:55029', 'complex_name': 'Forte Village Resort'},
#  {'complex_id': 'sr:complex:56886',
#   'complex_name': 'Limak Arcadia Sport Resort'},
#  {'complex_id': 'sr:complex:56888',
#   'complex_name': 'Zayed Sports City International Tennis Centre'},
#  {'complex_id': 'sr:complex:57152',
#   'complex_name': 'North-West University Tennis Complex'},
#  {'complex_id': 'sr:complex:57154', 'complex_name': 'Circolo Tennis I Faggi'},
#  {'complex_id': 'sr:complex:57188',
#   'complex_name': 'Club De Campo Bellavista'},
#  {'complex_id': 'sr:complex:57248', 'complex_name': 'OCBC Arena'},
#  {'complex_id': 'sr:complex:57286', 'complex_name': 'Halle Tony Garnier'},
#  {'complex_id': 'sr:complex:57308', 'complex_name': 'Formula Tennisa Lakhta'},
#  {'complex_id': 'sr:complex:57582', 'complex_name': 'Palasport Biella'},
#  {'complex_id': 'sr:complex:57924', 'complex_name': 'Hala Na Skarpie'},
#  {'complex_id': 'sr:complex:57926', 'complex_name': 'National Tennis Centre'},
#  {'complex_id': 'sr:complex:57928', 'complex_name': 'Elite Tennis Club'},
#  {'complex_id': 'sr:complex:57930',
#   'complex_name': 'Cordoba Lawn Tennis Club'},
#  {'complex_id': 'sr:complex:57950', 'complex_name': 'Istanbul Tennis Center'},
#  {'complex_id': 'sr:complex:58380', 'complex_name': 'Tenis Centar Maksimir'},
#  {'complex_id': 'sr:complex:58572', 'complex_name': 'President Tennis Club'},
#  {'complex_id': 'sr:complex:58652', 'complex_name': 'Rebsamen Tennis Center'},
#  {'complex_id': 'sr:complex:58874',
#   'complex_name': 'Complexo Tenis Monte Aventino'},
#  {'complex_id': 'sr:complex:58972', 'complex_name': 'Tennis Club Perugia'},
#  {'complex_id': 'sr:complex:59004', 'complex_name': 'TC GM Sports Anif'},
#  {'complex_id': 'sr:complex:59008',
#   'complex_name': 'Braunschweiger Tennis und Hockeyclub'},
#  {'complex_id': 'sr:complex:59082', 'complex_name': 'Ciric Sport Base'},
#  {'complex_id': 'sr:complex:59090',
#   'complex_name': 'Amersfoort Lawn Tennis Club'},
#  {'complex_id': 'sr:complex:59096', 'complex_name': 'Tennis Club Todi 1971'},
#  {'complex_id': 'sr:complex:59204', 'complex_name': 'Arka Tennis Club'},
#  {'complex_id': 'sr:complex:59212', 'complex_name': 'Cabo Sports Complex'},
#  {'complex_id': 'sr:complex:59214',
#   'complex_name': 'ATP Stadion Goran Ivanisevic'},
#  {'complex_id': 'sr:complex:59292', 'complex_name': 'Cary Tennis Park'},
#  {'complex_id': 'sr:complex:59332', 'complex_name': 'Tennis Club Triestino'},
#  {'complex_id': 'sr:complex:59334', 'complex_name': 'Tennis Club Triestino'},
#  {'complex_id': 'sr:complex:59348',
#   'complex_name': 'LTP Tennis Mount Pleasant'},
#  {'complex_id': 'sr:complex:59464', 'complex_name': 'The Thoreau Club'},
#  {'complex_id': 'sr:complex:59466',
#   'complex_name': 'San Jose State University Tennis Center'},
#  {'complex_id': 'sr:complex:59468', 'complex_name': 'Winners Sports Club'},
#  {'complex_id': 'sr:complex:59544', 'complex_name': 'Liberec Tennis Club'},
#  {'complex_id': 'sr:complex:59730',
#   'complex_name': 'Centro Tennis Cassa di Risparmio'},
#  {'complex_id': 'sr:complex:59754',
#   'complex_name': 'Associazione Tennis Verona'},
#  {'complex_id': 'sr:complex:59774', 'complex_name': 'LTV 1899'},
#  {'complex_id': 'sr:complex:59868', 'complex_name': 'XS Tennis Village'},
#  {'complex_id': 'sr:complex:59890',
#   'complex_name': 'Jacobs Pavilion at Nautica'},
#  {'complex_id': 'sr:complex:59994', 'complex_name': 'Legia Tenis & Golf'},
#  {'complex_id': 'sr:complex:60188',
#   'complex_name': 'Tennis Club Ruppurr 1929 e. V.'},
#  {'complex_id': 'sr:complex:60190', 'complex_name': 'Park Mladen Stojanovic'},
#  {'complex_id': 'sr:complex:60192',
#   'complex_name': 'Tennis Sporting Club de Cassis Les Gorguettes'},
#  {'complex_id': 'sr:complex:60194',
#   'complex_name': 'Tennis Club "Tennispark"'},
#  {'complex_id': 'sr:complex:60196',
#   'complex_name': 'Real Club de Tenis Betis'},
#  {'complex_id': 'sr:complex:60198', 'complex_name': 'Tennis Club Tulln'},
#  {'complex_id': 'sr:complex:60272',
#   'complex_name': 'TED Tenis Eskrim Dagcilik Spor Kulubu'},
#  {'complex_id': 'sr:complex:60274',
#   'complex_name': 'Club Rancho San Francisco'},
#  {'complex_id': 'sr:complex:60276', 'complex_name': 'Wojska Polskiego'},
#  {'complex_id': 'sr:complex:60350', 'complex_name': 'Le Liberte'},
#  {'complex_id': 'sr:complex:60384', 'complex_name': 'Rakiura Resort'},
#  {'complex_id': 'sr:complex:60386', 'complex_name': 'Jan Group Arena'},
#  {'complex_id': 'sr:complex:60388', 'complex_name': 'Lyttos Sportscenter'},
#  {'complex_id': 'sr:complex:60390', 'complex_name': 'Tennis Centre Portoroz'},
#  {'complex_id': 'sr:complex:60396', 'complex_name': 'National Tennis Centre'},
#  {'complex_id': 'sr:complex:60416',
#   'complex_name': 'Centrul National de Tenis'},
#  {'complex_id': 'sr:complex:60418', 'complex_name': 'Clube de Tenis de Braga'},
#  {'complex_id': 'sr:complex:60420', 'complex_name': 'Club Tungurahua'},
#  {'complex_id': 'sr:complex:60538', 'complex_name': 'Tennis Club Pamira'},
#  {'complex_id': 'sr:complex:60540', 'complex_name': 'Barnes Tennis Center'},
#  {'complex_id': 'sr:complex:60640', 'complex_name': 'Tennis Club Napoli'},
#  {'complex_id': 'sr:complex:60678',
#   'complex_name': 'Club de Polo y Equitacion San Cristobal'},
#  {'complex_id': 'sr:complex:60860', 'complex_name': 'Sporting Poseidon'},
#  {'complex_id': 'sr:complex:61026', 'complex_name': 'Abama Tennis Academy'},
#  {'complex_id': 'sr:complex:61028', 'complex_name': 'Ljubicic Tennis Academy'},
#  {'complex_id': 'sr:complex:61333', 'complex_name': 'PalaNorda'},
#  {'complex_id': 'sr:complex:61339',
#   'complex_name': 'Greater Midland Tennis Center'},
#  {'complex_id': 'sr:complex:61425', 'complex_name': 'Le Scarabee'},
#  {'complex_id': 'sr:complex:61437', 'complex_name': 'Pala Alpitour'},
#  {'complex_id': 'sr:complex:61551', 'complex_name': 'Iate Club de Brasilia'},
#  {'complex_id': 'sr:complex:61553',
#   'complex_name': 'Public Security Officers Club'},
#  {'complex_id': 'sr:complex:61555',
#   'complex_name': 'New Country Tennis Academy'},
#  {'complex_id': 'sr:complex:61565', 'complex_name': 'Parque Parota'},
#  {'complex_id': 'sr:complex:61641',
#   'complex_name': 'Circolo Tennis Villa Carpena'},
#  {'complex_id': 'sr:complex:61643',
#   'complex_name': 'Clube Hipico Santo Amaro'},
#  {'complex_id': 'sr:complex:61645',
#   'complex_name': 'Megasaray Tennis Academy'},
#  {'complex_id': 'sr:complex:61707', 'complex_name': 'Arena Loire Trelaze'},
#  {'complex_id': 'sr:complex:61737',
#   'complex_name': 'Parque Olimpico do Rio de Janeiro'},
#  {'complex_id': 'sr:complex:61761',
#   'complex_name': 'Seoul Olympic Park Tennis Center'},
#  {'complex_id': 'sr:complex:62147',
#   'complex_name': 'Styslinger Altec Tennis Complex'},
#  {'complex_id': 'sr:complex:62319', 'complex_name': 'Multisport Sports Club'},
#  {'complex_id': 'sr:complex:62321',
#   'complex_name': 'Tennis Academy El Cortijo Club De Campo'},
#  {'complex_id': 'sr:complex:62323',
#   'complex_name': 'Circolo Della Stampa Sporting'},
#  {'complex_id': 'sr:complex:62391', 'complex_name': 'Delhi Gymkhana Club'},
#  {'complex_id': 'sr:complex:62393', 'complex_name': 'Rixos Premium Belek'},
#  {'complex_id': 'sr:complex:62397',
#   'complex_name': 'Toto Hakriya Ashdod Arena'},
#  {'complex_id': 'sr:complex:62401',
#   'complex_name': 'The Lawn Tennis Association of Thailand'},
#  {'complex_id': 'sr:complex:62403', 'complex_name': 'Forus Tenniscenter'},
#  {'complex_id': 'sr:complex:62407', 'complex_name': 'Ace Tennis Club'},
#  {'complex_id': 'sr:complex:62409', 'complex_name': 'Tennis Club Roseto'},
#  {'complex_id': 'sr:complex:62419',
#   'complex_name': 'Club Manquehue de Vitacura'},
#  {'complex_id': 'sr:complex:62595',
#   'complex_name': 'Club Campestre de Pereira'},
#  {'complex_id': 'sr:complex:62617', 'complex_name': 'Padiglione Conza'},
#  {'complex_id': 'sr:complex:62619',
#   'complex_name': 'Tennis Club Saint-Brieuc'},
#  {'complex_id': 'sr:complex:62811',
#   'complex_name': 'Centro Deportivo Chapultepec'},
#  {'complex_id': 'sr:complex:62823',
#   'complex_name': 'Salinas Golf & Tennis Club'},
#  {'complex_id': 'sr:complex:62847', 'complex_name': 'Tennis Sanremo'},
#  {'complex_id': 'sr:complex:62903',
#   'complex_name': 'Monte-Carlo Country Club'},
#  {'complex_id': 'sr:complex:62905',
#   'complex_name': 'Payne Park Tennis Facility'},
#  {'complex_id': 'sr:complex:62907',
#   'complex_name': 'Circolo Tennis Hugo Simmen'},
#  {'complex_id': 'sr:complex:63005', 'complex_name': 'Adani Arena Rockhampton'},
#  {'complex_id': 'sr:complex:63033',
#   'complex_name': 'Club Campestre de Aguacalientes A.C.C.'},
#  {'complex_id': 'sr:complex:63055', 'complex_name': 'Teniski Klub Split'},
#  {'complex_id': 'sr:complex:63057',
#   'complex_name': 'Forestmeadows Tennis Center'},
#  {'complex_id': 'sr:complex:63059',
#   'complex_name': 'TTF Istanbul Tenis Merkezi'},
#  {'complex_id': 'sr:complex:63245', 'complex_name': 'SC Ostrava'},
#  {'complex_id': 'sr:complex:63247', 'complex_name': 'Tennis Club Garden'},
#  {'complex_id': 'sr:complex:63249',
#   'complex_name': 'Franklin Creek Tennis Center'},
#  {'complex_id': 'sr:complex:63309',
#   'complex_name': 'Parc ded Sports de Marville'},
#  {'complex_id': 'sr:complex:63311',
#   'complex_name': 'Danubis Tenniscenter Mauthausen'},
#  {'complex_id': 'sr:complex:63321', 'complex_name': 'Country Club Aixois'},
#  {'complex_id': 'sr:complex:63323', 'complex_name': 'Costa Verde Tenis Clube'},
#  {'complex_id': 'sr:complex:63407', 'complex_name': 'Villa Primrose'},
#  {'complex_id': 'sr:complex:63409', 'complex_name': 'Club de Tenis Coquimbo'},
#  {'complex_id': 'sr:complex:63427', 'complex_name': 'National Tennis Center'},
#  {'complex_id': 'sr:complex:63429',
#   'complex_name': 'Lagardere Paris Racing Club'},
#  {'complex_id': 'sr:complex:63527',
#   'complex_name': 'Circolo Tennis Francavilla al Mare Sporting Club'},
#  {'complex_id': 'sr:complex:63649', 'complex_name': 'TC RW-Troisdorf e.V'},
#  {'complex_id': 'sr:complex:63833', 'complex_name': 'TK Slovan Bratislava'},
#  {'complex_id': 'sr:complex:63835', 'complex_name': 'USTA National Campus'},
#  {'complex_id': 'sr:complex:63907', 'complex_name': 'Tenisovy Klub Prostejov'},
#  {'complex_id': 'sr:complex:63933', 'complex_name': 'OWL Arena'},
#  {'complex_id': 'sr:complex:63935', 'complex_name': 'The Queen’s Club'},
#  {'complex_id': 'sr:complex:63937',
#   'complex_name': 'CTC Corrientes Tennis Club'},
#  {'complex_id': 'sr:complex:63941', 'complex_name': 'Steffi-Graf Stadium'},
#  {'complex_id': 'sr:complex:63943',
#   'complex_name': 'Tennis Club Gaiba - Gaibledon'},
#  {'complex_id': 'sr:complex:64051', 'complex_name': 'Tenis Club Argentino'},
#  {'complex_id': 'sr:complex:64265',
#   'complex_name': 'AELTC Wimbledon Qualifying and Community Sports Ground'},
#  {'complex_id': 'sr:complex:64369', 'complex_name': 'Inacua Malaga'},
#  {'complex_id': 'sr:complex:64379', 'complex_name': 'Tennis Club de Troyes'},
#  {'complex_id': 'sr:complex:64571', 'complex_name': 'Salzburg Tennis Club'},
#  {'complex_id': 'sr:complex:64573',
#   'complex_name': 'Contrexeville Tennis Club'},
#  {'complex_id': 'sr:complex:64751', 'complex_name': 'Rome Tennis Center'},
#  {'complex_id': 'sr:complex:64869', 'complex_name': 'Am Rothenbaum'},
#  {'complex_id': 'sr:complex:64871',
#   'complex_name': 'Pearson Automotive Tennis Club'},
#  {'complex_id': 'sr:complex:64883',
#   'complex_name': 'C.D. Open Tenis Ciudad de Pozoblanco'},
#  {'complex_id': 'sr:complex:64885',
#   'complex_name': 'Tampereen Tenniskeskus Oy'},
#  {'complex_id': 'sr:complex:65099', 'complex_name': 'Circolo Tennis Maggioni'},
#  {'complex_id': 'sr:complex:65103',
#   'complex_name': 'Winnipeg Lawn Tennis Club'},
#  {'complex_id': 'sr:complex:65105', 'complex_name': 'Tennisclub Zug'},
#  {'complex_id': 'sr:complex:65205',
#   'complex_name': 'Hilary J. Boone Tennis Center'},
#  {'complex_id': 'sr:complex:65215', 'complex_name': 'Baza Sportiva Ciric'},
#  {'complex_id': 'sr:complex:65347', 'complex_name': 'Jockey Club del Peru'},
#  {'complex_id': 'sr:complex:65435', 'complex_name': 'Hollyburn Country Club'},
#  {'complex_id': 'sr:complex:65437',
#   'complex_name': 'Akademia Tenisowa Tenis Kozerki'},
#  {'complex_id': 'sr:complex:65597',
#   'complex_name': 'Tennis St-Luc - Les Loisirs De Granby'},
#  {'complex_id': 'sr:complex:65601', 'complex_name': 'TK Spoje Praha'},
#  {'complex_id': 'sr:complex:65603',
#   'complex_name': 'Nacionalni Trening Centar Teniskog'},
#  {'complex_id': 'sr:complex:65717', 'complex_name': 'A.S.D. Tennis Club Como'},
#  {'complex_id': 'sr:complex:65719', 'complex_name': 'Rafa Nadal Academy'},
#  {'complex_id': 'sr:complex:65739',
#   'complex_name': 'Stade Toulousain Tennis Club'},
#  {'complex_id': 'sr:complex:65779', 'complex_name': 'Etihad Arena'},
#  {'complex_id': 'sr:complex:65849', 'complex_name': 'Circolo Tennis Bari'},
#  {'complex_id': 'sr:complex:65973', 'complex_name': 'Tennis Academy SET'},
#  {'complex_id': 'sr:complex:65975', 'complex_name': 'SEB Arena'},
#  {'complex_id': 'sr:complex:65977',
#   'complex_name': 'Centro Cultural de Viana do Castelo'},
#  {'complex_id': 'sr:complex:65979',
#   'complex_name': 'The Lawn Tennis Association of Thailand'},
#  {'complex_id': 'sr:complex:65981', 'complex_name': 'Taipei Tennis Center'},
#  {'complex_id': 'sr:complex:65983', 'complex_name': 'National Tennis Centre'},
#  {'complex_id': 'sr:complex:65985', 'complex_name': 'Ohio State University'},
#  {'complex_id': 'sr:complex:65997', 'complex_name': 'Sport Social Club'},
#  {'complex_id': 'sr:complex:66093',
#   'complex_name': 'Tel Aviv International Convention Center'},
#  {'complex_id': 'sr:complex:66187',
#   'complex_name': 'Skanes Family Hotel Monastir'},
#  {'complex_id': 'sr:complex:66559', 'complex_name': 'Rio Tennis Academy'},
#  {'complex_id': 'sr:complex:66565',
#   'complex_name': 'Tennis Club Saint Tropez'},
#  {'complex_id': 'sr:complex:66785', 'complex_name': 'Spo1 Park'},
#  {'complex_id': 'sr:complex:66787',
#   'complex_name': 'Hamburger Tennis Verband e.V'},
#  {'complex_id': 'sr:complex:66951', 'complex_name': 'Tennis Club Ortisei'},
#  {'complex_id': 'sr:complex:66953',
#   'complex_name': 'Centro Libanes Mexicano de Tampico'},
#  {'complex_id': 'sr:complex:67275', 'complex_name': 'Olme Sport'},
#  {'complex_id': 'sr:complex:67459',
#   'complex_name': 'Ehime Prefectural Sports Complex'},
#  {'complex_id': 'sr:complex:67621',
#   'complex_name': 'Tennis Interieur Rene Verrier'},
#  {'complex_id': 'sr:complex:67855', 'complex_name': 'Yokkaichi Tennis Center'},
#  {'complex_id': 'sr:complex:68141',
#   'complex_name': 'Conde Jackson Tennis Club Maspalomas'},
#  {'complex_id': 'sr:complex:68959', 'complex_name': 'Club Nautico Hacoaj'},
#  {'complex_id': 'sr:complex:69121', 'complex_name': 'CLUBE CRISTOVAO COLOMBO'},
#  {'complex_id': 'sr:complex:69179',
#   'complex_name': 'Complexe Sportif du Blocry'},
#  {'complex_id': 'sr:complex:69183',
#   'complex_name': 'Estadio Espanol Chiguayante'},
#  {'complex_id': 'sr:complex:69645', 'complex_name': 'Complexe Jean Jaures'},
#  {'complex_id': 'sr:complex:69779',
#   'complex_name': 'Rome Tennis Center at Berry College'},
#  {'complex_id': 'sr:complex:69789', 'complex_name': 'Circolo Tennis Rovereto'},
#  {'complex_id': 'sr:complex:69799', 'complex_name': 'Yucatan Country Club'},
#  {'complex_id': 'sr:complex:69965', 'complex_name': 'Hurd Tennis Center'},
#  {'complex_id': 'sr:complex:69971', 'complex_name': 'Westwood Country Club'},
#  {'complex_id': 'sr:complex:70271',
#   'complex_name': 'Utilita Arena Birmingham'},
#  {'complex_id': 'sr:complex:70335', 'complex_name': 'Club Tennis Els Gorchs'},
#  {'complex_id': 'sr:complex:70345', 'complex_name': 'Club Tennis Girona'},
#  {'complex_id': 'sr:complex:70661', 'complex_name': 'Club Campestre'},
#  {'complex_id': 'sr:complex:70663', 'complex_name': 'Tenis Centar Firule'},
#  {'complex_id': 'sr:complex:71287',
#   'complex_name': 'Tennis Club Rot Weiss Troisdorf E. V.'},
#  {'complex_id': 'sr:complex:71431',
#   'complex_name': 'Club de Tennis La Bisbal Centre Esportiu'},
#  {'complex_id': 'sr:complex:71923',
#   'complex_name': 'Salle Omnisport de Rades'},
#  {'complex_id': 'sr:complex:71961', 'complex_name': 'Club La Meridiana'},
#  {'complex_id': 'sr:complex:72061',
#   'complex_name': 'Cranbrook Kingswood Tennis Complex'},
#  {'complex_id': 'sr:complex:72523', 'complex_name': 'Nice Lawn Tennis Club'},
#  {'complex_id': 'sr:complex:72533',
#   'complex_name': 'Complejo Deportivo Pedro Muñoz'},
#  {'complex_id': 'sr:complex:72677',
#   'complex_name': 'Corredor Turistico SJC-CSL'},
#  {'complex_id': 'sr:complex:73167',
#   'complex_name': 'Stanford Taube Tennis Center'},
#  {'complex_id': 'sr:complex:73179',
#   'complex_name': 'National Bank Tennis Hub @ West St Paul'},
#  {'complex_id': 'sr:complex:73191',
#   'complex_name': 'Parque Distrital de Raquetas'},
#  {'complex_id': 'sr:complex:73227', 'complex_name': 'AO Arena'},
#  {'complex_id': 'sr:complex:73463', 'complex_name': 'Academy Zhangjiagang'},
#  {'complex_id': 'sr:complex:73795', 'complex_name': 'Tivoli Tennis Center'},
#  {'complex_id': 'sr:complex:73797',
#   'complex_name': 'Guangzhou Nansha International Tennis Center'},
#  {'complex_id': 'sr:complex:73807', 'complex_name': 'Country Club Las Palmas'},
#  {'complex_id': 'sr:complex:73817', 'complex_name': 'Korty Mosrir'},
#  {'complex_id': 'sr:complex:73979', 'complex_name': 'Garikula Tennis Club'},
#  {'complex_id': 'sr:complex:73981', 'complex_name': 'ILT Stadium'},
#  {'complex_id': 'sr:complex:73997', 'complex_name': 'Autoclub Antofagasta'},
#  {'complex_id': 'sr:complex:74007',
#   'complex_name': 'Sportaktivpark Bad Waltersdorf'},
#  {'complex_id': 'sr:complex:74017', 'complex_name': 'Ty Tucker Tennis Center'},
#  {'complex_id': 'sr:complex:74049', 'complex_name': 'Tennis Club Mostar'},
#  {'complex_id': 'sr:complex:74051', 'complex_name': 'Helikon Teniszcentrum'},
#  {'complex_id': 'sr:complex:74053', 'complex_name': 'Multiversum Schwechat'},
#  {'complex_id': 'sr:complex:74061', 'complex_name': 'Tenis Club IDU'},
#  {'complex_id': 'sr:complex:74063', 'complex_name': 'Royal Stage'},
#  {'complex_id': 'sr:complex:74065', 'complex_name': 'Mini Stadium'},
#  {'complex_id': 'sr:complex:74067',
#   'complex_name': 'Complejo de Tenis Marcelo Arevalo'},
#  {'complex_id': 'sr:complex:74173',
#   'complex_name': 'National Tennis Center (Beeline Arena)'},
#  {'complex_id': 'sr:complex:74183', 'complex_name': 'Club Compensar Sede 220'},
#  {'complex_id': 'sr:complex:74193', 'complex_name': "Arena Co'Met"},
#  {'complex_id': 'sr:complex:74730', 'complex_name': 'Playford Tennis Centre'},
#  {'complex_id': 'sr:complex:74732', 'complex_name': 'Graciosa Country Club'},
#  {'complex_id': 'sr:complex:74734',
#   'complex_name': 'Ciudad Deportiva de Tampico'},
#  {'complex_id': 'sr:complex:74736', 'complex_name': 'Hengqin Tennis Center'},
#  {'complex_id': 'sr:complex:74912',
#   'complex_name': 'Estadio Paradisus Cancun Quintana Roo'},
#  {'complex_id': 'sr:complex:74962', 'complex_name': 'Arena Sofia'},
#  {'complex_id': 'sr:complex:75062',
#   'complex_name': 'Good To Great Tennis Academy'},
#  {'complex_id': 'sr:complex:75064',
#   'complex_name': 'Tennis Intérieur René Verrier'},
#  {'complex_id': 'sr:complex:75066',
#   'complex_name': 'Miki Disaster Management Park'},
#  {'complex_id': 'sr:complex:75068',
#   'complex_name': 'Carrasco Lawn Tennis Club'},
#  {'complex_id': 'sr:complex:75070', 'complex_name': 'Hacienda Chicureo'},
#  {'complex_id': 'sr:complex:75192', 'complex_name': 'Arena BRB'},
#  {'complex_id': 'sr:complex:75200', 'complex_name': 'Jurerê Sports Center'},
#  {'complex_id': 'sr:complex:75607',
#   'complex_name': 'Bezirksstützpunkt Biberach'},
#  {'complex_id': 'sr:complex:75731', 'complex_name': 'Hala Ricany'},
#  {'complex_id': 'sr:complex:76035', 'complex_name': 'Vitality Slezsko'},
#  {'complex_id': 'sr:complex:76037', 'complex_name': 'Jockey Club de Rosario'},
#  {'complex_id': 'sr:complex:76089', 'complex_name': 'Design Center Linz'},
#  {'complex_id': 'sr:complex:76107',
#   'complex_name': 'Guangzhou Development District International Tennis School'},
#  {'complex_id': 'sr:complex:76885',
#   'complex_name': 'Delhi Lawn Tennis Association'},
#  {'complex_id': 'sr:complex:77217', 'complex_name': 'Emilio Sanchez Academy'},
#  {'complex_id': 'sr:complex:77389', 'complex_name': 'Tiriac Stadium'},
#  {'complex_id': 'sr:complex:77391',
#   'complex_name': 'Tucumán Lawn Tennis Club'},
#  {'complex_id': 'sr:complex:77425', 'complex_name': 'Arena GNP Seguros'},
#  {'complex_id': 'sr:complex:77517', 'complex_name': 'Club Tennis Lleida'},
#  {'complex_id': 'sr:complex:77595',
#   'complex_name': 'Wuxi International Tennis Center'},
#  {'complex_id': 'sr:complex:77615', 'complex_name': 'Tênis Clube de Santos'},
#  {'complex_id': 'sr:complex:77763',
#   'complex_name': 'Complexo Desportivo do Jamor'},
#  {'complex_id': 'sr:complex:77767', 'complex_name': 'Tennis Club De Tunis'},
#  {'complex_id': 'sr:complex:77883', 'complex_name': 'Kachreti Golf Resort'},
#  {'complex_id': 'sr:complex:78093', 'complex_name': 'Sports Center Salata'},
#  {'complex_id': 'sr:complex:78363', 'complex_name': 'Community Sport Centre'},
#  {'complex_id': 'sr:complex:78489', 'complex_name': 'Baza Sportiva Olimpia'},
#  {'complex_id': 'sr:complex:78753', 'complex_name': 'Sporting Club Verona'},
#  {'complex_id': 'sr:complex:78831',
#   'complex_name': 'Victoria Park Tennis Stadium'},
#  {'complex_id': 'sr:complex:79097',
#   'complex_name': 'Bonn Tennis and Hockey Club'},
#  {'complex_id': 'sr:complex:79103',
#   'complex_name': 'Sid And Hazel Dillon Tennis Center'},
#  {'complex_id': 'sr:complex:79281', 'complex_name': 'Tennis Club Izida'},
#  {'complex_id': 'sr:complex:79391', 'complex_name': 'Omega Sport Center'},
#  {'complex_id': 'sr:complex:79459', 'complex_name': 'Clube de Tenis do Porto'},
#  {'complex_id': 'sr:complex:79633', 'complex_name': 'Gezira Sporting Club'},
#  {'complex_id': 'sr:complex:79665', 'complex_name': 'Montreux Tennis Club'},
#  {'complex_id': 'sr:complex:79837',
#   'complex_name': 'Club Campestre Farallones'},
#  {'complex_id': 'sr:complex:79851', 'complex_name': 'Fly Palmy Arena'},
#  {'complex_id': 'sr:complex:79853', 'complex_name': 'Tennis Club Lokomotiv'},
#  {'complex_id': 'sr:complex:79855', 'complex_name': 'Palm Hills Sports Club'},
#  {'complex_id': 'sr:complex:79861',
#   'complex_name': 'Tennis Club de Avenir Sportif de la Marsa'},
#  {'complex_id': 'sr:complex:80737',
#   'complex_name': 'International Tennis Center'},
#  {'complex_id': 'sr:complex:80851', 'complex_name': 'Beograndska Arena'},
#  {'complex_id': 'sr:complex:80961', 'complex_name': 'Inalpi Arena'},
#  {'complex_id': 'sr:complex:80963',
#   'complex_name': 'All In Country Club Decines'},
#  {'complex_id': 'sr:complex:81249',
#   'complex_name': 'Las Hadas Golf & Country Club'},
#  {'complex_id': 'sr:complex:81543',
#   'complex_name': 'Headington Family Tennis Center'},
#  {'complex_id': 'sr:complex:81613', 'complex_name': 'Royal SC Tennis'},
#  {'complex_id': 'sr:complex:81635', 'complex_name': 'LSU'},
#  {'complex_id': 'sr:complex:81651', 'complex_name': 'Robson Tennis Center'},
#  {'complex_id': 'sr:complex:81661',
#   'complex_name': 'Wake Forest Tennis Center'},
#  {'complex_id': 'sr:complex:81673', 'complex_name': 'Palmira Tennis Club'},
#  {'complex_id': 'sr:complex:81681',
#   'complex_name': 'Tennis Courts of the SW University Neofit Rilski'},
#  {'complex_id': 'sr:complex:81713',
#   'complex_name': 'Penina Hotel & Golf Resort'},
#  {'complex_id': 'sr:complex:81717', 'complex_name': 'Bloomington'},
#  {'complex_id': 'sr:complex:81745', 'complex_name': 'Clube Tenis Portimao'},
#  {'complex_id': 'sr:complex:81747', 'complex_name': 'Atlantis The Palm'},
#  {'complex_id': 'sr:complex:81751', 'complex_name': 'Kallang Tennis Centre'},
#  {'complex_id': 'sr:complex:81779', 'complex_name': 'KPI Park'},
#  {'complex_id': 'sr:complex:81809',
#   'complex_name': 'Courts De Tennis De La Cité Nationale Sportive El Menza'},
#  {'complex_id': 'sr:complex:81811',
#   'complex_name': 'Sala Polivalenta Craiova'},
#  {'complex_id': 'sr:complex:81813', 'complex_name': 'New Sport Palace'},
#  {'complex_id': 'sr:complex:81815', 'complex_name': 'Complejo de Raquetas'},
#  {'complex_id': 'sr:complex:81817', 'complex_name': 'DLTA Complex'},
#  {'complex_id': 'sr:complex:81819',
#   'complex_name': 'Monte-Carlo Country Club'},
#  {'complex_id': 'sr:complex:81821',
#   'complex_name': 'TENIS ESKRIM DAGCILIK KULÜBÜ'},
#  {'complex_id': 'sr:complex:81823', 'complex_name': 'Beeline Arena'},
#  {'complex_id': 'sr:complex:81827', 'complex_name': 'Coque Luxenbourg'},
#  {'complex_id': 'sr:complex:81977', 'complex_name': 'Green Tennis Plaza'},
#  {'complex_id': 'sr:complex:81985',
#   'complex_name': 'Boulevard de las Naciones and Paseo de los Manglares'},
#  {'complex_id': 'sr:complex:81995', 'complex_name': 'Georgia Gwinnett'},
#  {'complex_id': 'sr:complex:82007',
#   'complex_name': 'Sport Center Visnjik (Clay)'},
#  {'complex_id': 'sr:complex:82033',
#   'complex_name': 'Spot - Salle Jean Burger'},
#  {'complex_id': 'sr:complex:82065', 'complex_name': 'Raquet Village'},
#  {'complex_id': 'sr:complex:82109', 'complex_name': 'Manzanillo'},
#  {'complex_id': 'sr:complex:82131',
#   'complex_name': 'Club de Golf Tres Marias'},
#  {'complex_id': 'sr:complex:82133',
#   'complex_name': 'Sheraton Buganvilias Resort and Convention Center'},
#  {'complex_id': 'sr:complex:82197', 'complex_name': 'Tennis Club Porto Rose'},
#  {'complex_id': 'sr:complex:82223',
#   'complex_name': 'Complejo Deportivo San Carlos De Apoquindo'},
#  {'complex_id': 'sr:complex:82243', 'complex_name': 'Club Tenis Ciutadella'},
#  {'complex_id': 'sr:complex:82279',
#   'complex_name': 'Tenis Club Crvena Zvezda'},
#  {'complex_id': 'sr:complex:82301',
#   'complex_name': 'Villa Reale Tennis Monza'},
#  {'complex_id': 'sr:complex:82313',
#   'complex_name': 'Carvoeiro Clube de Tenis'},
#  {'complex_id': 'sr:complex:82335', 'complex_name': 'Sarasota Sports Club'},
#  {'complex_id': 'sr:complex:82343', 'complex_name': 'Le Central Tennis Club'},
#  {'complex_id': 'sr:complex:82356',
#   'complex_name': 'Dan Maskell Tennis Centre'},
#  {'complex_id': 'sr:complex:82415',
#   'complex_name': 'George P Mitchell 40 Tennis Center'},
#  {'complex_id': 'sr:complex:82417', 'complex_name': 'National Tennis Center'},
#  {'complex_id': 'sr:complex:82467', 'complex_name': 'Tcja Saint-Malo'},
#  {'complex_id': 'sr:complex:82469', 'complex_name': 'Club Tennis Vic'}]

# %% [markdown]
# Converting the data into DataFrame:

# %%
import pandas as pd
pd.DataFrame(complexes_list).to_csv('C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project1/Tennis_Data_SportRadar/csv_files/complexes_details.csv', index=False)

complexes_data = pd.read_csv('csv_files/complexes_details.csv')
complexes_data
# Out:
#            complex_id                           complex_name
# 0      sr:complex:705                               Nacional
# 1     sr:complex:1078                  Estadio de la Cartuja
# 2     sr:complex:1495                            Sibur Arena
# 3     sr:complex:2375             Complexo de Tenis do Jamor
# 4     sr:complex:4032  Shree Shiv Chhatrapati Sports Complex
# ..                ...                                    ...
# 652  sr:complex:82356              Dan Maskell Tennis Centre
# 653  sr:complex:82415     George P Mitchell 40 Tennis Center
# 654  sr:complex:82417                 National Tennis Center
# 655  sr:complex:82467                        Tcja Saint-Malo
# 656  sr:complex:82469                        Club Tennis Vic
#
# [657 rows x 2 columns]

# %% [markdown]
# save data in postgresql database

# %%
pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\dhars\downloads\dhass\codeing\guvi\2. mainboot\4.project_code\project1\tennis_data_sportradar\.venv\lib\site-packages (2.9.10)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Creating DataBase:

# %%
pip install toml
# Out:
# Requirement already satisfied: toml in c:\users\dhars\downloads\dhass\codeing\guvi\2. mainboot\4.project_code\project1\tennis_data_sportradar\.venv\lib\site-packages (0.10.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import psycopg2
import streamlit as st
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

import toml

# Load secrets from your custom toml file
secrets = toml.load(".pwd/pwd.toml")

# #SQl Connection - postgres - Using Psycopg2:
my_db_connection = psycopg2.connect(
    #If localDataBase:
        host=secrets["host"],
        user=secrets["user"],
        password=secrets["password"]
        # database=secrets["database"]

    #If Cloud:
        # host=st.secrets["host"],
        # user=st.secrets["user"],
        # password=st.secrets["password"], 
        # database=st.secrets["database"],
        # port=st.secrets["port"]
)

my_db_connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)


# #I need to connect the db and the python:
mycursor = my_db_connection.cursor()


# Check if database exists
mycursor.execute("SELECT * FROM pg_database WHERE datname='sportradar'")
exists = mycursor.fetchone()

if not exists:
    mycursor.execute("CREATE DATABASE sportradar")
    print("Database 'sportradar' created")
else:
    print("Database 'sportradar' already exists")

mycursor.close()
my_db_connection.close()
# Out:
# Database 'sportradar' already exists

# %% [markdown]
# Creating Complexes Table

# %%
#SQl Connection - postgres - Using Psycopg2:
my_db_connection = psycopg2.connect(
    #If localDataBase:
        host=secrets["host"],
        user=secrets["user"],
        password=secrets["password"],
        database=secrets["database"]

    #If Cloud:
        # host=st.secrets["host"],
        # user=st.secrets["user"],
        # password=st.secrets["password"], 
        # database=st.secrets["database"],
        # port=st.secrets["port"]
)
my_db_connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)


# #I need to connect the db and the python:
mycursor = my_db_connection.cursor()

complexes_create_table_sql = """create table if not exists complexes_table(
complex_id varchar(50) PRIMARY KEY, 
complex_name varchar(100) NOT NULL)"""

#execute:
mycursor.execute(complexes_create_table_sql)

print("Complex Table has been created")
# Out:
# Complex Table has been created

# %% [markdown]
# Fetching Column Name from complexes_table:

# %%
column_name = """SELECT column_name FROM 
        information_schema.columns WHERE table_name = 'complexes_table';"""
mycursor.execute(column_name)
fetching_column_names = mycursor.fetchall()
fetching_column_names
# Out:
# [('complex_id',), ('complex_name',)]

# %% [markdown]
# insert values into complexes table:

# %%
complex_insert_table_sql = """Insert into complexes_table(
complex_id, 
complex_name) 
values (%s, %s) 
ON CONFLICT (complex_id) DO NOTHING"""

#ON CONFLICT (cat_id) DO NOTHING
#“If there’s a conflict — like trying to insert a row with a duplicate primary key or unique value — then just skip that row and move on. 
# Don’t insert it, and don’t throw an error.”

# %%
for index, row in complexes_data.iterrows():
    print(row) #We will get the o/p in the format of dictionary with column names as keys.

    print("Inserting:", tuple(row))  #The iter row (only values) will converts into python tuple 
    print("----------------------\n")
    mycursor.execute(complex_insert_table_sql, tuple(row))
print("Data inserted into the complexes_table using iterrows()")
# Out:
# complex_id      sr:complex:705
# complex_name          Nacional
# Name: 0, dtype: object
# Inserting: ('sr:complex:705', 'Nacional')
# ----------------------
#
# complex_id            sr:complex:1078
# complex_name    Estadio de la Cartuja
# Name: 1, dtype: object
# Inserting: ('sr:complex:1078', 'Estadio de la Cartuja')
# ----------------------
#
# complex_id      sr:complex:1495
# complex_name        Sibur Arena
# Name: 2, dtype: object
# Inserting: ('sr:complex:1495', 'Sibur Arena')
# ----------------------
#
# complex_id                 sr:complex:2375
# complex_name    Complexo de Tenis do Jamor
# Name: 3, dtype: object
# Inserting: ('sr:complex:2375', 'Complexo de Tenis do Jamor')
# ----------------------
#
# complex_id                            sr:complex:4032
# complex_name    Shree Shiv Chhatrapati Sports Complex
# Name: 4, dtype: object
# Inserting: ('sr:complex:4032', 'Shree Shiv Chhatrapati Sports Complex')
# ----------------------
#
# complex_id      sr:complex:5520
# complex_name           O2 Arena
# Name: 5, dtype: object
# Inserting: ('sr:complex:5520', 'O2 Arena')
# ----------------------
#
# complex_id      sr:complex:5526
# complex_name     Ostravar Arena
# Name: 6, dtype: object
# Inserting: ('sr:complex:5526', 'Ostravar Arena')
# ----------------------
#
# complex_id      sr:complex:6310
# complex_name     Varazdin Arena
# Name: 7, dtype: object
# Inserting: ('sr:complex:6310', 'Varazdin Arena')
# ----------------------
#
# complex_id        sr:complex:6484
# complex_name    Arena Montpellier
# Name: 8, dtype: object
# Inserting: ('sr:complex:6484', 'Arena Montpellier')
# ----------------------
#
# complex_id      sr:complex:6736
# complex_name     Arenes de Metz
# Name: 9, dtype: object
# Inserting: ('sr:complex:6736', 'Arenes de Metz')
# ----------------------
#
# complex_id               sr:complex:6888
# complex_name    Palais des sports de Pau
# Name: 10, dtype: object
# Inserting: ('sr:complex:6888', 'Palais des sports de Pau')
# ----------------------
#
# complex_id                sr:complex:6890
# complex_name    Palais des Sports Orleans
# Name: 11, dtype: object
# Inserting: ('sr:complex:6890', 'Palais des Sports Orleans')
# ----------------------
#
# complex_id                sr:complex:6904
# complex_name    Stade Pierre-de-Coubertin
# Name: 12, dtype: object
# Inserting: ('sr:complex:6904', 'Stade Pierre-de-Coubertin')
# ----------------------
#
# complex_id                                    sr:complex:7048
# complex_name    Palacio de Deportes Jose Maria Martin Carpena
# Name: 13, dtype: object
# Inserting: ('sr:complex:7048', 'Palacio de Deportes Jose Maria Martin Carpena')
# ----------------------
#
# complex_id                         sr:complex:7052
# complex_name    Pabellon Municipal Fuente San Luis
# Name: 14, dtype: object
# Inserting: ('sr:complex:7052', 'Pabellon Municipal Fuente San Luis')
# ----------------------
#
# complex_id      sr:complex:7208
# complex_name       Unipol Arena
# Name: 15, dtype: object
# Inserting: ('sr:complex:7208', 'Unipol Arena')
# ----------------------
#
# complex_id      sr:complex:7778
# complex_name        Arena Gripe
# Name: 16, dtype: object
# Inserting: ('sr:complex:7778', 'Arena Gripe')
# ----------------------
#
# complex_id          sr:complex:9725
# complex_name    Arena Armeets Sofia
# Name: 17, dtype: object
# Inserting: ('sr:complex:9725', 'Arena Armeets Sofia')
# ----------------------
#
# complex_id      sr:complex:10063
# complex_name           Kindarena
# Name: 18, dtype: object
# Inserting: ('sr:complex:10063', 'Kindarena')
# ----------------------
#
# complex_id           sr:complex:11769
# complex_name    Estadio German Becker
# Name: 19, dtype: object
# Inserting: ('sr:complex:11769', 'Estadio German Becker')
# ----------------------
#
# complex_id                  sr:complex:12241
# complex_name    Palais des sports de Gerland
# Name: 20, dtype: object
# Inserting: ('sr:complex:12241', 'Palais des sports de Gerland')
# ----------------------
#
# complex_id      sr:complex:15014
# complex_name    Palais Des Sport
# Name: 21, dtype: object
# Inserting: ('sr:complex:15014', 'Palais Des Sport')
# ----------------------
#
# complex_id      sr:complex:15371
# complex_name           Palasport
# Name: 22, dtype: object
# Inserting: ('sr:complex:15371', 'Palasport')
# ----------------------
#
# complex_id      sr:complex:16020
# complex_name     Salle Steredenn
# Name: 23, dtype: object
# Inserting: ('sr:complex:16020', 'Salle Steredenn')
# ----------------------
#
# complex_id        sr:complex:16069
# complex_name    Garanti Koza Arena
# Name: 24, dtype: object
# Inserting: ('sr:complex:16069', 'Garanti Koza Arena')
# ----------------------
#
# complex_id      sr:complex:16612
# complex_name       Porsche-Arena
# Name: 25, dtype: object
# Inserting: ('sr:complex:16612', 'Porsche-Arena')
# ----------------------
#
# complex_id            sr:complex:17254
# complex_name    Poliesportiu d'Andorra
# Name: 26, dtype: object
# Inserting: ('sr:complex:17254', "Poliesportiu d'Andorra")
# ----------------------
#
# complex_id      sr:complex:17945
# complex_name      Rotterdam Ahoy
# Name: 27, dtype: object
# Inserting: ('sr:complex:17945', 'Rotterdam Ahoy')
# ----------------------
#
# complex_id      sr:complex:18201
# complex_name              The O2
# Name: 28, dtype: object
# Inserting: ('sr:complex:18201', 'The O2')
# ----------------------
#
# complex_id           sr:complex:18221
# complex_name    Bluesun Tennis Center
# Name: 29, dtype: object
# Inserting: ('sr:complex:18221', 'Bluesun Tennis Center')
# ----------------------
#
# complex_id        sr:complex:19166
# complex_name    Shlomo Group Arena
# Name: 30, dtype: object
# Inserting: ('sr:complex:19166', 'Shlomo Group Arena')
# ----------------------
#
# complex_id                      sr:complex:19737
# complex_name    Club Sonoma, Estadio Gnp Seguros
# Name: 31, dtype: object
# Inserting: ('sr:complex:19737', 'Club Sonoma, Estadio Gnp Seguros')
# ----------------------
#
# complex_id      sr:complex:19951
# complex_name         Accor Arena
# Name: 32, dtype: object
# Inserting: ('sr:complex:19951', 'Accor Arena')
# ----------------------
#
# complex_id                                  sr:complex:21870
# complex_name    Stadium Goran Ivanisevic in ITC Stella Maris
# Name: 33, dtype: object
# Inserting: ('sr:complex:21870', 'Stadium Goran Ivanisevic in ITC Stella Maris')
# ----------------------
#
# complex_id       sr:complex:21910
# complex_name    Roy Emerson Arena
# Name: 34, dtype: object
# Inserting: ('sr:complex:21910', 'Roy Emerson Arena')
# ----------------------
#
# complex_id                 sr:complex:26983
# complex_name    Club de Tenis Puente Romano
# Name: 35, dtype: object
# Inserting: ('sr:complex:26983', 'Club de Tenis Puente Romano')
# ----------------------
#
# complex_id            sr:complex:26985
# complex_name    National Tennis Center
# Name: 36, dtype: object
# Inserting: ('sr:complex:26985', 'National Tennis Center')
# ----------------------
#
# complex_id            sr:complex:27093
# complex_name    Canberra Tennis Centre
# Name: 37, dtype: object
# Inserting: ('sr:complex:27093', 'Canberra Tennis Centre')
# ----------------------
#
# complex_id      sr:complex:27095
# complex_name            BT Arena
# Name: 38, dtype: object
# Inserting: ('sr:complex:27095', 'BT Arena')
# ----------------------
#
# complex_id           sr:complex:28457
# complex_name    Valletta Cambiaso ASD
# Name: 39, dtype: object
# Inserting: ('sr:complex:28457', 'Valletta Cambiaso ASD')
# ----------------------
#
# complex_id      sr:complex:28617
# complex_name       Porsche Arena
# Name: 40, dtype: object
# Inserting: ('sr:complex:28617', 'Porsche Arena')
# ----------------------
#
# complex_id      sr:complex:28926
# complex_name         Royal Arena
# Name: 41, dtype: object
# Inserting: ('sr:complex:28926', 'Royal Arena')
# ----------------------
#
# complex_id      sr:complex:32327
# complex_name        Taipei Arena
# Name: 42, dtype: object
# Inserting: ('sr:complex:32327', 'Taipei Arena')
# ----------------------
#
# complex_id              sr:complex:32403
# complex_name    Ohio State University GC
# Name: 43, dtype: object
# Inserting: ('sr:complex:32403', 'Ohio State University GC')
# ----------------------
#
# complex_id                sr:complex:32668
# complex_name    Shenzhen Bay Sports Center
# Name: 44, dtype: object
# Inserting: ('sr:complex:32668', 'Shenzhen Bay Sports Center')
# ----------------------
#
# complex_id              sr:complex:32812
# complex_name    Singapore Indoor Stadium
# Name: 45, dtype: object
# Inserting: ('sr:complex:32812', 'Singapore Indoor Stadium')
# ----------------------
#
# complex_id                    sr:complex:33186
# complex_name    Palais des Sports de Marseille
# Name: 46, dtype: object
# Inserting: ('sr:complex:33186', 'Palais des Sports de Marseille')
# ----------------------
#
# complex_id      sr:complex:33188
# complex_name         Caja Magica
# Name: 47, dtype: object
# Inserting: ('sr:complex:33188', 'Caja Magica')
# ----------------------
#
# complex_id                              sr:complex:33190
# complex_name    All England Lawn Tennis and Croquet Club
# Name: 48, dtype: object
# Inserting: ('sr:complex:33190', 'All England Lawn Tennis and Croquet Club')
# ----------------------
#
# complex_id         sr:complex:33192
# complex_name    Stade Roland Garros
# Name: 49, dtype: object
# Inserting: ('sr:complex:33192', 'Stade Roland Garros')
# ----------------------
#
# complex_id      sr:complex:33194
# complex_name    Complexe Al Amal
# Name: 50, dtype: object
# Inserting: ('sr:complex:33194', 'Complexe Al Amal')
# ----------------------
#
# complex_id      sr:complex:33196
# complex_name      Melbourne Park
# Name: 51, dtype: object
# Inserting: ('sr:complex:33196', 'Melbourne Park')
# ----------------------
#
# complex_id                       sr:complex:33198
# complex_name    Qi zhong Forest Sports City Arena
# Name: 52, dtype: object
# Inserting: ('sr:complex:33198', 'Qi zhong Forest Sports City Arena')
# ----------------------
#
# complex_id                           sr:complex:33200
# complex_name    Wake Forest University Tennis Complex
# Name: 53, dtype: object
# Inserting: ('sr:complex:33200', 'Wake Forest University Tennis Complex')
# ----------------------
#
# complex_id               sr:complex:33204
# complex_name    Clube de Ténis do Estoril
# Name: 54, dtype: object
# Inserting: ('sr:complex:33204', 'Clube de Ténis do Estoril')
# ----------------------
#
# complex_id      sr:complex:33206
# complex_name           The Drive
# Name: 55, dtype: object
# Inserting: ('sr:complex:33206', 'The Drive')
# ----------------------
#
# complex_id      sr:complex:33208
# complex_name    Atlantic Station
# Name: 56, dtype: object
# Inserting: ('sr:complex:33208', 'Atlantic Station')
# ----------------------
#
# complex_id                       sr:complex:33210
# complex_name    International Tennis Hall of Fame
# Name: 57, dtype: object
# Inserting: ('sr:complex:33210', 'International Tennis Hall of Fame')
# ----------------------
#
# complex_id            sr:complex:33214
# complex_name    Club Jacaranda Cumbaya
# Name: 58, dtype: object
# Inserting: ('sr:complex:33214', 'Club Jacaranda Cumbaya')
# ----------------------
#
# complex_id                                sr:complex:33218
# complex_name    Hengqin International Tennis Center Zhuhai
# Name: 59, dtype: object
# Inserting: ('sr:complex:33218', 'Hengqin International Tennis Center Zhuhai')
# ----------------------
#
# complex_id                   sr:complex:33222
# complex_name    Buenos Aires Lawn Tennis Club
# Name: 60, dtype: object
# Inserting: ('sr:complex:33222', 'Buenos Aires Lawn Tennis Club')
# ----------------------
#
# complex_id                 sr:complex:33226
# complex_name    The Racquet Club of Memphis
# Name: 61, dtype: object
# Inserting: ('sr:complex:33226', 'The Racquet Club of Memphis')
# ----------------------
#
# complex_id                sr:complex:33228
# complex_name    Delray Beach Tennis Center
# Name: 62, dtype: object
# Inserting: ('sr:complex:33228', 'Delray Beach Tennis Center')
# ----------------------
#
# complex_id                  sr:complex:33230
# complex_name    CK Sportcenter Kockelscheuer
# Name: 63, dtype: object
# Inserting: ('sr:complex:33230', 'CK Sportcenter Kockelscheuer')
# ----------------------
#
# complex_id          sr:complex:33232
# complex_name    Singapore Sports Hub
# Name: 64, dtype: object
# Inserting: ('sr:complex:33232', 'Singapore Sports Hub')
# ----------------------
#
# complex_id       sr:complex:33234
# complex_name    Linzer Sporthalle
# Name: 65, dtype: object
# Inserting: ('sr:complex:33234', 'Linzer Sporthalle')
# ----------------------
#
# complex_id              sr:complex:33236
# complex_name    Luzhniki Olympic Complex
# Name: 66, dtype: object
# Inserting: ('sr:complex:33236', 'Luzhniki Olympic Complex')
# ----------------------
#
# complex_id      sr:complex:33238
# complex_name    Ariake Colosseum
# Name: 67, dtype: object
# Inserting: ('sr:complex:33238', 'Ariake Colosseum')
# ----------------------
#
# complex_id                               sr:complex:33240
# complex_name    Optics Valley International Tennis Center
# Name: 68, dtype: object
# Inserting: ('sr:complex:33240', 'Optics Valley International Tennis Center')
# ----------------------
#
# complex_id                    sr:complex:33242
# complex_name    Guangzhou Tianhe Sports Center
# Name: 69, dtype: object
# Inserting: ('sr:complex:33242', 'Guangzhou Tianhe Sports Center')
# ----------------------
#
# complex_id                sr:complex:33244
# complex_name    Olympic Park Tennis Center
# Name: 70, dtype: object
# Inserting: ('sr:complex:33244', 'Olympic Park Tennis Center')
# ----------------------
#
# complex_id                sr:complex:33246
# complex_name    Victoria Park Tennis Court
# Name: 71, dtype: object
# Inserting: ('sr:complex:33246', 'Victoria Park Tennis Court')
# ----------------------
#
# complex_id                                sr:complex:33248
# complex_name    Tianjin Tuanbo International Tennis Center
# Name: 72, dtype: object
# Inserting: ('sr:complex:33248', 'Tianjin Tuanbo International Tennis Center')
# ----------------------
#
# complex_id               sr:complex:33250
# complex_name    Tashkent Tennis Centreake
# Name: 73, dtype: object
# Inserting: ('sr:complex:33250', 'Tashkent Tennis Centreake')
# ----------------------
#
# complex_id                  sr:complex:33252
# complex_name    China National Tennis Center
# Name: 74, dtype: object
# Inserting: ('sr:complex:33252', 'China National Tennis Center')
# ----------------------
#
# complex_id          sr:complex:33254
# complex_name    Utsubo Tennis Center
# Name: 75, dtype: object
# Inserting: ('sr:complex:33254', 'Utsubo Tennis Center')
# ----------------------
#
# complex_id               sr:complex:33258
# complex_name    Connecticut Tennis Center
# Name: 76, dtype: object
# Inserting: ('sr:complex:33258', 'Connecticut Tennis Center')
# ----------------------
#
# complex_id                      sr:complex:33262
# complex_name    Santa Catarina Tennis Federation
# Name: 77, dtype: object
# Inserting: ('sr:complex:33262', 'Santa Catarina Tennis Federation')
# ----------------------
#
# complex_id         sr:complex:33264
# complex_name    Baku Tennis Academy
# Name: 78, dtype: object
# Inserting: ('sr:complex:33264', 'Baku Tennis Academy')
# ----------------------
#
# complex_id      sr:complex:33266
# complex_name      Sobeys Stadium
# Name: 79, dtype: object
# Inserting: ('sr:complex:33266', 'Sobeys Stadium')
# ----------------------
#
# complex_id                  sr:complex:33268
# complex_name    Lindner Family Tennis Center
# Name: 80, dtype: object
# Inserting: ('sr:complex:33268', 'Lindner Family Tennis Center')
# ----------------------
#
# complex_id          sr:complex:33270
# complex_name    Taube Tennis Stadium
# Name: 81, dtype: object
# Inserting: ('sr:complex:33270', 'Taube Tennis Stadium')
# ----------------------
#
# complex_id               sr:complex:33274
# complex_name    Tennis Club de Strasbourg
# Name: 82, dtype: object
# Inserting: ('sr:complex:33274', 'Tennis Club de Strasbourg')
# ----------------------
#
# complex_id           sr:complex:33276
# complex_name    Edgbaston Priory Club
# Name: 83, dtype: object
# Inserting: ('sr:complex:33276', 'Edgbaston Priory Club')
# ----------------------
#
# complex_id                    sr:complex:33278
# complex_name    Royal Tennis Club de Marrakech
# Name: 84, dtype: object
# Inserting: ('sr:complex:33278', 'Royal Tennis Club de Marrakech')
# ----------------------
#
# complex_id       sr:complex:33280
# complex_name    Tennis Club 1.FCN
# Name: 85, dtype: object
# Inserting: ('sr:complex:33280', 'Tennis Club 1.FCN')
# ----------------------
#
# complex_id                                 sr:complex:33282
# complex_name    Devonshire Park International Tennis Centre
# Name: 86, dtype: object
# Inserting: ('sr:complex:33282', 'Devonshire Park International Tennis Centre')
# ----------------------
#
# complex_id              sr:complex:33286
# complex_name    Tennis Club Sparta Praha
# Name: 87, dtype: object
# Inserting: ('sr:complex:33286', 'Tennis Club Sparta Praha')
# ----------------------
#
# complex_id              sr:complex:33288
# complex_name    Club Campestre El Rancho
# Name: 88, dtype: object
# Inserting: ('sr:complex:33288', 'Club Campestre El Rancho')
# ----------------------
#
# complex_id                                   sr:complex:33290
# complex_name    Khalifa International Tennis & Squash Complex
# Name: 89, dtype: object
# Inserting: ('sr:complex:33290', 'Khalifa International Tennis & Squash Complex')
# ----------------------
#
# complex_id      sr:complex:33292
# complex_name         Club Sonoma
# Name: 90, dtype: object
# Inserting: ('sr:complex:33292', 'Club Sonoma')
# ----------------------
#
# complex_id                              sr:complex:33294
# complex_name    Centre Municipal de Tennis Vall d Hebron
# Name: 91, dtype: object
# Inserting: ('sr:complex:33294', 'Centre Municipal de Tennis Vall d Hebron')
# ----------------------
#
# complex_id            sr:complex:33296
# complex_name    Jockey Club Brasileiro
# Name: 92, dtype: object
# Inserting: ('sr:complex:33296', 'Jockey Club Brasileiro')
# ----------------------
#
# complex_id                      sr:complex:33298
# complex_name    Acapulco Princess Mundo Imperial
# Name: 93, dtype: object
# Inserting: ('sr:complex:33298', 'Acapulco Princess Mundo Imperial')
# ----------------------
#
# complex_id                   sr:complex:33300
# complex_name    Tennis Center at Crandon Park
# Name: 94, dtype: object
# Inserting: ('sr:complex:33300', 'Tennis Center at Crandon Park')
# ----------------------
#
# complex_id                 sr:complex:33302
# complex_name    Family Circle Tennis Center
# Name: 95, dtype: object
# Inserting: ('sr:complex:33302', 'Family Circle Tennis Center')
# ----------------------
#
# complex_id                sr:complex:33306
# complex_name    Indian Wells Tennis Garden
# Name: 96, dtype: object
# Inserting: ('sr:complex:33306', 'Indian Wells Tennis Garden')
# ----------------------
#
# complex_id                 sr:complex:33310
# complex_name    Aviation Club Tennis Centre
# Name: 97, dtype: object
# Inserting: ('sr:complex:33310', 'Aviation Club Tennis Centre')
# ----------------------
#
# complex_id                sr:complex:33316
# complex_name    Indianapolis Tennis Center
# Name: 98, dtype: object
# Inserting: ('sr:complex:33316', 'Indianapolis Tennis Center')
# ----------------------
#
# complex_id      sr:complex:33318
# complex_name           SKT Sopot
# Name: 99, dtype: object
# Inserting: ('sr:complex:33318', 'SKT Sopot')
# ----------------------
#
# complex_id           sr:complex:33320
# complex_name    St. Jakobshalle Basel
# Name: 100, dtype: object
# Inserting: ('sr:complex:33320', 'St. Jakobshalle Basel')
# ----------------------
#
# complex_id             sr:complex:33322
# complex_name    Wien, Wiener Stadthalle
# Name: 101, dtype: object
# Inserting: ('sr:complex:33322', 'Wien, Wiener Stadthalle')
# ----------------------
#
# complex_id      sr:complex:33324
# complex_name             L'Agora
# Name: 102, dtype: object
# Inserting: ('sr:complex:33324', "L'Agora")
# ----------------------
#
# complex_id       sr:complex:33328
# complex_name    ASB Tennis Centre
# Name: 103, dtype: object
# Inserting: ('sr:complex:33328', 'ASB Tennis Centre')
# ----------------------
#
# complex_id       sr:complex:33332
# complex_name    NSW Tennis Centre
# Name: 104, dtype: object
# Inserting: ('sr:complex:33332', 'NSW Tennis Centre')
# ----------------------
#
# complex_id                     sr:complex:33334
# complex_name    Shenzhen Longgang Sports Center
# Name: 105, dtype: object
# Inserting: ('sr:complex:33334', 'Shenzhen Longgang Sports Center')
# ----------------------
#
# complex_id              sr:complex:33336
# complex_name    Queensland Tennis Centre
# Name: 106, dtype: object
# Inserting: ('sr:complex:33336', 'Queensland Tennis Centre')
# ----------------------
#
# complex_id      sr:complex:33338
# complex_name       Am Rothenbaum
# Name: 107, dtype: object
# Inserting: ('sr:complex:33338', 'Am Rothenbaum')
# ----------------------
#
# complex_id           sr:complex:33340
# complex_name    Kungliga Tennishallen
# Name: 108, dtype: object
# Inserting: ('sr:complex:33340', 'Kungliga Tennishallen')
# ----------------------
#
# complex_id                        sr:complex:33342
# complex_name    Kitzbuehel Tennis Club Sportfeld 2
# Name: 109, dtype: object
# Inserting: ('sr:complex:33342', 'Kitzbuehel Tennis Club Sportfeld 2')
# ----------------------
#
# complex_id      sr:complex:33344
# complex_name     The Queens Club
# Name: 110, dtype: object
# Inserting: ('sr:complex:33344', 'The Queens Club')
# ----------------------
#
# complex_id         sr:complex:33346
# complex_name    Gerry Weber Stadium
# Name: 111, dtype: object
# Inserting: ('sr:complex:33346', 'Gerry Weber Stadium')
# ----------------------
#
# complex_id              sr:complex:33348
# complex_name    Nottingham Tennis Centre
# Name: 112, dtype: object
# Inserting: ('sr:complex:33348', 'Nottingham Tennis Centre')
# ----------------------
#
# complex_id           sr:complex:33350
# complex_name    Bastad Tennis Stadium
# Name: 113, dtype: object
# Inserting: ('sr:complex:33350', 'Bastad Tennis Stadium')
# ----------------------
#
# complex_id           sr:complex:33354
# complex_name    Nice Lawn Tennis Club
# Name: 114, dtype: object
# Inserting: ('sr:complex:33354', 'Nice Lawn Tennis Club')
# ----------------------
#
# complex_id           sr:complex:33356
# complex_name    Tennis Club de Geneve
# Name: 115, dtype: object
# Inserting: ('sr:complex:33356', 'Tennis Club de Geneve')
# ----------------------
#
# complex_id                 sr:complex:33358
# complex_name    Koza World of Sport Complex
# Name: 116, dtype: object
# Inserting: ('sr:complex:33358', 'Koza World of Sport Complex')
# ----------------------
#
# complex_id            sr:complex:33362
# complex_name    Tennis Club Weissenhof
# Name: 117, dtype: object
# Inserting: ('sr:complex:33362', 'Tennis Club Weissenhof')
# ----------------------
#
# complex_id       sr:complex:33364
# complex_name    Autotron Rosmalen
# Name: 118, dtype: object
# Inserting: ('sr:complex:33364', 'Autotron Rosmalen')
# ----------------------
#
# complex_id      sr:complex:33366
# complex_name           BNR arena
# Name: 119, dtype: object
# Inserting: ('sr:complex:33366', 'BNR arena')
# ----------------------
#
# complex_id       sr:complex:33368
# complex_name    MTTC Iphitos e.V.
# Name: 120, dtype: object
# Inserting: ('sr:complex:33368', 'MTTC Iphitos e.V.')
# ----------------------
#
# complex_id                  sr:complex:33372
# complex_name    Real Club de Tenis Barcelona
# Name: 121, dtype: object
# Inserting: ('sr:complex:33372', 'Real Club de Tenis Barcelona')
# ----------------------
#
# complex_id             sr:complex:33374
# complex_name    Hiroshima Regional Park
# Name: 122, dtype: object
# Inserting: ('sr:complex:33374', 'Hiroshima Regional Park')
# ----------------------
#
# complex_id          sr:complex:33380
# complex_name    Europe Tennis Center
# Name: 123, dtype: object
# Inserting: ('sr:complex:33380', 'Europe Tennis Center')
# ----------------------
#
# complex_id             sr:complex:33382
# complex_name    Tennis Club Lido Lugano
# Name: 124, dtype: object
# Inserting: ('sr:complex:33382', 'Tennis Club Lido Lugano')
# ----------------------
#
# complex_id           sr:complex:33386
# complex_name    Nemzeti Edzes Kozpont
# Name: 125, dtype: object
# Inserting: ('sr:complex:33386', 'Nemzeti Edzes Kozpont')
# ----------------------
#
# complex_id      sr:complex:33390
# complex_name    Lyon Tennis Club
# Name: 126, dtype: object
# Inserting: ('sr:complex:33390', 'Lyon Tennis Club')
# ----------------------
#
# complex_id                         sr:complex:33392
# complex_name    Sichuan International Tennis Center
# Name: 127, dtype: object
# Inserting: ('sr:complex:33392', 'Sichuan International Tennis Center')
# ----------------------
#
# complex_id        sr:complex:33394
# complex_name    Swiss Tennis Arena
# Name: 128, dtype: object
# Inserting: ('sr:complex:33394', 'Swiss Tennis Arena')
# ----------------------
#
# complex_id                          sr:complex:33400
# complex_name    Nanchang International Tennis Center
# Name: 129, dtype: object
# Inserting: ('sr:complex:33400', 'Nanchang International Tennis Center')
# ----------------------
#
# complex_id          sr:complex:33402
# complex_name    Louisville Boat Club
# Name: 130, dtype: object
# Inserting: ('sr:complex:33402', 'Louisville Boat Club')
# ----------------------
#
# complex_id      sr:complex:33406
# complex_name          Rochusclub
# Name: 131, dtype: object
# Inserting: ('sr:complex:33406', 'Rochusclub')
# ----------------------
#
# complex_id                  sr:complex:33408
# complex_name    Shenzhen Luohu Tennis Centre
# Name: 132, dtype: object
# Inserting: ('sr:complex:33408', 'Shenzhen Luohu Tennis Centre')
# ----------------------
#
# complex_id             sr:complex:33410
# complex_name    Yang-Ming Tennis Centre
# Name: 133, dtype: object
# Inserting: ('sr:complex:33410', 'Yang-Ming Tennis Centre')
# ----------------------
#
# complex_id              sr:complex:33418
# complex_name    Country Club Santa Ponsa
# Name: 134, dtype: object
# Inserting: ('sr:complex:33418', 'Country Club Santa Ponsa')
# ----------------------
#
# complex_id                 sr:complex:33422
# complex_name    Royal Primerose Tennis Club
# Name: 135, dtype: object
# Inserting: ('sr:complex:33422', 'Royal Primerose Tennis Club')
# ----------------------
#
# complex_id                       sr:complex:33424
# complex_name    The Tennis Center at College Park
# Name: 136, dtype: object
# Inserting: ('sr:complex:33424', 'The Tennis Center at College Park')
# ----------------------
#
# complex_id         sr:complex:33426
# complex_name    Tennis Center Novak
# Name: 137, dtype: object
# Inserting: ('sr:complex:33426', 'Tennis Center Novak')
# ----------------------
#
# complex_id      sr:complex:33428
# complex_name         Farum Arena
# Name: 138, dtype: object
# Inserting: ('sr:complex:33428', 'Farum Arena')
# ----------------------
#
# complex_id               sr:complex:33430
# complex_name    Racquet Club of the South
# Name: 139, dtype: object
# Inserting: ('sr:complex:33430', 'Racquet Club of the South')
# ----------------------
#
# complex_id           sr:complex:33434
# complex_name    Atlanta Athletic Club
# Name: 140, dtype: object
# Inserting: ('sr:complex:33434', 'Atlanta Athletic Club')
# ----------------------
#
# complex_id      sr:complex:33436
# complex_name        Madrid Arena
# Name: 141, dtype: object
# Inserting: ('sr:complex:33436', 'Madrid Arena')
# ----------------------
#
# complex_id                sr:complex:33438
# complex_name    Club Avantage Multi-Sports
# Name: 142, dtype: object
# Inserting: ('sr:complex:33438', 'Club Avantage Multi-Sports')
# ----------------------
#
# complex_id        sr:complex:33440
# complex_name    Rama Gardens Hotel
# Name: 143, dtype: object
# Inserting: ('sr:complex:33440', 'Rama Gardens Hotel')
# ----------------------
#
# complex_id                 sr:complex:33442
# complex_name    Delmar International School
# Name: 144, dtype: object
# Inserting: ('sr:complex:33442', 'Delmar International School')
# ----------------------
#
# complex_id                sr:complex:33444
# complex_name    OMNI LA COSTA RESORT & SPA
# Name: 145, dtype: object
# Inserting: ('sr:complex:33444', 'OMNI LA COSTA RESORT & SPA')
# ----------------------
#
# complex_id       sr:complex:33446
# complex_name    Country Time Club
# Name: 146, dtype: object
# Inserting: ('sr:complex:33446', 'Country Time Club')
# ----------------------
#
# complex_id         sr:complex:33448
# complex_name    ŠRC MARINA PORTOROŽ
# Name: 147, dtype: object
# Inserting: ('sr:complex:33448', 'ŠRC MARINA PORTOROŽ')
# ----------------------
#
# complex_id                  sr:complex:33450
# complex_name    Fangcun Tennis Sports Center
# Name: 148, dtype: object
# Inserting: ('sr:complex:33450', 'Fangcun Tennis Sports Center')
# ----------------------
#
# complex_id           sr:complex:33454
# complex_name    Netaji Indoor Stadium
# Name: 149, dtype: object
# Inserting: ('sr:complex:33454', 'Netaji Indoor Stadium')
# ----------------------
#
# complex_id                              sr:complex:33456
# complex_name    Holiday Inn Crowne Plaza Hotel Asheville
# Name: 150, dtype: object
# Inserting: ('sr:complex:33456', 'Holiday Inn Crowne Plaza Hotel Asheville')
# ----------------------
#
# complex_id              sr:complex:33458
# complex_name    Ligue d'Alsace de Tennis
# Name: 151, dtype: object
# Inserting: ('sr:complex:33458', "Ligue d'Alsace de Tennis")
# ----------------------
#
# complex_id                     sr:complex:33460
# complex_name    I. Czech Lawn Tennis Club Praha
# Name: 152, dtype: object
# Inserting: ('sr:complex:33460', 'I. Czech Lawn Tennis Club Praha')
# ----------------------
#
# complex_id      sr:complex:33462
# complex_name    Fes Country Club
# Name: 153, dtype: object
# Inserting: ('sr:complex:33462', 'Fes Country Club')
# ----------------------
#
# complex_id                sr:complex:33466
# complex_name    Warszawianka Tennis Centre
# Name: 154, dtype: object
# Inserting: ('sr:complex:33466', 'Warszawianka Tennis Centre')
# ----------------------
#
# complex_id      sr:complex:33468
# complex_name      LTTC Rot-Weiss
# Name: 155, dtype: object
# Inserting: ('sr:complex:33468', 'LTTC Rot-Weiss')
# ----------------------
#
# complex_id                     sr:complex:33470
# complex_name    Amelia Island Plantation Resort
# Name: 156, dtype: object
# Inserting: ('sr:complex:33470', 'Amelia Island Plantation Resort')
# ----------------------
#
# complex_id          sr:complex:33472
# complex_name    Romai Tennis Academy
# Name: 157, dtype: object
# Inserting: ('sr:complex:33472', 'Romai Tennis Academy')
# ----------------------
#
# complex_id                     sr:complex:33474
# complex_name    El Recinto Ferial Casa de Campo
# Name: 158, dtype: object
# Inserting: ('sr:complex:33474', 'El Recinto Ferial Casa de Campo')
# ----------------------
#
# complex_id      sr:complex:33476
# complex_name        Impact Arena
# Name: 159, dtype: object
# Inserting: ('sr:complex:33476', 'Impact Arena')
# ----------------------
#
# complex_id                  sr:complex:33478
# complex_name    Tokyo Metropolitan Gymnasium
# Name: 160, dtype: object
# Inserting: ('sr:complex:33478', 'Tokyo Metropolitan Gymnasium')
# ----------------------
#
# complex_id                     sr:complex:33482
# complex_name    Sporting Club de Tenis Valencia
# Name: 161, dtype: object
# Inserting: ('sr:complex:33482', 'Sporting Club de Tenis Valencia')
# ----------------------
#
# complex_id             sr:complex:33484
# complex_name    Pörtschach Werzer Arena
# Name: 162, dtype: object
# Inserting: ('sr:complex:33484', 'Pörtschach Werzer Arena')
# ----------------------
#
# complex_id                     sr:complex:33486
# complex_name    Club Naval de Campo las Salinas
# Name: 163, dtype: object
# Inserting: ('sr:complex:33486', 'Club Naval de Campo las Salinas')
# ----------------------
#
# complex_id      sr:complex:33488
# complex_name    Hilton DFW Lakes
# Name: 164, dtype: object
# Inserting: ('sr:complex:33488', 'Hilton DFW Lakes')
# ----------------------
#
# complex_id              sr:complex:33490
# complex_name    Sportingclub Bokkeduinen
# Name: 165, dtype: object
# Inserting: ('sr:complex:33490', 'Sportingclub Bokkeduinen')
# ----------------------
#
# complex_id         sr:complex:33492
# complex_name    Baku Tennis Academy
# Name: 166, dtype: object
# Inserting: ('sr:complex:33492', 'Baku Tennis Academy')
# ----------------------
#
# complex_id                                  sr:complex:33808
# complex_name    USTA Billie Jean King National Tennis Center
# Name: 167, dtype: object
# Inserting: ('sr:complex:33808', 'USTA Billie Jean King National Tennis Center')
# ----------------------
#
# complex_id      sr:complex:34336
# complex_name      Emirates Arena
# Name: 168, dtype: object
# Inserting: ('sr:complex:34336', 'Emirates Arena')
# ----------------------
#
# complex_id      sr:complex:34586
# complex_name       Lanxess Arena
# Name: 169, dtype: object
# Inserting: ('sr:complex:34586', 'Lanxess Arena')
# ----------------------
#
# complex_id            sr:complex:34736
# complex_name    Tiburon Peninsula Club
# Name: 170, dtype: object
# Inserting: ('sr:complex:34736', 'Tiburon Peninsula Club')
# ----------------------
#
# complex_id            sr:complex:34766
# complex_name    Country Club de Bogota
# Name: 171, dtype: object
# Inserting: ('sr:complex:34766', 'Country Club de Bogota')
# ----------------------
#
# complex_id          sr:complex:34812
# complex_name    Almaty Tennis Center
# Name: 172, dtype: object
# Inserting: ('sr:complex:34812', 'Almaty Tennis Center')
# ----------------------
#
# complex_id                  sr:complex:34814
# complex_name    Sociedade Hipica de Campinas
# Name: 173, dtype: object
# Inserting: ('sr:complex:34814', 'Sociedade Hipica de Campinas')
# ----------------------
#
# complex_id                  sr:complex:34816
# complex_name    Eve Zimmermann Tennis Center
# Name: 174, dtype: object
# Inserting: ('sr:complex:34816', 'Eve Zimmermann Tennis Center')
# ----------------------
#
# complex_id                     sr:complex:34896
# complex_name    Circolo del Tennis Firenze 1898
# Name: 175, dtype: object
# Inserting: ('sr:complex:34896', 'Circolo del Tennis Firenze 1898')
# ----------------------
#
# complex_id                  sr:complex:35048
# complex_name    Sanchez-Casal Tennis Academy
# Name: 176, dtype: object
# Inserting: ('sr:complex:35048', 'Sanchez-Casal Tennis Academy')
# ----------------------
#
# complex_id                        sr:complex:35052
# complex_name    Santo Domingo Tennis Club La Bocha
# Name: 177, dtype: object
# Inserting: ('sr:complex:35052', 'Santo Domingo Tennis Club La Bocha')
# ----------------------
#
# complex_id                            sr:complex:35054
# complex_name    Solano Community College Tennis Center
# Name: 178, dtype: object
# Inserting: ('sr:complex:35054', 'Solano Community College Tennis Center')
# ----------------------
#
# complex_id      sr:complex:35142
# complex_name         Lotto Arena
# Name: 179, dtype: object
# Inserting: ('sr:complex:35142', 'Lotto Arena')
# ----------------------
#
# complex_id      sr:complex:35212
# complex_name         TC Ismaning
# Name: 180, dtype: object
# Inserting: ('sr:complex:35212', 'TC Ismaning')
# ----------------------
#
# complex_id                          sr:complex:35214
# complex_name    Osten & Victor Alberta Tennis Centre
# Name: 181, dtype: object
# Inserting: ('sr:complex:35214', 'Osten & Victor Alberta Tennis Centre')
# ----------------------
#
# complex_id                                   sr:complex:35236
# complex_name    Ningbo Tennis Center of WTA Ningbo, China w42
# Name: 182, dtype: object
# Inserting: ('sr:complex:35236', 'Ningbo Tennis Center of WTA Ningbo, China w42')
# ----------------------
#
# complex_id                            sr:complex:35290
# complex_name    Club Tennis Las Terrazas de Miraflores
# Name: 183, dtype: object
# Inserting: ('sr:complex:35290', 'Club Tennis Las Terrazas de Miraflores')
# ----------------------
#
# complex_id           sr:complex:35292
# complex_name    Liuzhou Tennis Center
# Name: 184, dtype: object
# Inserting: ('sr:complex:35292', 'Liuzhou Tennis Center')
# ----------------------
#
# complex_id                           sr:complex:35458
# complex_name    Shree Shiv Chhatrapati Sports Complex
# Name: 185, dtype: object
# Inserting: ('sr:complex:35458', 'Shree Shiv Chhatrapati Sports Complex')
# ----------------------
#
# complex_id                 sr:complex:35512
# complex_name    The Boar's Head Sports Club
# Name: 186, dtype: object
# Inserting: ('sr:complex:35512', "The Boar's Head Sports Club")
# ----------------------
#
# complex_id                sr:complex:35516
# complex_name    Anexo Guayaquil Tenis Club
# Name: 187, dtype: object
# Inserting: ('sr:complex:35516', 'Anexo Guayaquil Tenis Club')
# ----------------------
#
# complex_id      sr:complex:35580
# complex_name          Uber Arena
# Name: 188, dtype: object
# Inserting: ('sr:complex:35580', 'Uber Arena')
# ----------------------
#
# complex_id       sr:complex:35592
# complex_name    Sporting Milano 3
# Name: 189, dtype: object
# Inserting: ('sr:complex:35592', 'Sporting Milano 3')
# ----------------------
#
# complex_id          sr:complex:35638
# complex_name    Fiera Milano stadium
# Name: 190, dtype: object
# Inserting: ('sr:complex:35638', 'Fiera Milano stadium')
# ----------------------
#
# complex_id      sr:complex:35640
# complex_name       AXA Arena NTC
# Name: 191, dtype: object
# Inserting: ('sr:complex:35640', 'AXA Arena NTC')
# ----------------------
#
# complex_id      sr:complex:35642
# complex_name          Vendéspace
# Name: 192, dtype: object
# Inserting: ('sr:complex:35642', 'Vendéspace')
# ----------------------
#
# complex_id               sr:complex:35644
# complex_name    Carrasco Lawn Tennis Club
# Name: 193, dtype: object
# Inserting: ('sr:complex:35644', 'Carrasco Lawn Tennis Club')
# ----------------------
#
# complex_id                     sr:complex:35646
# complex_name    Goodfriend Indoor Tennis Center
# Name: 194, dtype: object
# Inserting: ('sr:complex:35646', 'Goodfriend Indoor Tennis Center')
# ----------------------
#
# complex_id                    sr:complex:35648
# complex_name    Palais des sports de Beaublanc
# Name: 195, dtype: object
# Inserting: ('sr:complex:35648', 'Palais des sports de Beaublanc')
# ----------------------
#
# complex_id                   sr:complex:35684
# complex_name    Miki Disaster Management Park
# Name: 196, dtype: object
# Inserting: ('sr:complex:35684', 'Miki Disaster Management Park')
# ----------------------
#
# complex_id                             sr:complex:35688
# complex_name    Karnataka State Lawn Tennis Association
# Name: 197, dtype: object
# Inserting: ('sr:complex:35688', 'Karnataka State Lawn Tennis Association')
# ----------------------
#
# complex_id            sr:complex:35690
# complex_name    Racket Club, Argentina
# Name: 198, dtype: object
# Inserting: ('sr:complex:35690', 'Racket Club, Argentina')
# ----------------------
#
# complex_id          sr:complex:35692
# complex_name    Atkins Tennis Center
# Name: 199, dtype: object
# Inserting: ('sr:complex:35692', 'Atkins Tennis Center')
# ----------------------
#
# complex_id                                       sr:complex:35694
# complex_name    Rice Stadium (Brian Patterson Sports Performan...
# Name: 200, dtype: object
# Inserting: ('sr:complex:35694', 'Rice Stadium (Brian Patterson Sports Performance Center)')
# ----------------------
#
# complex_id                      sr:complex:35870
# complex_name    Mhalunge Balewadi Tennis Complex
# Name: 201, dtype: object
# Inserting: ('sr:complex:35870', 'Mhalunge Balewadi Tennis Complex')
# ----------------------
#
# complex_id            sr:complex:35902
# complex_name    Palazzetto dello Sport
# Name: 202, dtype: object
# Inserting: ('sr:complex:35902', 'Palazzetto dello Sport')
# ----------------------
#
# complex_id      sr:complex:36493
# complex_name    ASB Tennis Arena
# Name: 203, dtype: object
# Inserting: ('sr:complex:36493', 'ASB Tennis Arena')
# ----------------------
#
# complex_id          sr:complex:36495
# complex_name    Domain Tennis Centre
# Name: 204, dtype: object
# Inserting: ('sr:complex:36495', 'Domain Tennis Centre')
# ----------------------
#
# complex_id                      sr:complex:36497
# complex_name    Ohio State Varsity Tennis Center
# Name: 205, dtype: object
# Inserting: ('sr:complex:36497', 'Ohio State Varsity Tennis Center')
# ----------------------
#
# complex_id      sr:complex:36573
# complex_name           EPG Arena
# Name: 206, dtype: object
# Inserting: ('sr:complex:36573', 'EPG Arena')
# ----------------------
#
# complex_id               sr:complex:36783
# complex_name    Newport Beach Tennis Club
# Name: 207, dtype: object
# Inserting: ('sr:complex:36783', 'Newport Beach Tennis Club')
# ----------------------
#
# complex_id        sr:complex:36785
# complex_name    Burnie Tennis Club
# Name: 208, dtype: object
# Inserting: ('sr:complex:36785', 'Burnie Tennis Club')
# ----------------------
#
# complex_id            sr:complex:36787
# complex_name    Cantegril Country Club
# Name: 209, dtype: object
# Inserting: ('sr:complex:36787', 'Cantegril Country Club')
# ----------------------
#
# complex_id        sr:complex:37001
# complex_name    Francoise Savatier
# Name: 210, dtype: object
# Inserting: ('sr:complex:37001', 'Francoise Savatier')
# ----------------------
#
# complex_id        sr:complex:37003
# complex_name    Francoise Savatier
# Name: 211, dtype: object
# Inserting: ('sr:complex:37003', 'Francoise Savatier')
# ----------------------
#
# complex_id          sr:complex:37007
# complex_name    Salle Collete-Benson
# Name: 212, dtype: object
# Inserting: ('sr:complex:37007', 'Salle Collete-Benson')
# ----------------------
#
# complex_id        sr:complex:38029
# complex_name    True Arena Hua Hin
# Name: 213, dtype: object
# Inserting: ('sr:complex:38029', 'True Arena Hua Hin')
# ----------------------
#
# complex_id                       sr:complex:38041
# complex_name    Launceston Regional Tennis Centre
# Name: 214, dtype: object
# Inserting: ('sr:complex:38041', 'Launceston Regional Tennis Centre')
# ----------------------
#
# complex_id        sr:complex:38043
# complex_name    True Arena Hua Hin
# Name: 215, dtype: object
# Inserting: ('sr:complex:38043', 'True Arena Hua Hin')
# ----------------------
#
# complex_id                              sr:complex:38045
# complex_name    Parc des Expositions Quimper Cornouaille
# Name: 216, dtype: object
# Inserting: ('sr:complex:38045', 'Parc des Expositions Quimper Cornouaille')
# ----------------------
#
# complex_id            sr:complex:38047
# complex_name    Cleveland Racquet Club
# Name: 217, dtype: object
# Inserting: ('sr:complex:38047', 'Cleveland Racquet Club')
# ----------------------
#
# complex_id         sr:complex:38187
# complex_name    Sud de France Arena
# Name: 218, dtype: object
# Inserting: ('sr:complex:38187', 'Sud de France Arena')
# ----------------------
#
# complex_id                  sr:complex:38189
# complex_name    Estadio Mario Alberto Kempes
# Name: 219, dtype: object
# Inserting: ('sr:complex:38189', 'Estadio Mario Alberto Kempes')
# ----------------------
#
# complex_id          sr:complex:38191
# complex_name    T Bar M Racquet Club
# Name: 220, dtype: object
# Inserting: ('sr:complex:38191', 'T Bar M Racquet Club')
# ----------------------
#
# complex_id                       sr:complex:38193
# complex_name    SYMA Sports and Conference Centre
# Name: 221, dtype: object
# Inserting: ('sr:complex:38193', 'SYMA Sports and Conference Centre')
# ----------------------
#
# complex_id         sr:complex:38195
# complex_name    SDAT Tennis Stadium
# Name: 222, dtype: object
# Inserting: ('sr:complex:38195', 'SDAT Tennis Stadium')
# ----------------------
#
# complex_id                     sr:complex:38277
# complex_name    Club Campestre Sede Llanogrande
# Name: 223, dtype: object
# Inserting: ('sr:complex:38277', 'Club Campestre Sede Llanogrande')
# ----------------------
#
# complex_id                  sr:complex:38285
# complex_name    Complexe Sportif Chantereyne
# Name: 224, dtype: object
# Inserting: ('sr:complex:38285', 'Complexe Sportif Chantereyne')
# ----------------------
#
# complex_id                    sr:complex:38313
# complex_name    Dubai Duty Free Tennis Stadium
# Name: 225, dtype: object
# Inserting: ('sr:complex:38313', 'Dubai Duty Free Tennis Stadium')
# ----------------------
#
# complex_id              sr:complex:38315
# complex_name    Hotel Racquet Cuernavaca
# Name: 226, dtype: object
# Inserting: ('sr:complex:38315', 'Hotel Racquet Cuernavaca')
# ----------------------
#
# complex_id                sr:complex:38419
# complex_name    Indian Wells Tennis Garden
# Name: 227, dtype: object
# Inserting: ('sr:complex:38419', 'Indian Wells Tennis Garden')
# ----------------------
#
# complex_id                                sr:complex:38421
# complex_name    Mamushidani Tennis Courts, Keio University
# Name: 228, dtype: object
# Inserting: ('sr:complex:38421', 'Mamushidani Tennis Courts, Keio University')
# ----------------------
#
# complex_id              sr:complex:38451
# complex_name    Palais des Sports de Pau
# Name: 229, dtype: object
# Inserting: ('sr:complex:38451', 'Palais des Sports de Pau')
# ----------------------
#
# complex_id           sr:complex:38483
# complex_name    Manquehue Sports Club
# Name: 230, dtype: object
# Inserting: ('sr:complex:38483', 'Manquehue Sports Club')
# ----------------------
#
# complex_id                          sr:complex:38603
# complex_name    Shenzhen International Tennis Center
# Name: 231, dtype: object
# Inserting: ('sr:complex:38603', 'Shenzhen International Tennis Center')
# ----------------------
#
# complex_id              sr:complex:38625
# complex_name    The Phoenix Country Club
# Name: 232, dtype: object
# Inserting: ('sr:complex:38625', 'The Phoenix Country Club')
# ----------------------
#
# complex_id              sr:complex:38631
# complex_name    The Phoenix Country Club
# Name: 233, dtype: object
# Inserting: ('sr:complex:38631', 'The Phoenix Country Club')
# ----------------------
#
# complex_id       sr:complex:38678
# complex_name    Hard Rock Stadium
# Name: 234, dtype: object
# Inserting: ('sr:complex:38678', 'Hard Rock Stadium')
# ----------------------
#
# complex_id                  sr:complex:38680
# complex_name    Centro Panamericano de Tenis
# Name: 235, dtype: object
# Inserting: ('sr:complex:38680', 'Centro Panamericano de Tenis')
# ----------------------
#
# complex_id       sr:complex:38684
# complex_name    Club Los Lagartos
# Name: 236, dtype: object
# Inserting: ('sr:complex:38684', 'Club Los Lagartos')
# ----------------------
#
# complex_id      sr:complex:38690
# complex_name     TK Sparta Praha
# Name: 237, dtype: object
# Inserting: ('sr:complex:38690', 'TK Sparta Praha')
# ----------------------
#
# complex_id               sr:complex:38692
# complex_name    Hot Springs Tennis Center
# Name: 238, dtype: object
# Inserting: ('sr:complex:38692', 'Hot Springs Tennis Center')
# ----------------------
#
# complex_id        sr:complex:38694
# complex_name    Club des Cheminots
# Name: 239, dtype: object
# Inserting: ('sr:complex:38694', 'Club des Cheminots')
# ----------------------
#
# complex_id      sr:complex:38698
# complex_name      La Caja Magica
# Name: 240, dtype: object
# Inserting: ('sr:complex:38698', 'La Caja Magica')
# ----------------------
#
# complex_id         sr:complex:38702
# complex_name    Tennis Club Kastela
# Name: 241, dtype: object
# Inserting: ('sr:complex:38702', 'Tennis Club Kastela')
# ----------------------
#
# complex_id             sr:complex:38704
# complex_name    River Oaks Country Club
# Name: 242, dtype: object
# Inserting: ('sr:complex:38704', 'River Oaks Country Club')
# ----------------------
#
# complex_id            sr:complex:38712
# complex_name    National Tennis Center
# Name: 243, dtype: object
# Inserting: ('sr:complex:38712', 'National Tennis Center')
# ----------------------
#
# complex_id               sr:complex:38716
# complex_name    Clube de Ténis do Estoril
# Name: 244, dtype: object
# Inserting: ('sr:complex:38716', 'Clube de Ténis do Estoril')
# ----------------------
#
# complex_id          sr:complex:38720
# complex_name    Parc De La TeTe D'or
# Name: 245, dtype: object
# Inserting: ('sr:complex:38720', "Parc De La TeTe D'or")
# ----------------------
#
# complex_id              sr:complex:38722
# complex_name    TC Weissenhof, Stuttgart
# Name: 246, dtype: object
# Inserting: ('sr:complex:38722', 'TC Weissenhof, Stuttgart')
# ----------------------
#
# complex_id                         sr:complex:38732
# complex_name    Tennis Club Lillois Lille Metropole
# Name: 247, dtype: object
# Inserting: ('sr:complex:38732', 'Tennis Club Lillois Lille Metropole')
# ----------------------
#
# complex_id                   sr:complex:38856
# complex_name    Sala Polivalenta Piatra Neamt
# Name: 248, dtype: object
# Inserting: ('sr:complex:38856', 'Sala Polivalenta Piatra Neamt')
# ----------------------
#
# complex_id                            sr:complex:38858
# complex_name    The National Tennis Development Center
# Name: 249, dtype: object
# Inserting: ('sr:complex:38858', 'The National Tennis Development Center')
# ----------------------
#
# complex_id                              sr:complex:38862
# complex_name    Complejo Polideportivo de Cuidad Merliot
# Name: 250, dtype: object
# Inserting: ('sr:complex:38862', 'Complejo Polideportivo de Cuidad Merliot')
# ----------------------
#
# complex_id                       sr:complex:38882
# complex_name    JC Ferrero Equelite Sport Academy
# Name: 251, dtype: object
# Inserting: ('sr:complex:38882', 'JC Ferrero Equelite Sport Academy')
# ----------------------
#
# ...
# ----------------------
#
# complex_id          sr:complex:75200
# complex_name    Jurerê Sports Center
# Name: 573, dtype: object
# Inserting: ('sr:complex:75200', 'Jurerê Sports Center')
# ----------------------
#
# complex_id                sr:complex:75607
# complex_name    Bezirksstützpunkt Biberach
# Name: 574, dtype: object
# Inserting: ('sr:complex:75607', 'Bezirksstützpunkt Biberach')
# ----------------------
#
# complex_id      sr:complex:75731
# complex_name         Hala Ricany
# Name: 575, dtype: object
# Inserting: ('sr:complex:75731', 'Hala Ricany')
# ----------------------
#
# complex_id      sr:complex:76035
# complex_name    Vitality Slezsko
# Name: 576, dtype: object
# Inserting: ('sr:complex:76035', 'Vitality Slezsko')
# ----------------------
#
# complex_id            sr:complex:76037
# complex_name    Jockey Club de Rosario
# Name: 577, dtype: object
# Inserting: ('sr:complex:76037', 'Jockey Club de Rosario')
# ----------------------
#
# complex_id        sr:complex:76089
# complex_name    Design Center Linz
# Name: 578, dtype: object
# Inserting: ('sr:complex:76089', 'Design Center Linz')
# ----------------------
#
# complex_id                                       sr:complex:76107
# complex_name    Guangzhou Development District International T...
# Name: 579, dtype: object
# Inserting: ('sr:complex:76107', 'Guangzhou Development District International Tennis School')
# ----------------------
#
# complex_id                   sr:complex:76885
# complex_name    Delhi Lawn Tennis Association
# Name: 580, dtype: object
# Inserting: ('sr:complex:76885', 'Delhi Lawn Tennis Association')
# ----------------------
#
# complex_id            sr:complex:77217
# complex_name    Emilio Sanchez Academy
# Name: 581, dtype: object
# Inserting: ('sr:complex:77217', 'Emilio Sanchez Academy')
# ----------------------
#
# complex_id      sr:complex:77389
# complex_name      Tiriac Stadium
# Name: 582, dtype: object
# Inserting: ('sr:complex:77389', 'Tiriac Stadium')
# ----------------------
#
# complex_id              sr:complex:77391
# complex_name    Tucumán Lawn Tennis Club
# Name: 583, dtype: object
# Inserting: ('sr:complex:77391', 'Tucumán Lawn Tennis Club')
# ----------------------
#
# complex_id       sr:complex:77425
# complex_name    Arena GNP Seguros
# Name: 584, dtype: object
# Inserting: ('sr:complex:77425', 'Arena GNP Seguros')
# ----------------------
#
# complex_id        sr:complex:77517
# complex_name    Club Tennis Lleida
# Name: 585, dtype: object
# Inserting: ('sr:complex:77517', 'Club Tennis Lleida')
# ----------------------
#
# complex_id                      sr:complex:77595
# complex_name    Wuxi International Tennis Center
# Name: 586, dtype: object
# Inserting: ('sr:complex:77595', 'Wuxi International Tennis Center')
# ----------------------
#
# complex_id           sr:complex:77615
# complex_name    Tênis Clube de Santos
# Name: 587, dtype: object
# Inserting: ('sr:complex:77615', 'Tênis Clube de Santos')
# ----------------------
#
# complex_id                  sr:complex:77763
# complex_name    Complexo Desportivo do Jamor
# Name: 588, dtype: object
# Inserting: ('sr:complex:77763', 'Complexo Desportivo do Jamor')
# ----------------------
#
# complex_id          sr:complex:77767
# complex_name    Tennis Club De Tunis
# Name: 589, dtype: object
# Inserting: ('sr:complex:77767', 'Tennis Club De Tunis')
# ----------------------
#
# complex_id          sr:complex:77883
# complex_name    Kachreti Golf Resort
# Name: 590, dtype: object
# Inserting: ('sr:complex:77883', 'Kachreti Golf Resort')
# ----------------------
#
# complex_id          sr:complex:78093
# complex_name    Sports Center Salata
# Name: 591, dtype: object
# Inserting: ('sr:complex:78093', 'Sports Center Salata')
# ----------------------
#
# complex_id            sr:complex:78363
# complex_name    Community Sport Centre
# Name: 592, dtype: object
# Inserting: ('sr:complex:78363', 'Community Sport Centre')
# ----------------------
#
# complex_id           sr:complex:78489
# complex_name    Baza Sportiva Olimpia
# Name: 593, dtype: object
# Inserting: ('sr:complex:78489', 'Baza Sportiva Olimpia')
# ----------------------
#
# complex_id          sr:complex:78753
# complex_name    Sporting Club Verona
# Name: 594, dtype: object
# Inserting: ('sr:complex:78753', 'Sporting Club Verona')
# ----------------------
#
# complex_id                  sr:complex:78831
# complex_name    Victoria Park Tennis Stadium
# Name: 595, dtype: object
# Inserting: ('sr:complex:78831', 'Victoria Park Tennis Stadium')
# ----------------------
#
# complex_id                 sr:complex:79097
# complex_name    Bonn Tennis and Hockey Club
# Name: 596, dtype: object
# Inserting: ('sr:complex:79097', 'Bonn Tennis and Hockey Club')
# ----------------------
#
# complex_id                        sr:complex:79103
# complex_name    Sid And Hazel Dillon Tennis Center
# Name: 597, dtype: object
# Inserting: ('sr:complex:79103', 'Sid And Hazel Dillon Tennis Center')
# ----------------------
#
# complex_id       sr:complex:79281
# complex_name    Tennis Club Izida
# Name: 598, dtype: object
# Inserting: ('sr:complex:79281', 'Tennis Club Izida')
# ----------------------
#
# complex_id        sr:complex:79391
# complex_name    Omega Sport Center
# Name: 599, dtype: object
# Inserting: ('sr:complex:79391', 'Omega Sport Center')
# ----------------------
#
# complex_id             sr:complex:79459
# complex_name    Clube de Tenis do Porto
# Name: 600, dtype: object
# Inserting: ('sr:complex:79459', 'Clube de Tenis do Porto')
# ----------------------
#
# complex_id          sr:complex:79633
# complex_name    Gezira Sporting Club
# Name: 601, dtype: object
# Inserting: ('sr:complex:79633', 'Gezira Sporting Club')
# ----------------------
#
# complex_id          sr:complex:79665
# complex_name    Montreux Tennis Club
# Name: 602, dtype: object
# Inserting: ('sr:complex:79665', 'Montreux Tennis Club')
# ----------------------
#
# complex_id               sr:complex:79837
# complex_name    Club Campestre Farallones
# Name: 603, dtype: object
# Inserting: ('sr:complex:79837', 'Club Campestre Farallones')
# ----------------------
#
# complex_id      sr:complex:79851
# complex_name     Fly Palmy Arena
# Name: 604, dtype: object
# Inserting: ('sr:complex:79851', 'Fly Palmy Arena')
# ----------------------
#
# complex_id           sr:complex:79853
# complex_name    Tennis Club Lokomotiv
# Name: 605, dtype: object
# Inserting: ('sr:complex:79853', 'Tennis Club Lokomotiv')
# ----------------------
#
# complex_id            sr:complex:79855
# complex_name    Palm Hills Sports Club
# Name: 606, dtype: object
# Inserting: ('sr:complex:79855', 'Palm Hills Sports Club')
# ----------------------
#
# complex_id                               sr:complex:79861
# complex_name    Tennis Club de Avenir Sportif de la Marsa
# Name: 607, dtype: object
# Inserting: ('sr:complex:79861', 'Tennis Club de Avenir Sportif de la Marsa')
# ----------------------
#
# complex_id                 sr:complex:80737
# complex_name    International Tennis Center
# Name: 608, dtype: object
# Inserting: ('sr:complex:80737', 'International Tennis Center')
# ----------------------
#
# complex_id       sr:complex:80851
# complex_name    Beograndska Arena
# Name: 609, dtype: object
# Inserting: ('sr:complex:80851', 'Beograndska Arena')
# ----------------------
#
# complex_id      sr:complex:80961
# complex_name        Inalpi Arena
# Name: 610, dtype: object
# Inserting: ('sr:complex:80961', 'Inalpi Arena')
# ----------------------
#
# complex_id                 sr:complex:80963
# complex_name    All In Country Club Decines
# Name: 611, dtype: object
# Inserting: ('sr:complex:80963', 'All In Country Club Decines')
# ----------------------
#
# complex_id                   sr:complex:81249
# complex_name    Las Hadas Golf & Country Club
# Name: 612, dtype: object
# Inserting: ('sr:complex:81249', 'Las Hadas Golf & Country Club')
# ----------------------
#
# complex_id                     sr:complex:81543
# complex_name    Headington Family Tennis Center
# Name: 613, dtype: object
# Inserting: ('sr:complex:81543', 'Headington Family Tennis Center')
# ----------------------
#
# complex_id      sr:complex:81613
# complex_name     Royal SC Tennis
# Name: 614, dtype: object
# Inserting: ('sr:complex:81613', 'Royal SC Tennis')
# ----------------------
#
# complex_id      sr:complex:81635
# complex_name                 LSU
# Name: 615, dtype: object
# Inserting: ('sr:complex:81635', 'LSU')
# ----------------------
#
# complex_id          sr:complex:81651
# complex_name    Robson Tennis Center
# Name: 616, dtype: object
# Inserting: ('sr:complex:81651', 'Robson Tennis Center')
# ----------------------
#
# complex_id               sr:complex:81661
# complex_name    Wake Forest Tennis Center
# Name: 617, dtype: object
# Inserting: ('sr:complex:81661', 'Wake Forest Tennis Center')
# ----------------------
#
# complex_id         sr:complex:81673
# complex_name    Palmira Tennis Club
# Name: 618, dtype: object
# Inserting: ('sr:complex:81673', 'Palmira Tennis Club')
# ----------------------
#
# complex_id                                      sr:complex:81681
# complex_name    Tennis Courts of the SW University Neofit Rilski
# Name: 619, dtype: object
# Inserting: ('sr:complex:81681', 'Tennis Courts of the SW University Neofit Rilski')
# ----------------------
#
# complex_id                sr:complex:81713
# complex_name    Penina Hotel & Golf Resort
# Name: 620, dtype: object
# Inserting: ('sr:complex:81713', 'Penina Hotel & Golf Resort')
# ----------------------
#
# complex_id      sr:complex:81717
# complex_name         Bloomington
# Name: 621, dtype: object
# Inserting: ('sr:complex:81717', 'Bloomington')
# ----------------------
#
# complex_id          sr:complex:81745
# complex_name    Clube Tenis Portimao
# Name: 622, dtype: object
# Inserting: ('sr:complex:81745', 'Clube Tenis Portimao')
# ----------------------
#
# complex_id       sr:complex:81747
# complex_name    Atlantis The Palm
# Name: 623, dtype: object
# Inserting: ('sr:complex:81747', 'Atlantis The Palm')
# ----------------------
#
# complex_id           sr:complex:81751
# complex_name    Kallang Tennis Centre
# Name: 624, dtype: object
# Inserting: ('sr:complex:81751', 'Kallang Tennis Centre')
# ----------------------
#
# complex_id      sr:complex:81779
# complex_name            KPI Park
# Name: 625, dtype: object
# Inserting: ('sr:complex:81779', 'KPI Park')
# ----------------------
#
# complex_id                                       sr:complex:81809
# complex_name    Courts De Tennis De La Cité Nationale Sportive...
# Name: 626, dtype: object
# Inserting: ('sr:complex:81809', 'Courts De Tennis De La Cité Nationale Sportive El Menza')
# ----------------------
#
# complex_id              sr:complex:81811
# complex_name    Sala Polivalenta Craiova
# Name: 627, dtype: object
# Inserting: ('sr:complex:81811', 'Sala Polivalenta Craiova')
# ----------------------
#
# complex_id      sr:complex:81813
# complex_name    New Sport Palace
# Name: 628, dtype: object
# Inserting: ('sr:complex:81813', 'New Sport Palace')
# ----------------------
#
# complex_id          sr:complex:81815
# complex_name    Complejo de Raquetas
# Name: 629, dtype: object
# Inserting: ('sr:complex:81815', 'Complejo de Raquetas')
# ----------------------
#
# complex_id      sr:complex:81817
# complex_name        DLTA Complex
# Name: 630, dtype: object
# Inserting: ('sr:complex:81817', 'DLTA Complex')
# ----------------------
#
# complex_id              sr:complex:81819
# complex_name    Monte-Carlo Country Club
# Name: 631, dtype: object
# Inserting: ('sr:complex:81819', 'Monte-Carlo Country Club')
# ----------------------
#
# complex_id                  sr:complex:81821
# complex_name    TENIS ESKRIM DAGCILIK KULÜBÜ
# Name: 632, dtype: object
# Inserting: ('sr:complex:81821', 'TENIS ESKRIM DAGCILIK KULÜBÜ')
# ----------------------
#
# complex_id      sr:complex:81823
# complex_name       Beeline Arena
# Name: 633, dtype: object
# Inserting: ('sr:complex:81823', 'Beeline Arena')
# ----------------------
#
# complex_id      sr:complex:81827
# complex_name    Coque Luxenbourg
# Name: 634, dtype: object
# Inserting: ('sr:complex:81827', 'Coque Luxenbourg')
# ----------------------
#
# complex_id        sr:complex:81977
# complex_name    Green Tennis Plaza
# Name: 635, dtype: object
# Inserting: ('sr:complex:81977', 'Green Tennis Plaza')
# ----------------------
#
# complex_id                                       sr:complex:81985
# complex_name    Boulevard de las Naciones and Paseo de los Man...
# Name: 636, dtype: object
# Inserting: ('sr:complex:81985', 'Boulevard de las Naciones and Paseo de los Manglares')
# ----------------------
#
# complex_id      sr:complex:81995
# complex_name    Georgia Gwinnett
# Name: 637, dtype: object
# Inserting: ('sr:complex:81995', 'Georgia Gwinnett')
# ----------------------
#
# complex_id                 sr:complex:82007
# complex_name    Sport Center Visnjik (Clay)
# Name: 638, dtype: object
# Inserting: ('sr:complex:82007', 'Sport Center Visnjik (Clay)')
# ----------------------
#
# complex_id              sr:complex:82033
# complex_name    Spot - Salle Jean Burger
# Name: 639, dtype: object
# Inserting: ('sr:complex:82033', 'Spot - Salle Jean Burger')
# ----------------------
#
# complex_id      sr:complex:82065
# complex_name      Raquet Village
# Name: 640, dtype: object
# Inserting: ('sr:complex:82065', 'Raquet Village')
# ----------------------
#
# complex_id      sr:complex:82109
# complex_name          Manzanillo
# Name: 641, dtype: object
# Inserting: ('sr:complex:82109', 'Manzanillo')
# ----------------------
#
# complex_id              sr:complex:82131
# complex_name    Club de Golf Tres Marias
# Name: 642, dtype: object
# Inserting: ('sr:complex:82131', 'Club de Golf Tres Marias')
# ----------------------
#
# complex_id                                       sr:complex:82133
# complex_name    Sheraton Buganvilias Resort and Convention Center
# Name: 643, dtype: object
# Inserting: ('sr:complex:82133', 'Sheraton Buganvilias Resort and Convention Center')
# ----------------------
#
# complex_id            sr:complex:82197
# complex_name    Tennis Club Porto Rose
# Name: 644, dtype: object
# Inserting: ('sr:complex:82197', 'Tennis Club Porto Rose')
# ----------------------
#
# complex_id                                sr:complex:82223
# complex_name    Complejo Deportivo San Carlos De Apoquindo
# Name: 645, dtype: object
# Inserting: ('sr:complex:82223', 'Complejo Deportivo San Carlos De Apoquindo')
# ----------------------
#
# complex_id           sr:complex:82243
# complex_name    Club Tenis Ciutadella
# Name: 646, dtype: object
# Inserting: ('sr:complex:82243', 'Club Tenis Ciutadella')
# ----------------------
#
# complex_id              sr:complex:82279
# complex_name    Tenis Club Crvena Zvezda
# Name: 647, dtype: object
# Inserting: ('sr:complex:82279', 'Tenis Club Crvena Zvezda')
# ----------------------
#
# complex_id              sr:complex:82301
# complex_name    Villa Reale Tennis Monza
# Name: 648, dtype: object
# Inserting: ('sr:complex:82301', 'Villa Reale Tennis Monza')
# ----------------------
#
# complex_id              sr:complex:82313
# complex_name    Carvoeiro Clube de Tenis
# Name: 649, dtype: object
# Inserting: ('sr:complex:82313', 'Carvoeiro Clube de Tenis')
# ----------------------
#
# complex_id          sr:complex:82335
# complex_name    Sarasota Sports Club
# Name: 650, dtype: object
# Inserting: ('sr:complex:82335', 'Sarasota Sports Club')
# ----------------------
#
# complex_id            sr:complex:82343
# complex_name    Le Central Tennis Club
# Name: 651, dtype: object
# Inserting: ('sr:complex:82343', 'Le Central Tennis Club')
# ----------------------
#
# complex_id               sr:complex:82356
# complex_name    Dan Maskell Tennis Centre
# Name: 652, dtype: object
# Inserting: ('sr:complex:82356', 'Dan Maskell Tennis Centre')
# ----------------------
#
# complex_id                        sr:complex:82415
# complex_name    George P Mitchell 40 Tennis Center
# Name: 653, dtype: object
# Inserting: ('sr:complex:82415', 'George P Mitchell 40 Tennis Center')
# ----------------------
#
# complex_id            sr:complex:82417
# complex_name    National Tennis Center
# Name: 654, dtype: object
# Inserting: ('sr:complex:82417', 'National Tennis Center')
# ----------------------
#
# complex_id      sr:complex:82467
# complex_name     Tcja Saint-Malo
# Name: 655, dtype: object
# Inserting: ('sr:complex:82467', 'Tcja Saint-Malo')
# ----------------------
#
# complex_id      sr:complex:82469
# complex_name     Club Tennis Vic
# Name: 656, dtype: object
# Inserting: ('sr:complex:82469', 'Club Tennis Vic')
# ----------------------
#
# Data inserted into the complexes_table using iterrows()

# %% [markdown]
# Fetching Data from complexes_table:

# %%
#execute:
mycursor.execute("Select * from complexes_table")

fetching_Data = mycursor.fetchall()
fetching_Data
# Out:
# [('sr:complex:705', 'Nacional'),
#  ('sr:complex:1078', 'Estadio de la Cartuja'),
#  ('sr:complex:1495', 'Sibur Arena'),
#  ('sr:complex:2375', 'Complexo de Tenis do Jamor'),
#  ('sr:complex:4032', 'Shree Shiv Chhatrapati Sports Complex'),
#  ('sr:complex:5520', 'O2 Arena'),
#  ('sr:complex:5526', 'Ostravar Arena'),
#  ('sr:complex:6310', 'Varazdin Arena'),
#  ('sr:complex:6484', 'Arena Montpellier'),
#  ('sr:complex:6736', 'Arenes de Metz'),
#  ('sr:complex:6888', 'Palais des sports de Pau'),
#  ('sr:complex:6890', 'Palais des Sports Orleans'),
#  ('sr:complex:6904', 'Stade Pierre-de-Coubertin'),
#  ('sr:complex:7048', 'Palacio de Deportes Jose Maria Martin Carpena'),
#  ('sr:complex:7052', 'Pabellon Municipal Fuente San Luis'),
#  ('sr:complex:7208', 'Unipol Arena'),
#  ('sr:complex:7778', 'Arena Gripe'),
#  ('sr:complex:9725', 'Arena Armeets Sofia'),
#  ('sr:complex:10063', 'Kindarena'),
#  ('sr:complex:11769', 'Estadio German Becker'),
#  ('sr:complex:12241', 'Palais des sports de Gerland'),
#  ('sr:complex:15014', 'Palais Des Sport'),
#  ('sr:complex:15371', 'Palasport'),
#  ('sr:complex:16020', 'Salle Steredenn'),
#  ('sr:complex:16069', 'Garanti Koza Arena'),
#  ('sr:complex:16612', 'Porsche-Arena'),
#  ('sr:complex:17254', "Poliesportiu d'Andorra"),
#  ('sr:complex:17945', 'Rotterdam Ahoy'),
#  ('sr:complex:18201', 'The O2'),
#  ('sr:complex:18221', 'Bluesun Tennis Center'),
#  ('sr:complex:19166', 'Shlomo Group Arena'),
#  ('sr:complex:19737', 'Club Sonoma, Estadio Gnp Seguros'),
#  ('sr:complex:19951', 'Accor Arena'),
#  ('sr:complex:21870', 'Stadium Goran Ivanisevic in ITC Stella Maris'),
#  ('sr:complex:21910', 'Roy Emerson Arena'),
#  ('sr:complex:26983', 'Club de Tenis Puente Romano'),
#  ('sr:complex:26985', 'National Tennis Center'),
#  ('sr:complex:27093', 'Canberra Tennis Centre'),
#  ('sr:complex:27095', 'BT Arena'),
#  ('sr:complex:28457', 'Valletta Cambiaso ASD'),
#  ('sr:complex:28617', 'Porsche Arena'),
#  ('sr:complex:28926', 'Royal Arena'),
#  ('sr:complex:32327', 'Taipei Arena'),
#  ('sr:complex:32403', 'Ohio State University GC'),
#  ('sr:complex:32668', 'Shenzhen Bay Sports Center'),
#  ('sr:complex:32812', 'Singapore Indoor Stadium'),
#  ('sr:complex:33186', 'Palais des Sports de Marseille'),
#  ('sr:complex:33188', 'Caja Magica'),
#  ('sr:complex:33190', 'All England Lawn Tennis and Croquet Club'),
#  ('sr:complex:33192', 'Stade Roland Garros'),
#  ('sr:complex:33194', 'Complexe Al Amal'),
#  ('sr:complex:33196', 'Melbourne Park'),
#  ('sr:complex:33198', 'Qi zhong Forest Sports City Arena'),
#  ('sr:complex:33200', 'Wake Forest University Tennis Complex'),
#  ('sr:complex:33204', 'Clube de Ténis do Estoril'),
#  ('sr:complex:33206', 'The Drive'),
#  ('sr:complex:33208', 'Atlantic Station'),
#  ('sr:complex:33210', 'International Tennis Hall of Fame'),
#  ('sr:complex:33214', 'Club Jacaranda Cumbaya'),
#  ('sr:complex:33218', 'Hengqin International Tennis Center Zhuhai'),
#  ('sr:complex:33222', 'Buenos Aires Lawn Tennis Club'),
#  ('sr:complex:33226', 'The Racquet Club of Memphis'),
#  ('sr:complex:33228', 'Delray Beach Tennis Center'),
#  ('sr:complex:33230', 'CK Sportcenter Kockelscheuer'),
#  ('sr:complex:33232', 'Singapore Sports Hub'),
#  ('sr:complex:33234', 'Linzer Sporthalle'),
#  ('sr:complex:33236', 'Luzhniki Olympic Complex'),
#  ('sr:complex:33238', 'Ariake Colosseum'),
#  ('sr:complex:33240', 'Optics Valley International Tennis Center'),
#  ('sr:complex:33242', 'Guangzhou Tianhe Sports Center'),
#  ('sr:complex:33244', 'Olympic Park Tennis Center'),
#  ('sr:complex:33246', 'Victoria Park Tennis Court'),
#  ('sr:complex:33248', 'Tianjin Tuanbo International Tennis Center'),
#  ('sr:complex:33250', 'Tashkent Tennis Centreake'),
#  ('sr:complex:33252', 'China National Tennis Center'),
#  ('sr:complex:33254', 'Utsubo Tennis Center'),
#  ('sr:complex:33258', 'Connecticut Tennis Center'),
#  ('sr:complex:33262', 'Santa Catarina Tennis Federation'),
#  ('sr:complex:33264', 'Baku Tennis Academy'),
#  ('sr:complex:33266', 'Sobeys Stadium'),
#  ('sr:complex:33268', 'Lindner Family Tennis Center'),
#  ('sr:complex:33270', 'Taube Tennis Stadium'),
#  ('sr:complex:33274', 'Tennis Club de Strasbourg'),
#  ('sr:complex:33276', 'Edgbaston Priory Club'),
#  ('sr:complex:33278', 'Royal Tennis Club de Marrakech'),
#  ('sr:complex:33280', 'Tennis Club 1.FCN'),
#  ('sr:complex:33282', 'Devonshire Park International Tennis Centre'),
#  ('sr:complex:33286', 'Tennis Club Sparta Praha'),
#  ('sr:complex:33288', 'Club Campestre El Rancho'),
#  ('sr:complex:33290', 'Khalifa International Tennis & Squash Complex'),
#  ('sr:complex:33292', 'Club Sonoma'),
#  ('sr:complex:33294', 'Centre Municipal de Tennis Vall d Hebron'),
#  ('sr:complex:33296', 'Jockey Club Brasileiro'),
#  ('sr:complex:33298', 'Acapulco Princess Mundo Imperial'),
#  ('sr:complex:33300', 'Tennis Center at Crandon Park'),
#  ('sr:complex:33302', 'Family Circle Tennis Center'),
#  ('sr:complex:33306', 'Indian Wells Tennis Garden'),
#  ('sr:complex:33310', 'Aviation Club Tennis Centre'),
#  ('sr:complex:33316', 'Indianapolis Tennis Center'),
#  ('sr:complex:33318', 'SKT Sopot'),
#  ('sr:complex:33320', 'St. Jakobshalle Basel'),
#  ('sr:complex:33322', 'Wien, Wiener Stadthalle'),
#  ('sr:complex:33324', "L'Agora"),
#  ('sr:complex:33328', 'ASB Tennis Centre'),
#  ('sr:complex:33332', 'NSW Tennis Centre'),
#  ('sr:complex:33334', 'Shenzhen Longgang Sports Center'),
#  ('sr:complex:33336', 'Queensland Tennis Centre'),
#  ('sr:complex:33338', 'Am Rothenbaum'),
#  ('sr:complex:33340', 'Kungliga Tennishallen'),
#  ('sr:complex:33342', 'Kitzbuehel Tennis Club Sportfeld 2'),
#  ('sr:complex:33344', 'The Queens Club'),
#  ('sr:complex:33346', 'Gerry Weber Stadium'),
#  ('sr:complex:33348', 'Nottingham Tennis Centre'),
#  ('sr:complex:33350', 'Bastad Tennis Stadium'),
#  ('sr:complex:33354', 'Nice Lawn Tennis Club'),
#  ('sr:complex:33356', 'Tennis Club de Geneve'),
#  ('sr:complex:33358', 'Koza World of Sport Complex'),
#  ('sr:complex:33362', 'Tennis Club Weissenhof'),
#  ('sr:complex:33364', 'Autotron Rosmalen'),
#  ('sr:complex:33366', 'BNR arena'),
#  ('sr:complex:33368', 'MTTC Iphitos e.V.'),
#  ('sr:complex:33372', 'Real Club de Tenis Barcelona'),
#  ('sr:complex:33374', 'Hiroshima Regional Park'),
#  ('sr:complex:33380', 'Europe Tennis Center'),
#  ('sr:complex:33382', 'Tennis Club Lido Lugano'),
#  ('sr:complex:33386', 'Nemzeti Edzes Kozpont'),
#  ('sr:complex:33390', 'Lyon Tennis Club'),
#  ('sr:complex:33392', 'Sichuan International Tennis Center'),
#  ('sr:complex:33394', 'Swiss Tennis Arena'),
#  ('sr:complex:33400', 'Nanchang International Tennis Center'),
#  ('sr:complex:33402', 'Louisville Boat Club'),
#  ('sr:complex:33406', 'Rochusclub'),
#  ('sr:complex:33408', 'Shenzhen Luohu Tennis Centre'),
#  ('sr:complex:33410', 'Yang-Ming Tennis Centre'),
#  ('sr:complex:33418', 'Country Club Santa Ponsa'),
#  ('sr:complex:33422', 'Royal Primerose Tennis Club'),
#  ('sr:complex:33424', 'The Tennis Center at College Park'),
#  ('sr:complex:33426', 'Tennis Center Novak'),
#  ('sr:complex:33428', 'Farum Arena'),
#  ('sr:complex:33430', 'Racquet Club of the South'),
#  ('sr:complex:33434', 'Atlanta Athletic Club'),
#  ('sr:complex:33436', 'Madrid Arena'),
#  ('sr:complex:33438', 'Club Avantage Multi-Sports'),
#  ('sr:complex:33440', 'Rama Gardens Hotel'),
#  ('sr:complex:33442', 'Delmar International School'),
#  ('sr:complex:33444', 'OMNI LA COSTA RESORT & SPA'),
#  ('sr:complex:33446', 'Country Time Club'),
#  ('sr:complex:33448', 'ŠRC MARINA PORTOROŽ'),
#  ('sr:complex:33450', 'Fangcun Tennis Sports Center'),
#  ('sr:complex:33454', 'Netaji Indoor Stadium'),
#  ('sr:complex:33456', 'Holiday Inn Crowne Plaza Hotel Asheville'),
#  ('sr:complex:33458', "Ligue d'Alsace de Tennis"),
#  ('sr:complex:33460', 'I. Czech Lawn Tennis Club Praha'),
#  ('sr:complex:33462', 'Fes Country Club'),
#  ('sr:complex:33466', 'Warszawianka Tennis Centre'),
#  ('sr:complex:33468', 'LTTC Rot-Weiss'),
#  ('sr:complex:33470', 'Amelia Island Plantation Resort'),
#  ('sr:complex:33472', 'Romai Tennis Academy'),
#  ('sr:complex:33474', 'El Recinto Ferial Casa de Campo'),
#  ('sr:complex:33476', 'Impact Arena'),
#  ('sr:complex:33478', 'Tokyo Metropolitan Gymnasium'),
#  ('sr:complex:33482', 'Sporting Club de Tenis Valencia'),
#  ('sr:complex:33484', 'Pörtschach Werzer Arena'),
#  ('sr:complex:33486', 'Club Naval de Campo las Salinas'),
#  ('sr:complex:33488', 'Hilton DFW Lakes'),
#  ('sr:complex:33490', 'Sportingclub Bokkeduinen'),
#  ('sr:complex:33492', 'Baku Tennis Academy'),
#  ('sr:complex:33808', 'USTA Billie Jean King National Tennis Center'),
#  ('sr:complex:34336', 'Emirates Arena'),
#  ('sr:complex:34586', 'Lanxess Arena'),
#  ('sr:complex:34736', 'Tiburon Peninsula Club'),
#  ('sr:complex:34766', 'Country Club de Bogota'),
#  ('sr:complex:34812', 'Almaty Tennis Center'),
#  ('sr:complex:34814', 'Sociedade Hipica de Campinas'),
#  ('sr:complex:34816', 'Eve Zimmermann Tennis Center'),
#  ('sr:complex:34896', 'Circolo del Tennis Firenze 1898'),
#  ('sr:complex:35048', 'Sanchez-Casal Tennis Academy'),
#  ('sr:complex:35052', 'Santo Domingo Tennis Club La Bocha'),
#  ('sr:complex:35054', 'Solano Community College Tennis Center'),
#  ('sr:complex:35142', 'Lotto Arena'),
#  ('sr:complex:35212', 'TC Ismaning'),
#  ('sr:complex:35214', 'Osten & Victor Alberta Tennis Centre'),
#  ('sr:complex:35236', 'Ningbo Tennis Center of WTA Ningbo, China w42'),
#  ('sr:complex:35290', 'Club Tennis Las Terrazas de Miraflores'),
#  ('sr:complex:35292', 'Liuzhou Tennis Center'),
#  ('sr:complex:35458', 'Shree Shiv Chhatrapati Sports Complex'),
#  ('sr:complex:35512', "The Boar's Head Sports Club"),
#  ('sr:complex:35516', 'Anexo Guayaquil Tenis Club'),
#  ('sr:complex:35580', 'Uber Arena'),
#  ('sr:complex:35592', 'Sporting Milano 3'),
#  ('sr:complex:35638', 'Fiera Milano stadium'),
#  ('sr:complex:35640', 'AXA Arena NTC'),
#  ('sr:complex:35642', 'Vendéspace'),
#  ('sr:complex:35644', 'Carrasco Lawn Tennis Club'),
#  ('sr:complex:35646', 'Goodfriend Indoor Tennis Center'),
#  ('sr:complex:35648', 'Palais des sports de Beaublanc'),
#  ('sr:complex:35684', 'Miki Disaster Management Park'),
#  ('sr:complex:35688', 'Karnataka State Lawn Tennis Association'),
#  ('sr:complex:35690', 'Racket Club, Argentina'),
#  ('sr:complex:35692', 'Atkins Tennis Center'),
#  ('sr:complex:35694',
#   'Rice Stadium (Brian Patterson Sports Performance Center)'),
#  ('sr:complex:35870', 'Mhalunge Balewadi Tennis Complex'),
#  ('sr:complex:35902', 'Palazzetto dello Sport'),
#  ('sr:complex:36493', 'ASB Tennis Arena'),
#  ('sr:complex:36495', 'Domain Tennis Centre'),
#  ('sr:complex:36497', 'Ohio State Varsity Tennis Center'),
#  ('sr:complex:36573', 'EPG Arena'),
#  ('sr:complex:36783', 'Newport Beach Tennis Club'),
#  ('sr:complex:36785', 'Burnie Tennis Club'),
#  ('sr:complex:36787', 'Cantegril Country Club'),
#  ('sr:complex:37001', 'Francoise Savatier'),
#  ('sr:complex:37003', 'Francoise Savatier'),
#  ('sr:complex:37007', 'Salle Collete-Benson'),
#  ('sr:complex:38029', 'True Arena Hua Hin'),
#  ('sr:complex:38041', 'Launceston Regional Tennis Centre'),
#  ('sr:complex:38043', 'True Arena Hua Hin'),
#  ('sr:complex:38045', 'Parc des Expositions Quimper Cornouaille'),
#  ('sr:complex:38047', 'Cleveland Racquet Club'),
#  ('sr:complex:38187', 'Sud de France Arena'),
#  ('sr:complex:38189', 'Estadio Mario Alberto Kempes'),
#  ('sr:complex:38191', 'T Bar M Racquet Club'),
#  ('sr:complex:38193', 'SYMA Sports and Conference Centre'),
#  ('sr:complex:38195', 'SDAT Tennis Stadium'),
#  ('sr:complex:38277', 'Club Campestre Sede Llanogrande'),
#  ('sr:complex:38285', 'Complexe Sportif Chantereyne'),
#  ('sr:complex:38313', 'Dubai Duty Free Tennis Stadium'),
#  ('sr:complex:38315', 'Hotel Racquet Cuernavaca'),
#  ('sr:complex:38419', 'Indian Wells Tennis Garden'),
#  ('sr:complex:38421', 'Mamushidani Tennis Courts, Keio University'),
#  ('sr:complex:38451', 'Palais des Sports de Pau'),
#  ('sr:complex:38483', 'Manquehue Sports Club'),
#  ('sr:complex:38603', 'Shenzhen International Tennis Center'),
#  ('sr:complex:38625', 'The Phoenix Country Club'),
#  ('sr:complex:38631', 'The Phoenix Country Club'),
#  ('sr:complex:38678', 'Hard Rock Stadium'),
#  ('sr:complex:38680', 'Centro Panamericano de Tenis'),
#  ('sr:complex:38684', 'Club Los Lagartos'),
#  ('sr:complex:38690', 'TK Sparta Praha'),
#  ('sr:complex:38692', 'Hot Springs Tennis Center'),
#  ('sr:complex:38694', 'Club des Cheminots'),
#  ('sr:complex:38698', 'La Caja Magica'),
#  ('sr:complex:38702', 'Tennis Club Kastela'),
#  ('sr:complex:38704', 'River Oaks Country Club'),
#  ('sr:complex:38712', 'National Tennis Center'),
#  ('sr:complex:38716', 'Clube de Ténis do Estoril'),
#  ('sr:complex:38720', "Parc De La TeTe D'or"),
#  ('sr:complex:38722', 'TC Weissenhof, Stuttgart'),
#  ('sr:complex:38732', 'Tennis Club Lillois Lille Metropole'),
#  ('sr:complex:38856', 'Sala Polivalenta Piatra Neamt'),
#  ('sr:complex:38858', 'The National Tennis Development Center'),
#  ('sr:complex:38862', 'Complejo Polideportivo de Cuidad Merliot'),
#  ('sr:complex:38882', 'JC Ferrero Equelite Sport Academy'),
#  ('sr:complex:38884', 'Mouratoglou Tennis Academy'),
#  ('sr:complex:38986', 'National Taiwan University Sports Center'),
#  ('sr:complex:38988', 'Circolo Tennis Barletta'),
#  ('sr:complex:38990', 'Murcia Tennis Club 1919'),
#  ('sr:complex:39000', 'El Club el Carmel'),
#  ('sr:complex:39093', 'Laurel Oak Country Club'),
#  ('sr:complex:39095', 'Club Deportivo Potosino'),
#  ('sr:complex:39097', 'Au Tennis Club De Tunis'),
#  ('sr:complex:39167', 'Tali Tennis Center'),
#  ('sr:complex:39377', 'Jinwol International Tennis Court'),
#  ('sr:complex:39379', 'Tennis Club Dinamo'),
#  ('sr:complex:39381', 'Tennisclub Heilbronn am Trappensee'),
#  ('sr:complex:39383', 'Club Internacional de Foot-ball'),
#  ('sr:complex:39483', 'Israel Tennis Center'),
#  ('sr:complex:39491', "The Queen's Club"),
#  ('sr:complex:39493', 'Kaya Palazzo Belek'),
#  ('sr:complex:39503', 'Fitzerald Tennis Center Rock Creek Park'),
#  ('sr:complex:39505', 'Delmar International School'),
#  ('sr:complex:39507', 'Tennis Club du Stade-Lausanne'),
#  ('sr:complex:39509', 'National Tennis Centre Lielupe'),
#  ('sr:complex:39511', 'TC Rüppurr'),
#  ('sr:complex:39513', 'San José State University Tennis Center'),
#  ('sr:complex:39515', 'Stade Iga'),
#  ('sr:complex:39591', 'Tennis Palladio 98'),
#  ('sr:complex:39653', 'Palexpo'),
#  ('sr:complex:39852', 'Club de Campo Villa de Madrid'),
#  ('sr:complex:39864', 'Istiklol Tennis Club'),
#  ('sr:complex:39866', 'AAJB Tennis'),
#  ('sr:complex:39868', 'Tenis Club Parma'),
#  ('sr:complex:39870', 'Ilkley Lawn Tennis and Squash Club'),
#  ('sr:complex:39872', 'NTC Arena'),
#  ('sr:complex:39958', 'RT Torax Arena'),
#  ('sr:complex:40110', 'Aspria Harbor Club'),
#  ('sr:complex:40788', 'Francesco Guzzini Recanati Tennis Club'),
#  ('sr:complex:44124', 'Cary Leeds Center for Tennis & Learning'),
#  ('sr:complex:44126', 'National Sport Center Nanchang'),
#  ('sr:complex:44128', 'Center Plains Tennis Center'),
#  ('sr:complex:44130', 'Les Arenes de Metz'),
#  ('sr:complex:44516', 'Ariake Tennis Forest Park Ariake Colesseum'),
#  ('sr:complex:44518', 'Qi Zhong Tennis Center'),
#  ('sr:complex:44520', 'Olympic Tennis Courts'),
#  ('sr:complex:44522', 'Olympic Tennis School'),
#  ('sr:complex:44640', 'Eurosporting Cordenons'),
#  ('sr:complex:46448', 'Hakons Hall'),
#  ('sr:complex:46526', 'National Tennis Center'),
#  ('sr:complex:46550', 'Palais des Sports'),
#  ('sr:complex:46552', 'Circolo del Tennis Firenze 1898'),
#  ('sr:complex:47140', 'Tips Arena Linz'),
#  ('sr:complex:47146', 'Solano Community College'),
#  ('sr:complex:47302', 'Ice Palace Krylatskoye'),
#  ('sr:complex:47306', 'Sportpark Ismaning'),
#  ('sr:complex:47476', 'DTB-Stutzpunkt'),
#  ('sr:complex:47815', 'Playford City Tennis Centre'),
#  ('sr:complex:47817', 'House of Sports'),
#  ('sr:complex:47819', 'Guayaquil Tennis Club'),
#  ('sr:complex:47893', 'Palalido Allianz Cloud'),
#  ('sr:complex:48779', 'Tennis Center, Roncaddizza'),
#  ('sr:complex:48857', 'Complexo Municipal de Tenis da Maia'),
#  ('sr:complex:49319', 'Stan Sheriff Center'),
#  ('sr:complex:49633', 'Bendigo Tennis Centre'),
#  ('sr:complex:49635', 'Complexe Tennistique Marie-Louise Lhuillier'),
#  ('sr:complex:49637', 'University of Michigan Varsity Tennis Center'),
#  ('sr:complex:49803', 'Kooyong Lawn Tennis Club'),
#  ('sr:complex:50605', 'Club Deportivo Universidad Catolica'),
#  ('sr:complex:50973', 'Tennis Club Cagliari'),
#  ('sr:complex:51589', 'Palais Des Sports De Gerland'),
#  ('sr:complex:51745', 'Pakistan Sports Complex'),
#  ('sr:complex:51757', 'Club de Tenis Santa Cruz'),
#  ('sr:complex:51761', 'Club Megasaray Tennis Centre'),
#  ('sr:complex:51775', 'Automobile and Touring Club of Lebanon'),
#  ('sr:complex:51779', 'Club Lawn Tennis de la Exposicion'),
#  ('sr:complex:51783', 'Oslo Tennis Arena'),
#  ('sr:complex:51785', 'Siauliai Tennis Academy'),
#  ('sr:complex:51791', 'Club Internacional de Tenis'),
#  ('sr:complex:51795', 'Federacion Nacional De Tenis'),
#  ('sr:complex:51797', 'Costa Rica Country Club'),
#  ('sr:complex:51805', 'Alex Metreveli Tennis Club'),
#  ('sr:complex:52275', 'TK As Timok'),
#  ('sr:complex:52289', 'TK Magnet'),
#  ('sr:complex:52527', 'COMUNIDAD VALENCIANA'),
#  ('sr:complex:52537', 'Sparta Prague Tennis Complex'),
#  ('sr:complex:52559', 'National Tennis Centre'),
#  ('sr:complex:52665', 'TOP SEED TENNIS CLUB'),
#  ('sr:complex:53263', 'Henan Provincial Sports Centre Stadium'),
#  ('sr:complex:53979', 'TC Bad Homburg'),
#  ('sr:complex:54105', 'Foro Italico'),
#  ('sr:complex:55029', 'Forte Village Resort'),
#  ('sr:complex:56886', 'Limak Arcadia Sport Resort'),
#  ('sr:complex:56888', 'Zayed Sports City International Tennis Centre'),
#  ('sr:complex:57152', 'North-West University Tennis Complex'),
#  ('sr:complex:57154', 'Circolo Tennis I Faggi'),
#  ('sr:complex:57188', 'Club De Campo Bellavista'),
#  ('sr:complex:57248', 'OCBC Arena'),
#  ('sr:complex:57286', 'Halle Tony Garnier'),
#  ('sr:complex:57308', 'Formula Tennisa Lakhta'),
#  ('sr:complex:57582', 'Palasport Biella'),
#  ('sr:complex:57924', 'Hala Na Skarpie'),
#  ('sr:complex:57926', 'National Tennis Centre'),
#  ('sr:complex:57928', 'Elite Tennis Club'),
#  ('sr:complex:57930', 'Cordoba Lawn Tennis Club'),
#  ('sr:complex:57950', 'Istanbul Tennis Center'),
#  ('sr:complex:58380', 'Tenis Centar Maksimir'),
#  ('sr:complex:58572', 'President Tennis Club'),
#  ('sr:complex:58652', 'Rebsamen Tennis Center'),
#  ('sr:complex:58874', 'Complexo Tenis Monte Aventino'),
#  ('sr:complex:58972', 'Tennis Club Perugia'),
#  ('sr:complex:59004', 'TC GM Sports Anif'),
#  ('sr:complex:59008', 'Braunschweiger Tennis und Hockeyclub'),
#  ('sr:complex:59082', 'Ciric Sport Base'),
#  ('sr:complex:59090', 'Amersfoort Lawn Tennis Club'),
#  ('sr:complex:59096', 'Tennis Club Todi 1971'),
#  ('sr:complex:59204', 'Arka Tennis Club'),
#  ('sr:complex:59212', 'Cabo Sports Complex'),
#  ('sr:complex:59214', 'ATP Stadion Goran Ivanisevic'),
#  ('sr:complex:59292', 'Cary Tennis Park'),
#  ('sr:complex:59332', 'Tennis Club Triestino'),
#  ('sr:complex:59334', 'Tennis Club Triestino'),
#  ('sr:complex:59348', 'LTP Tennis Mount Pleasant'),
#  ('sr:complex:59464', 'The Thoreau Club'),
#  ('sr:complex:59466', 'San Jose State University Tennis Center'),
#  ('sr:complex:59468', 'Winners Sports Club'),
#  ('sr:complex:59544', 'Liberec Tennis Club'),
#  ('sr:complex:59730', 'Centro Tennis Cassa di Risparmio'),
#  ('sr:complex:59754', 'Associazione Tennis Verona'),
#  ('sr:complex:59774', 'LTV 1899'),
#  ('sr:complex:59868', 'XS Tennis Village'),
#  ('sr:complex:59890', 'Jacobs Pavilion at Nautica'),
#  ('sr:complex:59994', 'Legia Tenis & Golf'),
#  ('sr:complex:60188', 'Tennis Club Ruppurr 1929 e. V.'),
#  ('sr:complex:60190', 'Park Mladen Stojanovic'),
#  ('sr:complex:60192', 'Tennis Sporting Club de Cassis Les Gorguettes'),
#  ('sr:complex:60194', 'Tennis Club "Tennispark"'),
#  ('sr:complex:60196', 'Real Club de Tenis Betis'),
#  ('sr:complex:60198', 'Tennis Club Tulln'),
#  ('sr:complex:60272', 'TED Tenis Eskrim Dagcilik Spor Kulubu'),
#  ('sr:complex:60274', 'Club Rancho San Francisco'),
#  ('sr:complex:60276', 'Wojska Polskiego'),
#  ('sr:complex:60350', 'Le Liberte'),
#  ('sr:complex:60384', 'Rakiura Resort'),
#  ('sr:complex:60386', 'Jan Group Arena'),
#  ('sr:complex:60388', 'Lyttos Sportscenter'),
#  ('sr:complex:60390', 'Tennis Centre Portoroz'),
#  ('sr:complex:60396', 'National Tennis Centre'),
#  ('sr:complex:60416', 'Centrul National de Tenis'),
#  ('sr:complex:60418', 'Clube de Tenis de Braga'),
#  ('sr:complex:60420', 'Club Tungurahua'),
#  ('sr:complex:60538', 'Tennis Club Pamira'),
#  ('sr:complex:60540', 'Barnes Tennis Center'),
#  ('sr:complex:60640', 'Tennis Club Napoli'),
#  ('sr:complex:60678', 'Club de Polo y Equitacion San Cristobal'),
#  ('sr:complex:60860', 'Sporting Poseidon'),
#  ('sr:complex:61026', 'Abama Tennis Academy'),
#  ('sr:complex:61028', 'Ljubicic Tennis Academy'),
#  ('sr:complex:61333', 'PalaNorda'),
#  ('sr:complex:61339', 'Greater Midland Tennis Center'),
#  ('sr:complex:61425', 'Le Scarabee'),
#  ('sr:complex:61437', 'Pala Alpitour'),
#  ('sr:complex:61551', 'Iate Club de Brasilia'),
#  ('sr:complex:61553', 'Public Security Officers Club'),
#  ('sr:complex:61555', 'New Country Tennis Academy'),
#  ('sr:complex:61565', 'Parque Parota'),
#  ('sr:complex:61641', 'Circolo Tennis Villa Carpena'),
#  ('sr:complex:61643', 'Clube Hipico Santo Amaro'),
#  ('sr:complex:61645', 'Megasaray Tennis Academy'),
#  ('sr:complex:61707', 'Arena Loire Trelaze'),
#  ('sr:complex:61737', 'Parque Olimpico do Rio de Janeiro'),
#  ('sr:complex:61761', 'Seoul Olympic Park Tennis Center'),
#  ('sr:complex:62147', 'Styslinger Altec Tennis Complex'),
#  ('sr:complex:62319', 'Multisport Sports Club'),
#  ('sr:complex:62321', 'Tennis Academy El Cortijo Club De Campo'),
#  ('sr:complex:62323', 'Circolo Della Stampa Sporting'),
#  ('sr:complex:62391', 'Delhi Gymkhana Club'),
#  ('sr:complex:62393', 'Rixos Premium Belek'),
#  ('sr:complex:62397', 'Toto Hakriya Ashdod Arena'),
#  ('sr:complex:62401', 'The Lawn Tennis Association of Thailand'),
#  ('sr:complex:62403', 'Forus Tenniscenter'),
#  ('sr:complex:62407', 'Ace Tennis Club'),
#  ('sr:complex:62409', 'Tennis Club Roseto'),
#  ('sr:complex:62419', 'Club Manquehue de Vitacura'),
#  ('sr:complex:62595', 'Club Campestre de Pereira'),
#  ('sr:complex:62617', 'Padiglione Conza'),
#  ('sr:complex:62619', 'Tennis Club Saint-Brieuc'),
#  ('sr:complex:62811', 'Centro Deportivo Chapultepec'),
#  ('sr:complex:62823', 'Salinas Golf & Tennis Club'),
#  ('sr:complex:62847', 'Tennis Sanremo'),
#  ('sr:complex:62903', 'Monte-Carlo Country Club'),
#  ('sr:complex:62905', 'Payne Park Tennis Facility'),
#  ('sr:complex:62907', 'Circolo Tennis Hugo Simmen'),
#  ('sr:complex:63005', 'Adani Arena Rockhampton'),
#  ('sr:complex:63033', 'Club Campestre de Aguacalientes A.C.C.'),
#  ('sr:complex:63055', 'Teniski Klub Split'),
#  ('sr:complex:63057', 'Forestmeadows Tennis Center'),
#  ('sr:complex:63059', 'TTF Istanbul Tenis Merkezi'),
#  ('sr:complex:63245', 'SC Ostrava'),
#  ('sr:complex:63247', 'Tennis Club Garden'),
#  ('sr:complex:63249', 'Franklin Creek Tennis Center'),
#  ('sr:complex:63309', 'Parc ded Sports de Marville'),
#  ('sr:complex:63311', 'Danubis Tenniscenter Mauthausen'),
#  ('sr:complex:63321', 'Country Club Aixois'),
#  ('sr:complex:63323', 'Costa Verde Tenis Clube'),
#  ('sr:complex:63407', 'Villa Primrose'),
#  ('sr:complex:63409', 'Club de Tenis Coquimbo'),
#  ('sr:complex:63427', 'National Tennis Center'),
#  ('sr:complex:63429', 'Lagardere Paris Racing Club'),
#  ('sr:complex:63527', 'Circolo Tennis Francavilla al Mare Sporting Club'),
#  ('sr:complex:63649', 'TC RW-Troisdorf e.V'),
#  ('sr:complex:63833', 'TK Slovan Bratislava'),
#  ('sr:complex:63835', 'USTA National Campus'),
#  ('sr:complex:63907', 'Tenisovy Klub Prostejov'),
#  ('sr:complex:63933', 'OWL Arena'),
#  ('sr:complex:63935', 'The Queen’s Club'),
#  ('sr:complex:63937', 'CTC Corrientes Tennis Club'),
#  ('sr:complex:63941', 'Steffi-Graf Stadium'),
#  ('sr:complex:63943', 'Tennis Club Gaiba - Gaibledon'),
#  ('sr:complex:64051', 'Tenis Club Argentino'),
#  ('sr:complex:64265',
#   'AELTC Wimbledon Qualifying and Community Sports Ground'),
#  ('sr:complex:64369', 'Inacua Malaga'),
#  ('sr:complex:64379', 'Tennis Club de Troyes'),
#  ('sr:complex:64571', 'Salzburg Tennis Club'),
#  ('sr:complex:64573', 'Contrexeville Tennis Club'),
#  ('sr:complex:64751', 'Rome Tennis Center'),
#  ('sr:complex:64869', 'Am Rothenbaum'),
#  ('sr:complex:64871', 'Pearson Automotive Tennis Club'),
#  ('sr:complex:64883', 'C.D. Open Tenis Ciudad de Pozoblanco'),
#  ('sr:complex:64885', 'Tampereen Tenniskeskus Oy'),
#  ('sr:complex:65099', 'Circolo Tennis Maggioni'),
#  ('sr:complex:65103', 'Winnipeg Lawn Tennis Club'),
#  ('sr:complex:65105', 'Tennisclub Zug'),
#  ('sr:complex:65205', 'Hilary J. Boone Tennis Center'),
#  ('sr:complex:65215', 'Baza Sportiva Ciric'),
#  ('sr:complex:65347', 'Jockey Club del Peru'),
#  ('sr:complex:65435', 'Hollyburn Country Club'),
#  ('sr:complex:65437', 'Akademia Tenisowa Tenis Kozerki'),
#  ('sr:complex:65597', 'Tennis St-Luc - Les Loisirs De Granby'),
#  ('sr:complex:65601', 'TK Spoje Praha'),
#  ('sr:complex:65603', 'Nacionalni Trening Centar Teniskog'),
#  ('sr:complex:65717', 'A.S.D. Tennis Club Como'),
#  ('sr:complex:65719', 'Rafa Nadal Academy'),
#  ('sr:complex:65739', 'Stade Toulousain Tennis Club'),
#  ('sr:complex:65779', 'Etihad Arena'),
#  ('sr:complex:65849', 'Circolo Tennis Bari'),
#  ('sr:complex:65973', 'Tennis Academy SET'),
#  ('sr:complex:65975', 'SEB Arena'),
#  ('sr:complex:65977', 'Centro Cultural de Viana do Castelo'),
#  ('sr:complex:65979', 'The Lawn Tennis Association of Thailand'),
#  ('sr:complex:65981', 'Taipei Tennis Center'),
#  ('sr:complex:65983', 'National Tennis Centre'),
#  ('sr:complex:65985', 'Ohio State University'),
#  ('sr:complex:65997', 'Sport Social Club'),
#  ('sr:complex:66093', 'Tel Aviv International Convention Center'),
#  ('sr:complex:66187', 'Skanes Family Hotel Monastir'),
#  ('sr:complex:66559', 'Rio Tennis Academy'),
#  ('sr:complex:66565', 'Tennis Club Saint Tropez'),
#  ('sr:complex:66785', 'Spo1 Park'),
#  ('sr:complex:66787', 'Hamburger Tennis Verband e.V'),
#  ('sr:complex:66951', 'Tennis Club Ortisei'),
#  ('sr:complex:66953', 'Centro Libanes Mexicano de Tampico'),
#  ('sr:complex:67275', 'Olme Sport'),
#  ('sr:complex:67459', 'Ehime Prefectural Sports Complex'),
#  ('sr:complex:67621', 'Tennis Interieur Rene Verrier'),
#  ('sr:complex:67855', 'Yokkaichi Tennis Center'),
#  ('sr:complex:68141', 'Conde Jackson Tennis Club Maspalomas'),
#  ('sr:complex:68959', 'Club Nautico Hacoaj'),
#  ('sr:complex:69121', 'CLUBE CRISTOVAO COLOMBO'),
#  ('sr:complex:69179', 'Complexe Sportif du Blocry'),
#  ('sr:complex:69183', 'Estadio Espanol Chiguayante'),
#  ('sr:complex:69645', 'Complexe Jean Jaures'),
#  ('sr:complex:69779', 'Rome Tennis Center at Berry College'),
#  ('sr:complex:69789', 'Circolo Tennis Rovereto'),
#  ('sr:complex:69799', 'Yucatan Country Club'),
#  ('sr:complex:69965', 'Hurd Tennis Center'),
#  ('sr:complex:69971', 'Westwood Country Club'),
#  ('sr:complex:70271', 'Utilita Arena Birmingham'),
#  ('sr:complex:70335', 'Club Tennis Els Gorchs'),
#  ('sr:complex:70345', 'Club Tennis Girona'),
#  ('sr:complex:70661', 'Club Campestre'),
#  ('sr:complex:70663', 'Tenis Centar Firule'),
#  ('sr:complex:71287', 'Tennis Club Rot Weiss Troisdorf E. V.'),
#  ('sr:complex:71431', 'Club de Tennis La Bisbal Centre Esportiu'),
#  ('sr:complex:71923', 'Salle Omnisport de Rades'),
#  ('sr:complex:71961', 'Club La Meridiana'),
#  ('sr:complex:72061', 'Cranbrook Kingswood Tennis Complex'),
#  ('sr:complex:72523', 'Nice Lawn Tennis Club'),
#  ('sr:complex:72533', 'Complejo Deportivo Pedro Muñoz'),
#  ('sr:complex:72677', 'Corredor Turistico SJC-CSL'),
#  ('sr:complex:73167', 'Stanford Taube Tennis Center'),
#  ('sr:complex:73179', 'National Bank Tennis Hub @ West St Paul'),
#  ('sr:complex:73191', 'Parque Distrital de Raquetas'),
#  ('sr:complex:73227', 'AO Arena'),
#  ('sr:complex:73463', 'Academy Zhangjiagang'),
#  ('sr:complex:73795', 'Tivoli Tennis Center'),
#  ('sr:complex:73797', 'Guangzhou Nansha International Tennis Center'),
#  ('sr:complex:73807', 'Country Club Las Palmas'),
#  ('sr:complex:73817', 'Korty Mosrir'),
#  ('sr:complex:73979', 'Garikula Tennis Club'),
#  ('sr:complex:73981', 'ILT Stadium'),
#  ('sr:complex:73997', 'Autoclub Antofagasta'),
#  ('sr:complex:74007', 'Sportaktivpark Bad Waltersdorf'),
#  ('sr:complex:74017', 'Ty Tucker Tennis Center'),
#  ('sr:complex:74049', 'Tennis Club Mostar'),
#  ('sr:complex:74051', 'Helikon Teniszcentrum'),
#  ('sr:complex:74053', 'Multiversum Schwechat'),
#  ('sr:complex:74061', 'Tenis Club IDU'),
#  ('sr:complex:74063', 'Royal Stage'),
#  ('sr:complex:74065', 'Mini Stadium'),
#  ('sr:complex:74067', 'Complejo de Tenis Marcelo Arevalo'),
#  ('sr:complex:74173', 'National Tennis Center (Beeline Arena)'),
#  ('sr:complex:74183', 'Club Compensar Sede 220'),
#  ('sr:complex:74193', "Arena Co'Met"),
#  ('sr:complex:74730', 'Playford Tennis Centre'),
#  ('sr:complex:74732', 'Graciosa Country Club'),
#  ('sr:complex:74734', 'Ciudad Deportiva de Tampico'),
#  ('sr:complex:74736', 'Hengqin Tennis Center'),
#  ('sr:complex:74912', 'Estadio Paradisus Cancun Quintana Roo'),
#  ('sr:complex:74962', 'Arena Sofia'),
#  ('sr:complex:75062', 'Good To Great Tennis Academy'),
#  ('sr:complex:75064', 'Tennis Intérieur René Verrier'),
#  ('sr:complex:75066', 'Miki Disaster Management Park'),
#  ('sr:complex:75068', 'Carrasco Lawn Tennis Club'),
#  ('sr:complex:75070', 'Hacienda Chicureo'),
#  ('sr:complex:75192', 'Arena BRB'),
#  ('sr:complex:75200', 'Jurerê Sports Center'),
#  ('sr:complex:75607', 'Bezirksstützpunkt Biberach'),
#  ('sr:complex:75731', 'Hala Ricany'),
#  ('sr:complex:76035', 'Vitality Slezsko'),
#  ('sr:complex:76037', 'Jockey Club de Rosario'),
#  ('sr:complex:76089', 'Design Center Linz'),
#  ('sr:complex:76107',
#   'Guangzhou Development District International Tennis School'),
#  ('sr:complex:76885', 'Delhi Lawn Tennis Association'),
#  ('sr:complex:77217', 'Emilio Sanchez Academy'),
#  ('sr:complex:77389', 'Tiriac Stadium'),
#  ('sr:complex:77391', 'Tucumán Lawn Tennis Club'),
#  ('sr:complex:77425', 'Arena GNP Seguros'),
#  ('sr:complex:77517', 'Club Tennis Lleida'),
#  ('sr:complex:77595', 'Wuxi International Tennis Center'),
#  ('sr:complex:77615', 'Tênis Clube de Santos'),
#  ('sr:complex:77763', 'Complexo Desportivo do Jamor'),
#  ('sr:complex:77767', 'Tennis Club De Tunis'),
#  ('sr:complex:77883', 'Kachreti Golf Resort'),
#  ('sr:complex:78093', 'Sports Center Salata'),
#  ('sr:complex:78363', 'Community Sport Centre'),
#  ('sr:complex:78489', 'Baza Sportiva Olimpia'),
#  ('sr:complex:78753', 'Sporting Club Verona'),
#  ('sr:complex:78831', 'Victoria Park Tennis Stadium'),
#  ('sr:complex:79097', 'Bonn Tennis and Hockey Club'),
#  ('sr:complex:79103', 'Sid And Hazel Dillon Tennis Center'),
#  ('sr:complex:79281', 'Tennis Club Izida'),
#  ('sr:complex:79391', 'Omega Sport Center'),
#  ('sr:complex:79459', 'Clube de Tenis do Porto'),
#  ('sr:complex:79633', 'Gezira Sporting Club'),
#  ('sr:complex:79665', 'Montreux Tennis Club'),
#  ('sr:complex:79837', 'Club Campestre Farallones'),
#  ('sr:complex:79851', 'Fly Palmy Arena'),
#  ('sr:complex:79853', 'Tennis Club Lokomotiv'),
#  ('sr:complex:79855', 'Palm Hills Sports Club'),
#  ('sr:complex:79861', 'Tennis Club de Avenir Sportif de la Marsa'),
#  ('sr:complex:80737', 'International Tennis Center'),
#  ('sr:complex:80851', 'Beograndska Arena'),
#  ('sr:complex:80961', 'Inalpi Arena'),
#  ('sr:complex:80963', 'All In Country Club Decines'),
#  ('sr:complex:81249', 'Las Hadas Golf & Country Club'),
#  ('sr:complex:81543', 'Headington Family Tennis Center'),
#  ('sr:complex:81613', 'Royal SC Tennis'),
#  ('sr:complex:81635', 'LSU'),
#  ('sr:complex:81651', 'Robson Tennis Center'),
#  ('sr:complex:81661', 'Wake Forest Tennis Center'),
#  ('sr:complex:81673', 'Palmira Tennis Club'),
#  ('sr:complex:81681', 'Tennis Courts of the SW University Neofit Rilski'),
#  ('sr:complex:81713', 'Penina Hotel & Golf Resort'),
#  ('sr:complex:81717', 'Bloomington'),
#  ('sr:complex:81745', 'Clube Tenis Portimao'),
#  ('sr:complex:81747', 'Atlantis The Palm'),
#  ('sr:complex:81751', 'Kallang Tennis Centre'),
#  ('sr:complex:81779', 'KPI Park'),
#  ('sr:complex:81809',
#   'Courts De Tennis De La Cité Nationale Sportive El Menza'),
#  ('sr:complex:81811', 'Sala Polivalenta Craiova'),
#  ('sr:complex:81813', 'New Sport Palace'),
#  ('sr:complex:81815', 'Complejo de Raquetas'),
#  ('sr:complex:81817', 'DLTA Complex'),
#  ('sr:complex:81819', 'Monte-Carlo Country Club'),
#  ('sr:complex:81821', 'TENIS ESKRIM DAGCILIK KULÜBÜ'),
#  ('sr:complex:81823', 'Beeline Arena'),
#  ('sr:complex:81827', 'Coque Luxenbourg'),
#  ('sr:complex:81977', 'Green Tennis Plaza'),
#  ('sr:complex:81985', 'Boulevard de las Naciones and Paseo de los Manglares'),
#  ('sr:complex:81995', 'Georgia Gwinnett'),
#  ('sr:complex:82007', 'Sport Center Visnjik (Clay)'),
#  ('sr:complex:82033', 'Spot - Salle Jean Burger'),
#  ('sr:complex:82065', 'Raquet Village'),
#  ('sr:complex:82109', 'Manzanillo'),
#  ('sr:complex:82131', 'Club de Golf Tres Marias'),
#  ('sr:complex:82133', 'Sheraton Buganvilias Resort and Convention Center'),
#  ('sr:complex:82197', 'Tennis Club Porto Rose'),
#  ('sr:complex:82223', 'Complejo Deportivo San Carlos De Apoquindo'),
#  ('sr:complex:82243', 'Club Tenis Ciutadella'),
#  ('sr:complex:82279', 'Tenis Club Crvena Zvezda'),
#  ('sr:complex:82301', 'Villa Reale Tennis Monza'),
#  ('sr:complex:82313', 'Carvoeiro Clube de Tenis'),
#  ('sr:complex:82335', 'Sarasota Sports Club'),
#  ('sr:complex:82343', 'Le Central Tennis Club'),
#  ('sr:complex:82356', 'Dan Maskell Tennis Centre'),
#  ('sr:complex:82415', 'George P Mitchell 40 Tennis Center'),
#  ('sr:complex:82417', 'National Tennis Center'),
#  ('sr:complex:82467', 'Tcja Saint-Malo'),
#  ('sr:complex:82469', 'Club Tennis Vic')]

# %% [markdown]
# close cursor & db connection:

# %%
mycursor.close()
my_db_connection.close()
